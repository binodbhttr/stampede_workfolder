# %% [markdown]
# ## this file will load snapshots and store details of the tracked star cluster thoroughout the snapshots into individual files available at ./data

# %% [markdown]
# ### Given that I don't have all snapshots downloaded, I ran into issues of tracking clusters at unevenly spaced snapshots (code was going from snap 1 to snap 1+1. If snap 2 did not exsit, it didn't know how to jumpt to the next available snapshot. This code fixes this issue).

# %%
from fof_analysis import fof

# %% [markdown]
# above cell add the for loop and store into pkl

# %%
import gizmo_analysis as gizmo
import utilities as ut
from matplotlib import pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
from sl_utilities import distinct_colours as dc
from sl_utilities import distance_functions
import os
import pickle

# %%
#read in the simulation
simname = 'm12i_res7100'
simdir = '/Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100'

# %%
# creating a loop of snapshots (to track clusters over long periods of time)

# snapshot_start=446
# snapshot_end=600 

snaps = [412,446,486,534,590,591,592,593,594,595,596,597,598,599,600]

#Loading the sample cluster to be tracked and sorting its id and id_child
# snapnumber=590 #Remember to change it if you  are changing the star cluster you are tracking in given snapshot

path="/Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/Plots/"
if not os.path.exists(path):
  os.makedirs(path)


temporary_name ="fire2_clusters_m12i_res7100_snapshot_600_5.0>age>6.0.pkl"
# temporary_name = simname+'.'+str(snaps[0])+".minage"+ str('%.2f' %min_age_array_Gyr[k])+"_"+"maxage"+"_"+str('%.2f' %max_age_array_Gyr[k])+"_b"+str(b_parsec)+"_nmin"+str(ncut_min)+".pkl"
with open(path+temporary_name, "rb") as fp:
    cluster_dic = pickle.load(fp)

# %%
def matchids(id_current,id_child_current,id_next,id_child_next,id_generation_next): #this function returns the index of the ids in the next snapshot that match with the current
    ind=np.array(0)
    for i in range(len(id_current)):
        match=np.where((id_next==id_current[i])&(id_child_next==id_child_current[i])&(id_generation_next<30)) #Also add id_generations<30
    print("\nFound the id",id_next[match],"at the index",match[0],"in this snapshot")
    ind=np.append(ind,match)
    ind_tracked_id_next=ind[1:len(ind)]  #The extra element in the beginning is removed by this process
    print("\nThese are the indices of the ids that matched in current snapshot\n",ind_tracked_id_next)
    return ind_tracked_id_next  
################################################################
################################################################

# %%
total_clusters=len(cluster_dic)         #count the total no. of clusters we have in clusters file
total_snaps=len(snaps)  #count the total no. of snapshots we are going to track
snap=snaps[0]                      #Mark the beginning of the snapshot
test_cluster=1                             #Mark the beginning of the cluster that we would be tracking
ind_tracked={}                             #finding the indices of the tracked stars in each snapshot for each cluster.

tracked_data_all_clusters_each_snap={}     #dictionary for storing data from all clusters and in each snapshot

# %%
for snap in snaps:               #we run a for loop until the end of all snapshots
    part=gizmo.io.Read.read_snapshots(['star'],'index', snap, simulation_name=simname, simulation_directory=simdir, assign_hosts=True, assign_hosts_rotation=True)               #snap is the snapshot number here that changes everytime the loop iterates. It starts with sanpshot_start

    id=part['star'].prop('id')
    id_child=part['star'].prop('id.child')
    id_generation=part['star'].prop('id.generation')
    age=part['star'].prop('age')
    x=part['star'].prop('host.distance.principal')[:,0] #x component of the position of all stars 
    y=part['star'].prop('host.distance.principal')[:,1] #y component of the position of all stars
    z=part['star'].prop('host.distance.principal')[:,2] #z component of the position of all stars
    n=len(x) # counting the total no. of star particles
    vx=part['star'].prop('host.velocity.principal')[:,0]
    vy=part['star'].prop('host.velocity.principal')[:,1]
    vz=part['star'].prop('host.velocity.principal')[:,2]
    mass=part['star']['mass'] #mass of all stars in snapshot 691
    
#     above is simulation data without transformation

#  transformation code 
# save output into new set of variables = data with transformation

    
    
    
    #compute 3-D velocity in cylindrical coordinates
    # first value is along the major axes (positive definite)
    # secod value is azimuthal velocity in the plane of the disk (positive definite)
    # third value is vertical velocity wrt the disk (signed)
    vR_cyl=part['star'].prop('host.velocity.principal.cylindrical')[:,0]
    vphi_cyl=part['star'].prop('host.velocity.principal.cylindrical')[:,1]
    vz_cyl=part['star'].prop('host.velocity.principal.cylindrical')[:,2]
    print("\n#########\n############\nLoaded id,id_child,age,x,y,z,vx,vy,vz,mass, cylindrical velocities and number of particles for snapshot no.",snap)
    print("Total no of particles in this shapshot no.",snap,"is",n)
    
 ### Now matching the IDs of this snapshot with the ids of all clusters


    test_cluster=1                       #This is the test cluster to begin with. It resets to 1 at each snapshot 
    tracked_data_all_clusters={}         #This dictionary keeps the tracked information for all star clusters in given snapshot. It also resets with snapshots.
    for j in range(total_clusters):
        tracked_data={}                    #This dictionary holds the tracked information for a cluster temporarily until it is pushed to tracked_data_all_clusters
        print("\n\nNow Matching the ids of the snapshot",snap," with the cluster group id",test_cluster)
        id_test_cluster=cluster_dic[test_cluster]["id"]
        id_child_test_cluster=cluster_dic[test_cluster]["id_children"]
        sortind=np.argsort(id_test_cluster)
        id_test_cluster_sorted=id_test_cluster[sortind]
        id_child_test_cluster_sorted=id_child_test_cluster[sortind]
        print("The total no. of stars in cluster id ",test_cluster," is",len(id_test_cluster_sorted))
        print("Sorted ids of this cluster is",id_test_cluster_sorted)
        ind_tracked=matchids(id_test_cluster_sorted,id_child_test_cluster_sorted,id,id_child,id_generation)
    
    ################################################################
    ################################################################
    #Now finding the postion, velocities, age and mass of the tracked stars in each snapshots
        age_tracked=age[ind_tracked]
        x_tracked=x[ind_tracked]
        y_tracked=y[ind_tracked]
        z_tracked=z[ind_tracked]
        vx_tracked=vx[ind_tracked]
        vy_tracked=vy[ind_tracked]
        vz_tracked=vz[ind_tracked]
        mass_tracked=mass[ind_tracked]
        
        vR_cyl_tracked=vR_cyl[ind_tracked]
        vphi_cyl_tracked=vphi_cyl[ind_tracked]
        vz_cyl_tracked=vz_cyl[ind_tracked]
    
    
    ################################################################
    ################################################################
        #Now calculating center of mass and related properties  
        print(mass_tracked)
        xcm=distance_functions.cm(x_tracked,mass_tracked)
        ycm=distance_functions.cm(y_tracked,mass_tracked)
        zcm=distance_functions.cm(z_tracked,mass_tracked)
        delta_rxyz=distance_functions.dr(x_tracked,y_tracked,z_tracked,mass_tracked)
        rmax=distance_functions.drmax(x_tracked,y_tracked,z_tracked,mass_tracked)
        ymax=(ycm+1.1*rmax)
        ymin=(ycm-1.1*rmax)
        xmax=(xcm+1.1*rmax)
        xmin=(xcm-1.1*rmax)
        avg_delta_rxyz=np.mean(np.absolute(delta_rxyz))
  
  
    ################################################################
    ################################################################
    #Now lets write our tracked data from each snapshots to a file
        tracked_data={"ind_tracked":ind_tracked,"age_tracked":age_tracked,"x_tracked":x_tracked,"y_tracked":y_tracked,"z_tracked":z_tracked,
        "vx_tracked":vx_tracked,"vy_tracked":vy_tracked,"vz_tracked":vz_tracked,
        "mass_tracked":mass_tracked,"xcm":xcm,"ycm":ycm,"zcm":zcm,"delta_rxyz":delta_rxyz,"rmax":rmax,
        "ymax":ymax,"ymin":ymin,"xmax":xmax,"xmin":xmin,"avg_delta_rxyz":avg_delta_rxyz,
        "vR_cyl_tracked":vR_cyl_tracked,"vphi_cyl_tracked":vphi_cyl_tracked,"vz_cyl_tracked":vz_cyl_tracked}

    
        tracked_data_all_clusters.update({test_cluster:tracked_data}) #access it using tracked_data_all_clusters[clusterid]["key"]
        test_cluster+=1
  
  #We have collected all tracked information for our test clusters for one snapshot now which is in dictionary tracked_data_all_clusters.
  #We would store that dictionary in a pickle file as a backup data from each snapshot about or all star cluster.
  ###Now moving out of the j loop. We scanned all clusters and stored the tracked data into a dictionary tracked_data_all_clusters  
    file_name="tracked_clusters_at_snapshot_"+str(snap)+".pkl"
    with open(path+file_name, 'wb') as output:
        pickle.dump(tracked_data_all_clusters, output)
    print("\n Stored tracked data of all stars clusters in the snapshot no.",snap,"to filename:",file_name,"\n#####\n")
  #Note we are still in i loop which is scanning each snapshot !!!!!!!!!!!!!!!!!!
    tracked_data_all_clusters_each_snap.update({snap:tracked_data_all_clusters}) 

 
#Came out of i loop 
  
#Finally we scanned through all the snapshots and now we come out of the loop to store the final file that contains all the tracked information of all clusters 
#Now we store the tracked data of all clusters into a dictionary with snapshot number as the key. This would be our final dictionary of dictinaries. 
with open(path+"total_data_tracked_clusters_all_snapshots.pkl", 'wb') as output:
    pickle.dump(tracked_data_all_clusters_each_snap, output) #access the data using tracked_data_all_clusters_each_snap[snapshot][cluster_id]["x_tracked"])
  
#Expected Result: tracked_data_all_clusters_each_snap={596:{1:tracked_data,2:tracked_data..},597:{1:tracked_data,2:tracked_data..upto total clusters},598....     upto total snapshots}
# Out:
# # in utilities.simulation.Snapshot():
# * reading:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/snapshot_times.txt
#
#   using snapshot index = 412, redshift = 0.399
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/output/snapdir_412/snapshot_412.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 70514272 particles
#     dark2     (id = 2): 5513331 particles
#     gas       (id = 0): 60849899 particles
#     star      (id = 4): 9868633 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['star']
# /Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/repos/utilities/simulation.py:93: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if snapshot_values == 'all' or snapshot_values == ['all'] or snapshot_values is None:
# * reading particles from:
#     snapshot_412.0.hdf5
#     snapshot_412.1.hdf5
#     snapshot_412.2.hdf5
#     snapshot_412.3.hdf5
#
# * reading cosmological parameters from:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/initial_condition/ic_agora_m12i.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/track/host_coordinates.hdf5
#   host1 position = (42060.36, 43741.45, 45776.49) [kpc comoving]
#   host1 velocity = (-60.9, 68.4, 96.3) [km / s]
#   host1 axis ratios = (0.30, 0.33, 0.91)
#
#
# #########
# ############
# Loaded id,id_child,age,x,y,z,vx,vy,vz,mass, cylindrical velocities and number of particles for snapshot no. 412
# Total no of particles in this shapshot no. 412 is 9868633
#
#
# Now Matching the ids of the snapshot 412  with the cluster group id 1
# The total no. of stars in cluster id  1  is 6
# Sorted ids of this cluster is [11448980 17601245 28363580 46218099 52654906 59514107]
#
# Found the id [59514107] at the index [6379701] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [6379701]
# [7827.4424]
#
#
# Now Matching the ids of the snapshot 412  with the cluster group id 2
# The total no. of stars in cluster id  2  is 5
# Sorted ids of this cluster is [10956972 19282605 30082663 37408125 38998283]
#
# Found the id [38998283] at the index [6586217] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [6586217]
# [11767.462]
#
#  Stored tracked data of all stars clusters in the snapshot no. 412 to filename: tracked_clusters_at_snapshot_412.pkl
# #####
#
#
# # in utilities.simulation.Snapshot():
# * reading:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/snapshot_times.txt
#
#   using snapshot index = 446, redshift = 0.300
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/output/snapdir_446/snapshot_446.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 70514272 particles
#     dark2     (id = 2): 5513331 particles
#     gas       (id = 0): 59886009 particles
#     star      (id = 4): 10884848 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['star']
#
# * reading particles from:
#     snapshot_446.0.hdf5
#     snapshot_446.1.hdf5
#     snapshot_446.2.hdf5
#     snapshot_446.3.hdf5
#
# * reading cosmological parameters from:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/initial_condition/ic_agora_m12i.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/track/host_coordinates.hdf5
#   host1 position = (41988.72, 43826.07, 45889.89) [kpc comoving]
#   host1 velocity = (-55.8, 73.1, 94.8) [km / s]
#   host1 axis ratios = (0.24, 0.26, 0.91)
#
#
# #########
# ############
# Loaded id,id_child,age,x,y,z,vx,vy,vz,mass, cylindrical velocities and number of particles for snapshot no. 446
# Total no of particles in this shapshot no. 446 is 10884848
#
#
# Now Matching the ids of the snapshot 446  with the cluster group id 1
# The total no. of stars in cluster id  1  is 6
# Sorted ids of this cluster is [11448980 17601245 28363580 46218099 52654906 59514107]
#
# Found the id [59514107] at the index [5248849] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [5248849]
# [7739.1943]
#
#
# Now Matching the ids of the snapshot 446  with the cluster group id 2
# The total no. of stars in cluster id  2  is 5
# Sorted ids of this cluster is [10956972 19282605 30082663 37408125 38998283]
#
# Found the id [38998283] at the index [7389960] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [7389960]
# [11214.977]
#
#  Stored tracked data of all stars clusters in the snapshot no. 446 to filename: tracked_clusters_at_snapshot_446.pkl
# #####
#
#
# # in utilities.simulation.Snapshot():
# * reading:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/snapshot_times.txt
#
#   using snapshot index = 486, redshift = 0.201
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/output/snapdir_486/snapshot_486.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 70514272 particles
#     dark2     (id = 2): 5513331 particles
#     gas       (id = 0): 58949032 particles
#     star      (id = 4): 11904900 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['star']
#
# * reading particles from:
#     snapshot_486.0.hdf5
#     snapshot_486.1.hdf5
#     snapshot_486.2.hdf5
#     snapshot_486.3.hdf5
#
# * reading cosmological parameters from:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/initial_condition/ic_agora_m12i.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/track/host_coordinates.hdf5
#   host1 position = (41918.97, 43922.57, 46010.39) [kpc comoving]
#   host1 velocity = (-48.0, 78.9, 94.2) [km / s]
#   host1 axis ratios = (0.20, 0.20, 0.99)
#
#
# #########
# ############
# Loaded id,id_child,age,x,y,z,vx,vy,vz,mass, cylindrical velocities and number of particles for snapshot no. 486
# Total no of particles in this shapshot no. 486 is 11904900
#
#
# Now Matching the ids of the snapshot 486  with the cluster group id 1
# The total no. of stars in cluster id  1  is 6
# Sorted ids of this cluster is [11448980 17601245 28363580 46218099 52654906 59514107]
#
# Found the id [59514107] at the index [5248625] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [5248625]
# [7622.56]
#
#
# Now Matching the ids of the snapshot 486  with the cluster group id 2
# The total no. of stars in cluster id  2  is 5
# Sorted ids of this cluster is [10956972 19282605 30082663 37408125 38998283]
#
# Found the id [38998283] at the index [9415969] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [9415969]
# [10815.033]
#
#  Stored tracked data of all stars clusters in the snapshot no. 486 to filename: tracked_clusters_at_snapshot_486.pkl
# #####
#
#
# # in utilities.simulation.Snapshot():
# * reading:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/snapshot_times.txt
#
#   using snapshot index = 534, redshift = 0.100
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/output/snapdir_534/snapshot_534.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 70514272 particles
#     dark2     (id = 2): 5513331 particles
#     gas       (id = 0): 57969288 particles
#     star      (id = 4): 12974577 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['star']
#
# * reading particles from:
#     snapshot_534.0.hdf5
#     snapshot_534.1.hdf5
#     snapshot_534.2.hdf5
#     snapshot_534.3.hdf5
#
# * reading cosmological parameters from:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/initial_condition/ic_agora_m12i.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/track/host_coordinates.hdf5
#   host1 position = (41860.26, 44029.37, 46137.26) [kpc comoving]
#   host1 velocity = (-44.6, 69.5, 96.8) [km / s]
#   host1 axis ratios = (0.17, 0.18, 0.96)
#
#
# #########
# ############
# Loaded id,id_child,age,x,y,z,vx,vy,vz,mass, cylindrical velocities and number of particles for snapshot no. 534
# Total no of particles in this shapshot no. 534 is 12974577
#
#
# Now Matching the ids of the snapshot 534  with the cluster group id 1
# The total no. of stars in cluster id  1  is 6
# Sorted ids of this cluster is [11448980 17601245 28363580 46218099 52654906 59514107]
#
# Found the id [59514107] at the index [7797598] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [7797598]
# [7538.082]
#
#
# Now Matching the ids of the snapshot 534  with the cluster group id 2
# The total no. of stars in cluster id  2  is 5
# Sorted ids of this cluster is [10956972 19282605 30082663 37408125 38998283]
# Found the id [38998283] at the index [6059281] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [6059281]
# [10523.518]
#
#  Stored tracked data of all stars clusters in the snapshot no. 534 to filename: tracked_clusters_at_snapshot_534.pkl
# #####
#
#
# # in utilities.simulation.Snapshot():
# * reading:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/snapshot_times.txt
#
#   using snapshot index = 590, redshift = 0.002
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/output/snapdir_590/snapshot_590.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 70514272 particles
#     dark2     (id = 2): 5513331 particles
#     gas       (id = 0): 57075281 particles
#     star      (id = 4): 13959845 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['star']
#
# * reading particles from:
#     snapshot_590.0.hdf5
#     snapshot_590.1.hdf5
#     snapshot_590.2.hdf5
#     snapshot_590.3.hdf5
#
# * reading cosmological parameters from:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/initial_condition/ic_agora_m12i.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/track/host_coordinates.hdf5
#   host1 position = (41793.43, 44129.60, 46265.46) [kpc comoving]
#   host1 velocity = (-51.8, 72.8, 94.2) [km / s]
#   host1 axis ratios = (0.16, 0.16, 0.98)
#
#
# #########
# ############
# Loaded id,id_child,age,x,y,z,vx,vy,vz,mass, cylindrical velocities and number of particles for snapshot no. 590
# Total no of particles in this shapshot no. 590 is 13959845
#
#
# Now Matching the ids of the snapshot 590  with the cluster group id 1
# The total no. of stars in cluster id  1  is 6
# Sorted ids of this cluster is [11448980 17601245 28363580 46218099 52654906 59514107]
#
# Found the id [59514107] at the index [320506] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [320506]
# [7538.082]
#
#
# Now Matching the ids of the snapshot 590  with the cluster group id 2
# The total no. of stars in cluster id  2  is 5
# Sorted ids of this cluster is [10956972 19282605 30082663 37408125 38998283]
#
# Found the id [38998283] at the index [13824280] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [13824280]
# [10416.606]
#
#  Stored tracked data of all stars clusters in the snapshot no. 590 to filename: tracked_clusters_at_snapshot_590.pkl
# #####
#
#
# # in utilities.simulation.Snapshot():
# * reading:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/snapshot_times.txt
#
#   using snapshot index = 591, redshift = 0.001
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/output/snapdir_591/snapshot_591.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 70514272 particles
#     dark2     (id = 2): 5513331 particles
#     gas       (id = 0): 57073835 particles
#     star      (id = 4): 13961462 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['star']
#
# * reading particles from:
#     snapshot_591.0.hdf5
#     snapshot_591.1.hdf5
#     snapshot_591.2.hdf5
#     snapshot_591.3.hdf5
#
# * reading cosmological parameters from:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/initial_condition/ic_agora_m12i.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/track/host_coordinates.hdf5
#   host1 position = (41793.29, 44129.76, 46265.69) [kpc comoving]
#   host1 velocity = (-51.8, 72.8, 94.3) [km / s]
#   host1 axis ratios = (0.16, 0.16, 0.98)
#
#
# #########
# ############
# Loaded id,id_child,age,x,y,z,vx,vy,vz,mass, cylindrical velocities and number of particles for snapshot no. 591
# Total no of particles in this shapshot no. 591 is 13961462
#
#
# Now Matching the ids of the snapshot 591  with the cluster group id 1
# The total no. of stars in cluster id  1  is 6
# Sorted ids of this cluster is [11448980 17601245 28363580 46218099 52654906 59514107]
#
# Found the id [59514107] at the index [8687574] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [8687574]
# [7538.082]
#
#
# Now Matching the ids of the snapshot 591  with the cluster group id 2
# The total no. of stars in cluster id  2  is 5
# Sorted ids of this cluster is [10956972 19282605 30082663 37408125 38998283]
#
# Found the id [38998283] at the index [5426284] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [5426284]
# [10416.606]
#
#  Stored tracked data of all stars clusters in the snapshot no. 591 to filename: tracked_clusters_at_snapshot_591.pkl
# #####
#
#
# # in utilities.simulation.Snapshot():
# * reading:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/snapshot_times.txt
#
#   using snapshot index = 592, redshift = 0.001
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/output/snapdir_592/snapshot_592.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 70514272 particles
#     dark2     (id = 2): 5513331 particles
#     gas       (id = 0): 57072221 particles
#     star      (id = 4): 13963183 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['star']
#
# * reading particles from:
#     snapshot_592.0.hdf5
#     snapshot_592.1.hdf5
#     snapshot_592.2.hdf5
#     snapshot_592.3.hdf5
#
# * reading cosmological parameters from:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/initial_condition/ic_agora_m12i.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/track/host_coordinates.hdf5
#   host1 position = (41793.16, 44129.93, 46265.91) [kpc comoving]
#   host1 velocity = (-51.8, 72.8, 94.4) [km / s]
#   host1 axis ratios = (0.16, 0.16, 0.98)
#
#
# #########
# ############
# Loaded id,id_child,age,x,y,z,vx,vy,vz,mass, cylindrical velocities and number of particles for snapshot no. 592
# Total no of particles in this shapshot no. 592 is 13963183
#
#
# Now Matching the ids of the snapshot 592  with the cluster group id 1
# The total no. of stars in cluster id  1  is 6
# Sorted ids of this cluster is [11448980 17601245 28363580 46218099 52654906 59514107]
#
# Found the id [59514107] at the index [5966062] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [5966062]
# [7538.082]
#
#
# Now Matching the ids of the snapshot 592  with the cluster group id 2
# The total no. of stars in cluster id  2  is 5
# Sorted ids of this cluster is [10956972 19282605 30082663 37408125 38998283]
#
# Found the id [38998283] at the index [3559864] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [3559864]
# [10416.606]
#
#  Stored tracked data of all stars clusters in the snapshot no. 592 to filename: tracked_clusters_at_snapshot_592.pkl
# #####
#
#
# # in utilities.simulation.Snapshot():
# * reading:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/snapshot_times.txt
#
#   using snapshot index = 593, redshift = 0.001
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/output/snapdir_593/snapshot_593.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 70514272 particles
#     dark2     (id = 2): 5513331 particles
#     gas       (id = 0): 57070632 particles
#     star      (id = 4): 13964900 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['star']
#
# * reading particles from:
#     snapshot_593.0.hdf5
#     snapshot_593.1.hdf5
#     snapshot_593.2.hdf5
#     snapshot_593.3.hdf5
#
# * reading cosmological parameters from:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/initial_condition/ic_agora_m12i.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/track/host_coordinates.hdf5
#   host1 position = (41793.04, 44130.09, 46266.13) [kpc comoving]
#   host1 velocity = (-51.9, 72.8, 94.5) [km / s]
#   host1 axis ratios = (0.16, 0.16, 0.98)
#
#
# #########
# ############
# Loaded id,id_child,age,x,y,z,vx,vy,vz,mass, cylindrical velocities and number of particles for snapshot no. 593
# Total no of particles in this shapshot no. 593 is 13964900
#
#
# Now Matching the ids of the snapshot 593  with the cluster group id 1
# The total no. of stars in cluster id  1  is 6
# Sorted ids of this cluster is [11448980 17601245 28363580 46218099 52654906 59514107]
#
# Found the id [59514107] at the index [6013291] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [6013291]
# [7538.082]
#
#
# Now Matching the ids of the snapshot 593  with the cluster group id 2
# The total no. of stars in cluster id  2  is 5
# Sorted ids of this cluster is [10956972 19282605 30082663 37408125 38998283]
#
# Found the id [38998283] at the index [1286890] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [1286890]
# [10416.606]
#
#  Stored tracked data of all stars clusters in the snapshot no. 593 to filename: tracked_clusters_at_snapshot_593.pkl
# #####
#
#
# # in utilities.simulation.Snapshot():
# * reading:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/snapshot_times.txt
#
#   using snapshot index = 594, redshift = 0.001
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/output/snapdir_594/snapshot_594.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 70514272 particles
#     dark2     (id = 2): 5513331 particles
#     gas       (id = 0): 57069087 particles
#     star      (id = 4): 13966599 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['star']
#
# * reading particles from:
#     snapshot_594.0.hdf5
#     snapshot_594.1.hdf5
#     snapshot_594.2.hdf5
#     snapshot_594.3.hdf5
#
# * reading cosmological parameters from:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/initial_condition/ic_agora_m12i.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/track/host_coordinates.hdf5
#   host1 position = (41792.92, 44130.25, 46266.34) [kpc comoving]
#   host1 velocity = (-52.0, 72.9, 94.6) [km / s]
#   host1 axis ratios = (0.16, 0.16, 0.98)
#
#
# #########
# ############
# Loaded id,id_child,age,x,y,z,vx,vy,vz,mass, cylindrical velocities and number of particles for snapshot no. 594
# Total no of particles in this shapshot no. 594 is 13966599
#
#
# Now Matching the ids of the snapshot 594  with the cluster group id 1
# The total no. of stars in cluster id  1  is 6
# Sorted ids of this cluster is [11448980 17601245 28363580 46218099 52654906 59514107]
#
# Found the id [59514107] at the index [12339134] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [12339134]
# [7538.082]
#
#
# Now Matching the ids of the snapshot 594  with the cluster group id 2
# The total no. of stars in cluster id  2  is 5
# Sorted ids of this cluster is [10956972 19282605 30082663 37408125 38998283]
#
# Found the id [38998283] at the index [8085376] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [8085376]
# [10416.606]
#
#  Stored tracked data of all stars clusters in the snapshot no. 594 to filename: tracked_clusters_at_snapshot_594.pkl
# #####
#
#
# # in utilities.simulation.Snapshot():
# * reading:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/snapshot_times.txt
#
#   using snapshot index = 595, redshift = 0.001
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/output/snapdir_595/snapshot_595.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 70514272 particles
#     dark2     (id = 2): 5513331 particles
#     gas       (id = 0): 57067638 particles
#     star      (id = 4): 13968198 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['star']
#
# * reading particles from:
#     snapshot_595.0.hdf5
#     snapshot_595.1.hdf5
#     snapshot_595.2.hdf5
#     snapshot_595.3.hdf5
#
# * reading cosmological parameters from:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/initial_condition/ic_agora_m12i.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/track/host_coordinates.hdf5
#   host1 position = (41792.80, 44130.40, 46266.57) [kpc comoving]
#   host1 velocity = (-52.1, 72.9, 94.6) [km / s]
#   host1 axis ratios = (0.16, 0.16, 0.98)
#
#
# #########
# ############
# Loaded id,id_child,age,x,y,z,vx,vy,vz,mass, cylindrical velocities and number of particles for snapshot no. 595
# Total no of particles in this shapshot no. 595 is 13968198
#
#
# Now Matching the ids of the snapshot 595  with the cluster group id 1
# The total no. of stars in cluster id  1  is 6
# Sorted ids of this cluster is [11448980 17601245 28363580 46218099 52654906 59514107]
#
# Found the id [59514107] at the index [13034807] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [13034807]
# [7538.082]
#
#
# Now Matching the ids of the snapshot 595  with the cluster group id 2
# The total no. of stars in cluster id  2  is 5
# Sorted ids of this cluster is [10956972 19282605 30082663 37408125 38998283]
#
# Found the id [38998283] at the index [4157802] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [4157802]
# [10416.606]
#
#  Stored tracked data of all stars clusters in the snapshot no. 595 to filename: tracked_clusters_at_snapshot_595.pkl
# #####
#
#
# # in utilities.simulation.Snapshot():
# * reading:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/snapshot_times.txt
#
#   using snapshot index = 596, redshift = 0.001
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/output/snapdir_596/snapshot_596.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 70514272 particles
#     dark2     (id = 2): 5513331 particles
#     gas       (id = 0): 57066077 particles
#     star      (id = 4): 13969903 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['star']
#
# * reading particles from:
#     snapshot_596.0.hdf5
#     snapshot_596.1.hdf5
#     snapshot_596.2.hdf5
#     snapshot_596.3.hdf5
#
# * reading cosmological parameters from:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/initial_condition/ic_agora_m12i.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/track/host_coordinates.hdf5
#   host1 position = (41792.66, 44130.55, 46266.80) [kpc comoving]
#   host1 velocity = (-52.3, 73.1, 94.7) [km / s]
#   host1 axis ratios = (0.16, 0.16, 0.98)
#
#
# #########
# ############
# Loaded id,id_child,age,x,y,z,vx,vy,vz,mass, cylindrical velocities and number of particles for snapshot no. 596
# Total no of particles in this shapshot no. 596 is 13969903
#
#
# Now Matching the ids of the snapshot 596  with the cluster group id 1
# The total no. of stars in cluster id  1  is 6
# Sorted ids of this cluster is [11448980 17601245 28363580 46218099 52654906 59514107]
#
# Found the id [59514107] at the index [5328282] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [5328282]
# [7538.082]
#
#
# Now Matching the ids of the snapshot 596  with the cluster group id 2
# The total no. of stars in cluster id  2  is 5
# Sorted ids of this cluster is [10956972 19282605 30082663 37408125 38998283]
#
# Found the id [38998283] at the index [10079928] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [10079928]
# [10416.606]
#
#  Stored tracked data of all stars clusters in the snapshot no. 596 to filename: tracked_clusters_at_snapshot_596.pkl
# #####
#
#
# # in utilities.simulation.Snapshot():
# * reading:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/snapshot_times.txt
#
#   using snapshot index = 597, redshift = 0.000
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/output/snapdir_597/snapshot_597.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 70514272 particles
#     dark2     (id = 2): 5513331 particles
#     gas       (id = 0): 57064479 particles
#     star      (id = 4): 13971634 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['star']
#
# * reading particles from:
#     snapshot_597.0.hdf5
#     snapshot_597.1.hdf5
#     snapshot_597.2.hdf5
#     snapshot_597.3.hdf5
#
# * reading cosmological parameters from:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/initial_condition/ic_agora_m12i.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/track/host_coordinates.hdf5
#   host1 position = (41792.51, 44130.72, 46267.03) [kpc comoving]
#   host1 velocity = (-52.4, 73.3, 94.7) [km / s]
#   host1 axis ratios = (0.16, 0.16, 0.98)
#
#
# #########
# ############
# Loaded id,id_child,age,x,y,z,vx,vy,vz,mass, cylindrical velocities and number of particles for snapshot no. 597
# Total no of particles in this shapshot no. 597 is 13971634
#
#
# Now Matching the ids of the snapshot 597  with the cluster group id 1
# The total no. of stars in cluster id  1  is 6
# Sorted ids of this cluster is [11448980 17601245 28363580 46218099 52654906 59514107]
#
# Found the id [59514107] at the index [10309341] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [10309341]
# [7538.082]
#
#
# Now Matching the ids of the snapshot 597  with the cluster group id 2
# The total no. of stars in cluster id  2  is 5
# Sorted ids of this cluster is [10956972 19282605 30082663 37408125 38998283]
#
# Found the id [38998283] at the index [13742553] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [13742553]
# [10416.606]
#
#  Stored tracked data of all stars clusters in the snapshot no. 597 to filename: tracked_clusters_at_snapshot_597.pkl
# #####
#
#
# # in utilities.simulation.Snapshot():
# * reading:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/snapshot_times.txt
#
#   using snapshot index = 598, redshift = 0.000
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/output/snapdir_598/snapshot_598.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 70514272 particles
#     dark2     (id = 2): 5513331 particles
#     gas       (id = 0): 57062850 particles
#     star      (id = 4): 13973410 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['star']
#
# * reading particles from:
#     snapshot_598.0.hdf5
#     snapshot_598.1.hdf5
#     snapshot_598.2.hdf5
#     snapshot_598.3.hdf5
#
# * reading cosmological parameters from:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/initial_condition/ic_agora_m12i.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/track/host_coordinates.hdf5
#   host1 position = (41792.39, 44130.90, 46267.25) [kpc comoving]
#   host1 velocity = (-52.3, 73.5, 94.7) [km / s]
#   host1 axis ratios = (0.16, 0.16, 0.98)
#
#
# #########
# ############
# Loaded id,id_child,age,x,y,z,vx,vy,vz,mass, cylindrical velocities and number of particles for snapshot no. 598
# Total no of particles in this shapshot no. 598 is 13973410
#
#
# Now Matching the ids of the snapshot 598  with the cluster group id 1
# The total no. of stars in cluster id  1  is 6
# Sorted ids of this cluster is [11448980 17601245 28363580 46218099 52654906 59514107]
#
# Found the id [59514107] at the index [3146034] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [3146034]
# [7538.082]
#
#
# Now Matching the ids of the snapshot 598  with the cluster group id 2
# The total no. of stars in cluster id  2  is 5
# Sorted ids of this cluster is [10956972 19282605 30082663 37408125 38998283]
#
# Found the id [38998283] at the index [5439811] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [5439811]
# [10416.606]
#
#  Stored tracked data of all stars clusters in the snapshot no. 598 to filename: tracked_clusters_at_snapshot_598.pkl
# #####
#
#
# # in utilities.simulation.Snapshot():
# * reading:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/snapshot_times.txt
#
#   using snapshot index = 599, redshift = 0.000
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/output/snapdir_599/snapshot_599.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 70514272 particles
#     dark2     (id = 2): 5513331 particles
#     gas       (id = 0): 57061516 particles
#     star      (id = 4): 13974917 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['star']
#
# * reading particles from:
#     snapshot_599.0.hdf5
#     snapshot_599.1.hdf5
#     snapshot_599.2.hdf5
#     snapshot_599.3.hdf5
#
# * reading cosmological parameters from:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/initial_condition/ic_agora_m12i.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/track/host_coordinates.hdf5
#   host1 position = (41792.27, 44131.07, 46267.46) [kpc comoving]
#   host1 velocity = (-52.3, 73.6, 94.7) [km / s]
#   host1 axis ratios = (0.16, 0.16, 0.98)
#
#
# #########
# ############
# Loaded id,id_child,age,x,y,z,vx,vy,vz,mass, cylindrical velocities and number of particles for snapshot no. 599
# Total no of particles in this shapshot no. 599 is 13974917
#
#
# Now Matching the ids of the snapshot 599  with the cluster group id 1
# The total no. of stars in cluster id  1  is 6
# Sorted ids of this cluster is [11448980 17601245 28363580 46218099 52654906 59514107]
#
# Found the id [59514107] at the index [7564652] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [7564652]
# [7538.082]
#
#
# Now Matching the ids of the snapshot 599  with the cluster group id 2
# The total no. of stars in cluster id  2  is 5
# Sorted ids of this cluster is [10956972 19282605 30082663 37408125 38998283]
# Found the id [38998283] at the index [9063570] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [9063570]
# [10416.606]
#
#  Stored tracked data of all stars clusters in the snapshot no. 599 to filename: tracked_clusters_at_snapshot_599.pkl
# #####
#
#
# # in utilities.simulation.Snapshot():
# * reading:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/snapshot_times.txt
#
#   using snapshot index = 600, redshift = 0.000
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/output/snapdir_600/snapshot_600.0.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 70514272 particles
#     dark2     (id = 2): 5513331 particles
#     gas       (id = 0): 57060074 particles
#     star      (id = 4): 13976485 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['star']
#
# * reading particles from:
#     snapshot_600.0.hdf5
#     snapshot_600.1.hdf5
#     snapshot_600.2.hdf5
#     snapshot_600.3.hdf5
#
# * reading cosmological parameters from:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/initial_condition/ic_agora_m12i.conf
#
# * checking sanity of particle properties
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/m12i_res7100/track/host_coordinates.hdf5
#   host1 position = (41792.15, 44131.23, 46267.68) [kpc comoving]
#   host1 velocity = (-52.2, 73.6, 94.7) [km / s]
#   host1 axis ratios = (0.16, 0.16, 0.99)
#
#
# #########
# ############
# Loaded id,id_child,age,x,y,z,vx,vy,vz,mass, cylindrical velocities and number of particles for snapshot no. 600
# Total no of particles in this shapshot no. 600 is 13976485
#
#
# Now Matching the ids of the snapshot 600  with the cluster group id 1
# The total no. of stars in cluster id  1  is 6
# Sorted ids of this cluster is [11448980 17601245 28363580 46218099 52654906 59514107]
#
# Found the id [59514107] at the index [11577188] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [11577188]
# [7538.082]
#
#
# Now Matching the ids of the snapshot 600  with the cluster group id 2
# The total no. of stars in cluster id  2  is 5
# Sorted ids of this cluster is [10956972 19282605 30082663 37408125 38998283]
#
# Found the id [38998283] at the index [292144] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [292144]
# [10416.606]
#
#  Stored tracked data of all stars clusters in the snapshot no. 600 to filename: tracked_clusters_at_snapshot_600.pkl
# #####

# %%
cluster_dic.keys()
tracked_data_all_clusters_each_snap.keys()

# %%
# print out masses see when it is giving me zero

# %%
path_2="/Network/Servers/VALIVARRE.PHY.TCU.EDU/Volumes/SDF2/aibrahim/Research_with_Sarah/Plots/"
# if not os.path.exists(path):
#   os.makedirs(path)


tracked_file ="total_data_tracked_clusters_all_snapshots.pkl"
# temporary_name = simname+'.'+str(snaps[0])+".minage"+ str('%.2f' %min_age_array_Gyr[k])+"_"+"maxage"+"_"+str('%.2f' %max_age_array_Gyr[k])+"_b"+str(b_parsec)+"_nmin"+str(ncut_min)+".pkl"
with open(path_2+tracked_file, "rb") as fp:
    tracked_data_all_clusters_each_snap = pickle.load(fp)

# %% [markdown]
# change aspect ratio CHECK
# plot rcm vs. zcm
# legend by snapshot number

# %%
snaps = [412,446,486,534,590,591,592,593,594,595,596,597,598,599,600]

fig2 = plt.figure()
ax2 = plt.gca()

for m in range(2,3):
    for i in snaps:
        
        x_tracked_cluster = tracked_data_all_clusters_each_snap[i][m]["xcm"]
        y_tracked_cluster = tracked_data_all_clusters_each_snap[i][m]["ycm"]
        z_tracked_cluster = tracked_data_all_clusters_each_snap[i][m]["zcm"]
        rcm = np.sqrt(x_tracked_cluster**2+y_tracked_cluster**2)
        ax2.scatter(rcm,z_tracked_cluster,label=i)
        ax2.set_xlabel("X [kpc]")
        ax2.set_ylabel("Z [kpc]")
#         ax2.set_aspect('equal')
#         ax2.legend()
    plt.show()

# %%
rcm_values = []
zcm_values = []
for m in range(1,2):
    for i in snaps:
        snaps = [412,446,486,534,590,591,592,593,594,595,596,597,598,599,600]

        x_tracked_cluster = tracked_data_all_clusters_each_snap[i][m]["xcm"]
        y_tracked_cluster = tracked_data_all_clusters_each_snap[i][m]["ycm"]
        z_tracked_cluster = tracked_data_all_clusters_each_snap[i][m]["zcm"]
        rcm = np.sqrt(x_tracked_cluster**2+y_tracked_cluster**2)
        rcm_values.append(rcm)
        zcm_values.append(z_tracked_cluster)
#         ax2.scatter(np.array(rcm),np.array(z_tracked_cluster),c=snaps,cmap='Purples')
#         ax2.set_xlabel("rcm [kpc]")
#         ax2.set_ylabel("Z [kpc]")
#         ax2.set_aspect('equal')
# #         print(x_tracked_cluster)
#         print(rcm)
#         print(z_tracked_cluster)

        #         ax2.legend()
#     plt.show()

# %%
fig = plt.figure()
ax = plt.gca()

ax.scatter(rcm_values,zcm_values,c=snaps,cmap='gist_rainbow')
ax.text(3.78,-0.52,'snap 600')
ax.text(3.27,-0.27,'Snap 446')
ax.text(5.8,1.47,'Snap 486')
ax.text(3.58, 1.4372971018024545,'Snap 534')
ax.text(3.99,-0.3500246096634756,'Snap 599')
ax.set_xlabel('Rcm [Kpc]')
ax.set_ylabel('Zcm [Kpc]')
ax.set_aspect('equal')

# %%
# ###### snaps = [446,486,534,590,591,592,593,594,595,596,597,598,599,600]

# fig2 = plt.figure()
# ax2 = plt.gca()

rcm_values = []
zcm_values = []
for m in range(2,3):
    for i in snaps:
        snaps = [412,446,486,534,590,591,592,593,594,595,596,597,598,599,600]

        x_tracked_cluster = tracked_data_all_clusters_each_snap[i][m]["xcm"]
        y_tracked_cluster = tracked_data_all_clusters_each_snap[i][m]["ycm"]
        z_tracked_cluster = tracked_data_all_clusters_each_snap[i][m]["zcm"]
        rcm = np.sqrt(x_tracked_cluster**2+y_tracked_cluster**2)
        rcm_values.append(rcm)
        zcm_values.append(z_tracked_cluster)
#         ax2.scatter(np.array(rcm),np.array(z_tracked_cluster),c=snaps,cmap='Purples')
#         ax2.set_xlabel("rcm [kpc]")
#         ax2.set_ylabel("Z [kpc]")
#         ax2.set_aspect('equal')
# #         print(x_tracked_cluster)
#         print(rcm)
#         print(z_tracked_cluster)

#         #         ax2.legend()
#     plt.show()

# %%
fig = plt.figure()
ax = plt.gca()

ax.scatter(rcm_values,zcm_values,c=snaps,cmap ='gist_rainbow')
ax.text(4.3,-0.93,'snap 600')
ax.text(3.77 ,-1.104,'Snap 446')
ax.text(4.76,-0.74,'Snap 486')
ax.text(5.27,-0.93,'Snap 534')
ax.text(4.46,-1.12,'Snap 599')
ax.set_xlabel('Rcm [Kpc]')
ax.set_ylabel('Zcm [Kpc]')
ax.set_aspect('equal')

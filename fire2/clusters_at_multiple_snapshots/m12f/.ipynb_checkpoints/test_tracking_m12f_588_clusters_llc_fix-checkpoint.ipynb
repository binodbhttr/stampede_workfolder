# %%
#!/usr/bin/env python
# coding: utf-8

#this file will load snapshots and store details of the tracked star cluster thoroughout the snapshots into individual files available at ./data

import gizmo_analysis as gizmo
import utilities as ut
from matplotlib import pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
from sl_utilities import distinct_colours as dc
from sl_utilities import distance_functions
import os
import pickle

# %%
simname = 'm12f_res7100_mhdcv'
simdir = '/scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/'

# %%
snapshot_start=597
snapshot_end=600 #ran out of memory after 646


#Loading the sample cluster to be tracked and sorting its id and id_child
snapnumber=588 #Remember to change it if you  are changing the star cluster you are tracking in given snapshot

path="/home1/07428/binod/work2/data/m12f_588_clusters_tracked_data_b4n5_pkl/" #creating a path to store the data only if it does not exist
if not os.path.exists(path):
    os.makedirs(path)

###############################################
###############################################
#loading data of all clusters (id, id_children and all)

cluster_file_name="fire2_clusters_"+simname+"_snapshot_"+str(snapnumber)+"_b4n5.pkl" 
with open(path+cluster_file_name, "rb") as fp:
    import_cluster = pickle.load(fp)

'''
import_cluster is a dictionary which is a collection of dictionaries for each cluster.
It was exported as follows from the program that tracked the clusters.
Note keys might have changed. Make a test run by importing the pkl file that contains the cluster info. 

cluster1={"cluster_groupid":grpid1,"no_of_star":nstar1,"id":id1,"id_children":id_children1}
cluster2={"cluster_groupid":grpid2,"no_of_star":nstar2,"id":id2,"id_children":id_children2}
cluster3={"cluster_groupid":grpid3,"no_of_star":nstar3,"id":id3,"id_children":id_children3} and so on
export_cluster={1:cluster1,2:cluster2,3:cluster3,4:cluster4,5:cluster5,6:cluster6,7:cluster7,8:cluster8,9:cluster9,10:cluster10}
path="./"
file_name="clusters_"+simname+"_snapshot_"+str(snapshot) 
with open(path+file_name, 'wb') as output:
    pickle.dump(export_cluster, output)

#####3
To access id from say cluster 2, use import_cluster[2]["id"]
'''
################################################################
################################################################





################################################################
################################################################
###Now let's create a function for find the matching ids in the next snapshot using a function
def matchids(id_current,id_child_current,id_next,id_child_next,id_generation_next): #this function returns the index of the ids in the next snapshot that match with the current
    ind=np.array(0)
    for i in range(len(id_current)):
        match=np.where((id_next==id_current[i])&(id_child_next==id_child_current[i])&(id_generation_next<30)) #Also add id_generations<30
        print("\nFound the id",id_next[match],"at the index",match[0],"in this snapshot")
        ind=np.append(ind,match)
    ind_tracked_id_next=ind[1:len(ind)]  #The extra element in the beginning is removed by this process
    print("\nThese are the indices of the ids that matched in current snapshot\n",ind_tracked_id_next)
    return ind_tracked_id_next  
################################################################
################################################################


total_clusters=len(import_cluster)         #count the total no. of clusters we have in clusters file
total_snaps=snapshot_end-snapshot_start+1  #count the total no. of snapshots we are going to track
snap=snapshot_start                        #Mark the beginning of the snapshot
test_cluster=1                             #Mark the beginning of the cluster that we would be tracking
ind_tracked={}                             #finding the indices of the tracked stars in each snapshot for each cluster.

tracked_data_all_clusters_each_snap={}     #dictionary for storing data from all clusters and in each snapshot


#Algorithm followed for scanning each snapshot for all given star clusters is as follows
'''
Step1: Load the star clusters from the given file
Step2: snap=snapshot to begin with
Step3: Load id, id_child, id_genearation, age, mass, positoins, velocities and everything you want form the snapshot snap
Step4: Now assign test_cluster=1 which is the star cluster to begin with for tracking
Step5: Track the stars from the test_cluster using the id, id_child and id_generation
Step6: Get the information of the tracked stars id, id_child, id_genearation, age, mass, positoins, velocities and everything you want form the snapshot snap
        Save the information you gathered into a dictionary tracked_data_all_clusters
        test_cluster+=1
Step7: Is test_cluster<total_clusters? If yes goto step 5 else goto step 8
Step8: All clusters were tracked for the given snapshot
        Store the data gathered from all clusters in given snapshot to a dictionary tracked_data_all_clusters_each_snap
        It has the format {596:{1:{"x_tracked":[array],...},2:{"x_tracked":[array],...}},597:{1:{"x_tracked":[array],..},2:{"x_tracked":[array],..}..}}
        snap+=1
        Is snap<total_snaps? If yes goto step 3 else goto Step 9
Step9: End

'''




for i in range(total_snaps):               #we run a for loop until the end of all snapshots
    part=gizmo.io.Read.read_snapshots(['star'],'snapshot_index', snap, simulation_name=simname, simulation_directory=simdir, assign_hosts=True, assign_hosts_rotation=True)               #snap is the snapshot number here that changes everytime the loop iterates. It starts with sanpshot_start

    id=part['star'].prop('id')
    id_child=part['star'].prop('id.child')
    id_generation=part['star'].prop('id.generation')
    age=part['star'].prop('age')
    x=part['star'].prop('host.distance.principal')[:,0] #x component of the position of all stars 
    y=part['star'].prop('host.distance.principal')[:,1] #y component of the position of all stars
    z=part['star'].prop('host.distance.principal')[:,2] #z component of the position of all stars
    n=len(x) # counting the total no. of star particles
    vx=part['star'].prop('host.velocity.principal')[:,0]
    vy=part['star'].prop('host.velocity.principal')[:,1]
    vz=part['star'].prop('host.velocity.principal')[:,2]
    mass=part['star']['mass'] #mass of all stars in snapshot 691
    # compute 3-D velocity in cylindrical coordinates
    # first value is along the major axes (positive definite)
    # secod value is azimuthal velocity in the plane of the disk (positive definite)
    # third value is vertical velocity wrt the disk (signed)
    vR_cyl=part['star'].prop('host.velocity.principal.cylindrical')[:,0]
    vphi_cyl=part['star'].prop('host.velocity.principal.cylindrical')[:,1]
    vz_cyl=part['star'].prop('host.velocity.principal.cylindrical')[:,2]
    print("\n#########\n############\nLoaded id,id_child,age,x,y,z,vx,vy,vz,mass, cylindrical velocities and number of particles for snapshot no.",snap)
    print("Total no of particles in this shapshot no.",snap,"is",n)





    ################################################################
    ################################################################
    ### Now matching the IDs of this snapshot with the ids of all clusters
    test_cluster=1                       #This is the test cluster to begin with. It resets to 1 at each snapshot 
    tracked_data_all_clusters={}         #This dictionary keeps the tracked information for all star clusters in given snapshot. It also resets with snapshots.
    for j in range(total_clusters):
        tracked_data={}                    #This dictionary holds the tracked information for a cluster temporarily until it is pushed to tracked_data_all_clusters
        print("\n\nNow Matching the ids of the snapshot",snap," with the cluster group id",test_cluster)
        id_test_cluster=import_cluster[test_cluster]["id"]
        id_child_test_cluster=import_cluster[test_cluster]["id_children"]
        sortind=np.argsort(id_test_cluster)
        id_test_cluster_sorted=id_test_cluster[sortind]
        id_child_test_cluster_sorted=id_child_test_cluster[sortind]
        print("The total no. of stars in cluster id ",test_cluster," is",len(id_test_cluster_sorted))
        print("Sorted ids of this cluster is",id_test_cluster_sorted)
        ind_tracked=matchids(id_test_cluster_sorted,id_child_test_cluster_sorted,id,id_child,id_generation)

        ################################################################
        ################################################################
        #Now finding the postion, velocities, age and mass of the tracked stars in each snapshots
        age_tracked=age[ind_tracked]
        x_tracked=x[ind_tracked]
        y_tracked=y[ind_tracked]
        z_tracked=z[ind_tracked]
        vx_tracked=vx[ind_tracked]
        vy_tracked=vy[ind_tracked]
        vz_tracked=vz[ind_tracked]
        mass_tracked=mass[ind_tracked]
        vR_cyl_tracked=vR_cyl[ind_tracked]
        vphi_cyl_tracked=vphi_cyl[ind_tracked]
        vz_cyl_tracked=vz_cyl[ind_tracked]


        ################################################################
        ################################################################
        #Now calculating center of mass and realted properties  
        xcm=distance_functions.cm(x_tracked,mass_tracked)
        ycm=distance_functions.cm(y_tracked,mass_tracked)
        zcm=distance_functions.cm(z_tracked,mass_tracked)
        delta_rxyz=distance_functions.dr(x_tracked,y_tracked,z_tracked,mass_tracked)
        rmax=distance_functions.drmax(x_tracked,y_tracked,z_tracked,mass_tracked)
        ymax=(ycm+1.1*rmax)
        ymin=(ycm-1.1*rmax)
        xmax=(xcm+1.1*rmax)
        xmin=(xcm-1.1*rmax)
        avg_delta_rxyz=np.mean(np.absolute(delta_rxyz))


        ################################################################
        ################################################################
        #Now lets write our tracked data from each snapshots to a file
        tracked_data={"ind_tracked":ind_tracked,"age_tracked":age_tracked,"x_tracked":x_tracked,"y_tracked":y_tracked,"z_tracked":z_tracked,
        "vx_tracked":vx_tracked,"vy_tracked":vy_tracked,"vz_tracked":vz_tracked,
        "mass_tracked":mass_tracked,"xcm":xcm,"ycm":ycm,"zcm":zcm,"delta_rxyz":delta_rxyz,"rmax":rmax,
        "ymax":ymax,"ymin":ymin,"xmax":xmax,"xmin":xmin,"avg_delta_rxyz":avg_delta_rxyz,
        "vR_cyl_tracked":vR_cyl_tracked,"vphi_cyl_tracked":vphi_cyl_tracked,"vz_cyl_tracked":vz_cyl_tracked}


        tracked_data_all_clusters.update({test_cluster:tracked_data}) #access it using tracked_data_all_clusters[clusterid]["key"]
        test_cluster+=1

        #We have collected all tracked information for our test clusters for one snapshot now which is in dictionary tracked_data_all_clusters.
        #We would store that dictionary in a pickle file as a backup data from each snapshot about or all star cluster.
        ###Now moving out of the j loop. We scanned all clusters and stored the tracked data into a dictionary tracked_data_all_clusters  
    file_name="tracked_clusters_at_snapshot_"+str(snap)+".pkl"
    with open(path+file_name, 'wb') as output:
        pickle.dump(tracked_data_all_clusters, output)
    print("\n Stored tracked data of all stars clusters in the snapshot no.",snap,"to filename:",file_name,"\n#####\n")
    #Note we are still in i loop which is scanning each snapshot !!!!!!!!!!!!!!!!!!
    tracked_data_all_clusters_each_snap.update({snap:tracked_data_all_clusters}) 
    snap=snap+1

    #Came out of i loop 
  
#Finally we scanned through all the snapshots and now we come out of the loop to store the final file that contains all the tracked information of all clusters 
#Now we store the tracked data of all clusters into a dictionary with snapshot number as the key. This would be our final dictionary of dictinaries. 
with open(path+"total_data_tracked_clusters_all_snapshots.pkl", 'wb') as output:
    pickle.dump(tracked_data_all_clusters_each_snap, output) #access the data using tracked_data_all_clusters_each_snap[snapshot][cluster_id]["x_tracked"])
  
#Expected Result: tracked_data_all_clusters_each_snap={596:{1:tracked_data,2:tracked_data..},597:{1:tracked_data,2:tracked_data..upto total clusters},598....     upto total snapshots}
# Out:
# # in utilities.simulation.Snapshot():
# * reading:  scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/snapshot_times.txt
#
#   using snapshot index = 597, redshift = 0.007
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/output/snapshot_597.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 81363848 particles
#     dark2     (id = 2): 7086235 particles
#     gas       (id = 0): 64166200 particles
#     star      (id = 4): 17784971 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['star']
# * reading particles from:
#     scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/output/snapshot_597.hdf5
#
# * reading cosmological parameters from:  scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
# ! warning: star id.child [min, max] = [0.000, 4.254e9]
# ! warning: star mass [min, med, max] = [3245.210, 5412.012, 1.375e5]
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/track/host_coordinates.hdf5
#   host1 position = (38723.84, 47658.03, 46754.42) [kpc comoving]
#   host1 velocity = (-157.8, 165.8, 106.8) [km / s]
#   host1 axis ratios = (0.18, 0.19, 0.95)
#   host1 R_90 = 12.1 kpc
#   host1 M_90 = 7.5e+10 Msun
#
#
# #########
# ############
# Loaded id,id_child,age,x,y,z,vx,vy,vz,mass, cylindrical velocities and number of particles for snapshot no. 597
# Total no of particles in this shapshot no. 597 is 17784971
#
#
# Now Matching the ids of the snapshot 597  with the cluster group id 1
# The total no. of stars in cluster id  1  is 9
# Sorted ids of this cluster is [12233101 15939420 16676135 21789997 35600867 36199746 38743397 52460765
#  79474586]
#
# Found the id [12233101] at the index [438065] in this snapshot
#
# Found the id [15939420] at the index [438060] in this snapshot
#
# Found the id [16676135] at the index [438027] in this snapshot
#
# Found the id [21789997] at the index [438231] in this snapshot
#
# Found the id [35600867] at the index [438025] in this snapshot
#
# Found the id [36199746] at the index [438026] in this snapshot
#
# Found the id [38743397] at the index [438066] in this snapshot
#
# Found the id [52460765] at the index [438070] in this snapshot
#
# Found the id [79474586] at the index [438067] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [438065 438060 438027 438231 438025 438026 438066 438070 438067]
#
#
# Now Matching the ids of the snapshot 597  with the cluster group id 2
# The total no. of stars in cluster id  2  is 8
# Sorted ids of this cluster is [ 6288525 13442273 15683027 23830710 35882027 44637212 47692615 55510626]
#
# Found the id [6288525] at the index [10072272] in this snapshot
#
# Found the id [13442273] at the index [10072275] in this snapshot
#
# Found the id [15683027] at the index [10072278] in this snapshot
#
# Found the id [23830710] at the index [10072277] in this snapshot
#
# Found the id [35882027] at the index [10072280] in this snapshot
#
# Found the id [44637212] at the index [10072274] in this snapshot
#
# Found the id [47692615] at the index [10072273] in this snapshot
#
# Found the id [55510626] at the index [10072276] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [10072272 10072275 10072278 10072277 10072280 10072274 10072273 10072276]
#
#
# Now Matching the ids of the snapshot 597  with the cluster group id 3
# The total no. of stars in cluster id  3  is 7
# Sorted ids of this cluster is [ 6522694  9082875 17946997 19734054 29732816 40989092 57694150]
#
# Found the id [6522694] at the index [16458677] in this snapshot
#
# Found the id [9082875] at the index [16458678] in this snapshot
#
# Found the id [17946997] at the index [16458713] in this snapshot
#
# Found the id [19734054] at the index [16458699] in this snapshot
#
# Found the id [29732816] at the index [16458712] in this snapshot
#
# Found the id [40989092] at the index [16458714] in this snapshot
#
# Found the id [57694150] at the index [16458676] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [16458677 16458678 16458713 16458699 16458712 16458714 16458676]
#
#
# Now Matching the ids of the snapshot 597  with the cluster group id 4
# The total no. of stars in cluster id  4  is 7
# Sorted ids of this cluster is [31895283 48004469 51588915 60048561 63871484 68625169 74584151]
#
# Found the id [31895283] at the index [5298791] in this snapshot
#
# Found the id [48004469] at the index [5298794] in this snapshot
#
# Found the id [51588915] at the index [5298790] in this snapshot
#
# Found the id [60048561] at the index [5298789] in this snapshot
#
# Found the id [63871484] at the index [5298793] in this snapshot
#
# Found the id [68625169] at the index [5298792] in this snapshot
#
# Found the id [74584151] at the index [5298795] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [5298791 5298794 5298790 5298789 5298793 5298792 5298795]
#
#
# Now Matching the ids of the snapshot 597  with the cluster group id 5
# The total no. of stars in cluster id  5  is 7
# Sorted ids of this cluster is [17432067 18309009 43044321 46292834 54644758 60039322 79765310]
#
# Found the id [17432067] at the index [11075629] in this snapshot
#
# Found the id [18309009] at the index [11075623] in this snapshot
#
# Found the id [43044321] at the index [11075627] in this snapshot
#
# Found the id [46292834] at the index [11075633] in this snapshot
#
# Found the id [54644758] at the index [11075624] in this snapshot
#
# Found the id [60039322] at the index [11075618] in this snapshot
#
# Found the id [79765310] at the index [11075628] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [11075629 11075623 11075627 11075633 11075624 11075618 11075628]
#
#
# Now Matching the ids of the snapshot 597  with the cluster group id 6
# The total no. of stars in cluster id  6  is 7
# Sorted ids of this cluster is [14946122 17736446 19224491 24150783 42481897 43565926 45006599]
#
# Found the id [14946122] at the index [142555] in this snapshot
#
# Found the id [17736446] at the index [1206768] in this snapshot
#
# Found the id [19224491] at the index [142558] in this snapshot
#
# Found the id [24150783] at the index [142620] in this snapshot
#
# Found the id [42481897] at the index [1206769] in this snapshot
#
# Found the id [43565926] at the index [142617] in this snapshot
#
# Found the id [45006599] at the index [142556] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [ 142555 1206768  142558  142620 1206769  142617  142556]
#
#
# Now Matching the ids of the snapshot 597  with the cluster group id 7
# The total no. of stars in cluster id  7  is 6
# Sorted ids of this cluster is [26799622 31366904 33517759 43344184 59273944 66179841]
#
# Found the id [26799622] at the index [5487250] in this snapshot
#
# Found the id [31366904] at the index [5487258] in this snapshot
#
# Found the id [33517759] at the index [5487252] in this snapshot
#
# Found the id [43344184] at the index [5487251] in this snapshot
#
# Found the id [59273944] at the index [5487262] in this snapshot
#
# Found the id [66179841] at the index [5487246] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [5487250 5487258 5487252 5487251 5487262 5487246]
#
#
# Now Matching the ids of the snapshot 597  with the cluster group id 8
# The total no. of stars in cluster id  8  is 6
# Sorted ids of this cluster is [ 8078634 30501388 37124620 59473105 63656844 73852946]
#
# Found the id [8078634] at the index [6202022] in this snapshot
#
# Found the id [30501388] at the index [1523417] in this snapshot
#
# Found the id [37124620] at the index [1523418] in this snapshot
#
# Found the id [59473105] at the index [6202021] in this snapshot
#
# Found the id [63656844] at the index [6202030] in this snapshot
#
# Found the id [73852946] at the index [6202018] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [6202022 1523417 1523418 6202021 6202030 6202018]
#
#
# Now Matching the ids of the snapshot 597  with the cluster group id 9
# The total no. of stars in cluster id  9  is 5
# Sorted ids of this cluster is [22688626 25015777 32104848 55232462 65198437]
#
# Found the id [22688626] at the index [4267749] in this snapshot
#
# Found the id [25015777] at the index [4267746] in this snapshot
#
# Found the id [32104848] at the index [4267748] in this snapshot
#
# Found the id [55232462] at the index [4267750] in this snapshot
#
# Found the id [65198437] at the index [4267747] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [4267749 4267746 4267748 4267750 4267747]
#
#
# Now Matching the ids of the snapshot 597  with the cluster group id 10
# The total no. of stars in cluster id  10  is 5
# Sorted ids of this cluster is [ 9748455  9749625 13096782 20388585 35390117]
#
# Found the id [9748455] at the index [828143] in this snapshot
#
# Found the id [9749625] at the index [828153] in this snapshot
#
# Found the id [13096782] at the index [828152] in this snapshot
#
# Found the id [20388585] at the index [828154] in this snapshot
#
# Found the id [35390117] at the index [828149] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [828143 828153 828152 828154 828149]
#
#
# Now Matching the ids of the snapshot 597  with the cluster group id 11
# The total no. of stars in cluster id  11  is 5
# Sorted ids of this cluster is [11552938 18551404 23608604 36698843 68738504]
#
# Found the id [11552938] at the index [2389721] in this snapshot
#
# Found the id [18551404] at the index [2389873] in this snapshot
#
# Found the id [23608604] at the index [2389722] in this snapshot
#
# Found the id [36698843] at the index [2389719] in this snapshot
#
# Found the id [68738504] at the index [2389724] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [2389721 2389873 2389722 2389719 2389724]
#
#
# Now Matching the ids of the snapshot 597  with the cluster group id 12
# The total no. of stars in cluster id  12  is 5
# Sorted ids of this cluster is [11705068 36488475 39925280 40237329 71222733]
#
# Found the id [11705068] at the index [1084667] in this snapshot
#
# Found the id [36488475] at the index [1085792] in this snapshot
#
# Found the id [39925280] at the index [1084665] in this snapshot
#
# Found the id [40237329] at the index [1084669] in this snapshot
#
# Found the id [71222733] at the index [1084666] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [1084667 1085792 1084665 1084669 1084666]
#
#
# Now Matching the ids of the snapshot 597  with the cluster group id 13
# The total no. of stars in cluster id  13  is 5
# Sorted ids of this cluster is [27767024 59622229 62412117 69193608 75470406]
#
# Found the id [27767024] at the index [16581053] in this snapshot
#
# Found the id [59622229] at the index [16581051] in this snapshot
#
# Found the id [62412117] at the index [16581050] in this snapshot
#
# Found the id [69193608] at the index [16581032] in this snapshot
#
# Found the id [75470406] at the index [16581052] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [16581053 16581051 16581050 16581032 16581052]
#
#
# Now Matching the ids of the snapshot 597  with the cluster group id 14
# The total no. of stars in cluster id  14  is 5
# Sorted ids of this cluster is [ 9910784 31078456 35148679 54122687 67035242]
#
# Found the id [9910784] at the index [12040502] in this snapshot
#
# Found the id [31078456] at the index [12040504] in this snapshot
#
# Found the id [35148679] at the index [12040483] in this snapshot
#
# Found the id [54122687] at the index [12040484] in this snapshot
#
# Found the id [67035242] at the index [12040485] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [12040502 12040504 12040483 12040484 12040485]
#
#  Stored tracked data of all stars clusters in the snapshot no. 597 to filename: tracked_clusters_at_snapshot_597.pkl
# #####
#
#
# # in utilities.simulation.Snapshot():
# * reading:  scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/snapshot_times.txt
#
#   using snapshot index = 598, redshift = 0.007
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/output/snapshot_598.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 81363848 particles
#     dark2     (id = 2): 7086235 particles
#     gas       (id = 0): 64165126 particles
#     star      (id = 4): 17786045 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['star']
# * reading particles from:
#     scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/output/snapshot_598.hdf5
#
# * reading cosmological parameters from:  scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
# ! warning: star id.child [min, max] = [0.000, 4.254e9]
# ! warning: star mass [min, med, max] = [3245.210, 5412.011, 1.375e5]
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/track/host_coordinates.hdf5
#   host1 position = (38723.68, 47658.20, 46754.54) [kpc comoving]
#   host1 velocity = (-157.9, 165.8, 106.7) [km / s]
#   host1 axis ratios = (0.18, 0.19, 0.96)
#   host1 R_90 = 12.1 kpc
#   host1 M_90 = 7.5e+10 Msun
#
#
# #########
# ############
# Loaded id,id_child,age,x,y,z,vx,vy,vz,mass, cylindrical velocities and number of particles for snapshot no. 598
# Total no of particles in this shapshot no. 598 is 17786045
#
#
# Now Matching the ids of the snapshot 598  with the cluster group id 1
# The total no. of stars in cluster id  1  is 9
# Sorted ids of this cluster is [12233101 15939420 16676135 21789997 35600867 36199746 38743397 52460765
#  79474586]
#
# Found the id [12233101] at the index [9023195] in this snapshot
#
# Found the id [15939420] at the index [9023197] in this snapshot
#
# Found the id [16676135] at the index [9185426] in this snapshot
#
# Found the id [21789997] at the index [9023187] in this snapshot
#
# Found the id [35600867] at the index [9185424] in this snapshot
#
# Found the id [36199746] at the index [9185425] in this snapshot
#
# Found the id [38743397] at the index [9023194] in this snapshot
#
# Found the id [52460765] at the index [9023200] in this snapshot
#
# Found the id [79474586] at the index [9023198] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [9023195 9023197 9185426 9023187 9185424 9185425 9023194 9023200 9023198]
#
#
# Now Matching the ids of the snapshot 598  with the cluster group id 2
# The total no. of stars in cluster id  2  is 8
# Sorted ids of this cluster is [ 6288525 13442273 15683027 23830710 35882027 44637212 47692615 55510626]
#
# Found the id [6288525] at the index [10226146] in this snapshot
#
# Found the id [13442273] at the index [10226148] in this snapshot
#
# Found the id [15683027] at the index [10226149] in this snapshot
#
# Found the id [23830710] at the index [10226145] in this snapshot
#
# Found the id [35882027] at the index [10226137] in this snapshot
#
# Found the id [44637212] at the index [10226147] in this snapshot
#
# Found the id [47692615] at the index [10226144] in this snapshot
#
# Found the id [55510626] at the index [10226150] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [10226146 10226148 10226149 10226145 10226137 10226147 10226144 10226150]
#
#
# Now Matching the ids of the snapshot 598  with the cluster group id 3
# The total no. of stars in cluster id  3  is 7
# Sorted ids of this cluster is [ 6522694  9082875 17946997 19734054 29732816 40989092 57694150]
#
# Found the id [6522694] at the index [16369379] in this snapshot
#
# Found the id [9082875] at the index [16369380] in this snapshot
#
# Found the id [17946997] at the index [16369395] in this snapshot
#
# Found the id [19734054] at the index [16369398] in this snapshot
#
# Found the id [29732816] at the index [16369396] in this snapshot
#
# Found the id [40989092] at the index [16369394] in this snapshot
#
# Found the id [57694150] at the index [16369382] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [16369379 16369380 16369395 16369398 16369396 16369394 16369382]
#
#
# Now Matching the ids of the snapshot 598  with the cluster group id 4
# The total no. of stars in cluster id  4  is 7
# Sorted ids of this cluster is [31895283 48004469 51588915 60048561 63871484 68625169 74584151]
#
# Found the id [31895283] at the index [15981560] in this snapshot
#
# Found the id [48004469] at the index [15981558] in this snapshot
#
# Found the id [51588915] at the index [15981557] in this snapshot
#
# Found the id [60048561] at the index [15981556] in this snapshot
#
# Found the id [63871484] at the index [15981559] in this snapshot
#
# Found the id [68625169] at the index [15981555] in this snapshot
#
# Found the id [74584151] at the index [15981561] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [15981560 15981558 15981557 15981556 15981559 15981555 15981561]
#
#
# Now Matching the ids of the snapshot 598  with the cluster group id 5
# The total no. of stars in cluster id  5  is 7
# Sorted ids of this cluster is [17432067 18309009 43044321 46292834 54644758 60039322 79765310]
#
# Found the id [17432067] at the index [10106069] in this snapshot
#
# Found the id [18309009] at the index [10106092] in this snapshot
#
# Found the id [43044321] at the index [10106070] in this snapshot
#
# Found the id [46292834] at the index [10106091] in this snapshot
#
# Found the id [54644758] at the index [10106066] in this snapshot
#
# Found the id [60039322] at the index [10106063] in this snapshot
#
# Found the id [79765310] at the index [10106068] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [10106069 10106092 10106070 10106091 10106066 10106063 10106068]
#
#
# Now Matching the ids of the snapshot 598  with the cluster group id 6
# The total no. of stars in cluster id  6  is 7
# Sorted ids of this cluster is [14946122 17736446 19224491 24150783 42481897 43565926 45006599]
#
# Found the id [14946122] at the index [2953537] in this snapshot
#
# Found the id [17736446] at the index [5806948] in this snapshot
#
# Found the id [19224491] at the index [5806944] in this snapshot
#
# Found the id [24150783] at the index [2953578] in this snapshot
#
# Found the id [42481897] at the index [5806947] in this snapshot
#
# Found the id [43565926] at the index [2953579] in this snapshot
#
# Found the id [45006599] at the index [2953538] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [2953537 5806948 5806944 2953578 5806947 2953579 2953538]
#
#
# Now Matching the ids of the snapshot 598  with the cluster group id 7
# The total no. of stars in cluster id  7  is 6
# Sorted ids of this cluster is [26799622 31366904 33517759 43344184 59273944 66179841]
#
# Found the id [26799622] at the index [3185466] in this snapshot
#
# Found the id [31366904] at the index [3185448] in this snapshot
#
# Found the id [33517759] at the index [3185469] in this snapshot
#
# Found the id [43344184] at the index [3185467] in this snapshot
#
# Found the id [59273944] at the index [10349100] in this snapshot
#
# Found the id [66179841] at the index [3185465] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [ 3185466  3185448  3185469  3185467 10349100  3185465]
#
#
# Now Matching the ids of the snapshot 598  with the cluster group id 8
# The total no. of stars in cluster id  8  is 6
# Sorted ids of this cluster is [ 8078634 30501388 37124620 59473105 63656844 73852946]
#
# Found the id [8078634] at the index [1405528] in this snapshot
#
# Found the id [30501388] at the index [1405534] in this snapshot
#
# Found the id [37124620] at the index [1405535] in this snapshot
#
# Found the id [59473105] at the index [1405533] in this snapshot
#
# Found the id [63656844] at the index [1405532] in this snapshot
#
# Found the id [73852946] at the index [1405513] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [1405528 1405534 1405535 1405533 1405532 1405513]
#
#
# Now Matching the ids of the snapshot 598  with the cluster group id 9
# The total no. of stars in cluster id  9  is 5
# Sorted ids of this cluster is [22688626 25015777 32104848 55232462 65198437]
#
# Found the id [22688626] at the index [12361166] in this snapshot
#
# Found the id [25015777] at the index [12361165] in this snapshot
#
# Found the id [32104848] at the index [12361167] in this snapshot
#
# Found the id [55232462] at the index [12361162] in this snapshot
#
# Found the id [65198437] at the index [12361168] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [12361166 12361165 12361167 12361162 12361168]
#
#
# Now Matching the ids of the snapshot 598  with the cluster group id 10
# The total no. of stars in cluster id  10  is 5
# Sorted ids of this cluster is [ 9748455  9749625 13096782 20388585 35390117]
#
# Found the id [9748455] at the index [15964751] in this snapshot
#
# Found the id [9749625] at the index [15964866] in this snapshot
#
# Found the id [13096782] at the index [15964752] in this snapshot
#
# Found the id [20388585] at the index [15964750] in this snapshot
#
# Found the id [35390117] at the index [15964756] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [15964751 15964866 15964752 15964750 15964756]
#
#
# Now Matching the ids of the snapshot 598  with the cluster group id 11
# The total no. of stars in cluster id  11  is 5
# Sorted ids of this cluster is [11552938 18551404 23608604 36698843 68738504]
#
# Found the id [11552938] at the index [8515613] in this snapshot
#
# Found the id [18551404] at the index [8515614] in this snapshot
#
# Found the id [23608604] at the index [8515615] in this snapshot
#
# Found the id [36698843] at the index [8515617] in this snapshot
#
# Found the id [68738504] at the index [8515616] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [8515613 8515614 8515615 8515617 8515616]
#
#
# Now Matching the ids of the snapshot 598  with the cluster group id 12
# The total no. of stars in cluster id  12  is 5
# Sorted ids of this cluster is [11705068 36488475 39925280 40237329 71222733]
#
# Found the id [11705068] at the index [3814376] in this snapshot
#
# Found the id [36488475] at the index [3814384] in this snapshot
#
# Found the id [39925280] at the index [3814375] in this snapshot
#
# Found the id [40237329] at the index [3814374] in this snapshot
#
# Found the id [71222733] at the index [3814377] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [3814376 3814384 3814375 3814374 3814377]
#
#
# Now Matching the ids of the snapshot 598  with the cluster group id 13
# The total no. of stars in cluster id  13  is 5
# Sorted ids of this cluster is [27767024 59622229 62412117 69193608 75470406]
#
# Found the id [27767024] at the index [648946] in this snapshot
#
# Found the id [59622229] at the index [648942] in this snapshot
#
# Found the id [62412117] at the index [648943] in this snapshot
#
# Found the id [69193608] at the index [648948] in this snapshot
#
# Found the id [75470406] at the index [648949] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [648946 648942 648943 648948 648949]
#
#
# Now Matching the ids of the snapshot 598  with the cluster group id 14
# The total no. of stars in cluster id  14  is 5
# Sorted ids of this cluster is [ 9910784 31078456 35148679 54122687 67035242]
#
# Found the id [9910784] at the index [15335986] in this snapshot
#
# Found the id [31078456] at the index [15335985] in this snapshot
#
# Found the id [35148679] at the index [15335989] in this snapshot
#
# Found the id [54122687] at the index [15335992] in this snapshot
#
# Found the id [67035242] at the index [15335991] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [15335986 15335985 15335989 15335992 15335991]
#
#  Stored tracked data of all stars clusters in the snapshot no. 598 to filename: tracked_clusters_at_snapshot_598.pkl
# #####
#
#
# # in utilities.simulation.Snapshot():
# * reading:  scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/snapshot_times.txt
#
#   using snapshot index = 599, redshift = 0.007
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/output/snapshot_599.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 81363848 particles
#     dark2     (id = 2): 7086235 particles
#     gas       (id = 0): 64164017 particles
#     star      (id = 4): 17787154 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['star']
# * reading particles from:
#     scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/output/snapshot_599.hdf5
#
# * reading cosmological parameters from:  scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
# ! warning: star id.child [min, max] = [0.000, 4.254e9]
# ! warning: star mass [min, med, max] = [3245.210, 5412.010, 1.375e5]
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/track/host_coordinates.hdf5
#   host1 position = (38723.50, 47658.37, 46754.65) [kpc comoving]
#   host1 velocity = (-157.9, 165.7, 106.6) [km / s]
#   host1 axis ratios = (0.18, 0.19, 0.96)
#   host1 R_90 = 12.1 kpc
#   host1 M_90 = 7.5e+10 Msun
#
#
# #########
# ############
# Loaded id,id_child,age,x,y,z,vx,vy,vz,mass, cylindrical velocities and number of particles for snapshot no. 599
# Total no of particles in this shapshot no. 599 is 17787154
#
#
# Now Matching the ids of the snapshot 599  with the cluster group id 1
# The total no. of stars in cluster id  1  is 9
# Sorted ids of this cluster is [12233101 15939420 16676135 21789997 35600867 36199746 38743397 52460765
#  79474586]
#
# Found the id [12233101] at the index [11728422] in this snapshot
#
# Found the id [15939420] at the index [11728420] in this snapshot
#
# Found the id [16676135] at the index [7613119] in this snapshot
#
# Found the id [21789997] at the index [11728413] in this snapshot
#
# Found the id [35600867] at the index [7613117] in this snapshot
#
# Found the id [36199746] at the index [7613118] in this snapshot
#
# Found the id [38743397] at the index [11728418] in this snapshot
#
# Found the id [52460765] at the index [11728417] in this snapshot
#
# Found the id [79474586] at the index [11728421] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [11728422 11728420  7613119 11728413  7613117  7613118 11728418 11728417
#  11728421]
#
#
# Now Matching the ids of the snapshot 599  with the cluster group id 2
# The total no. of stars in cluster id  2  is 8
# Sorted ids of this cluster is [ 6288525 13442273 15683027 23830710 35882027 44637212 47692615 55510626]
#
# Found the id [6288525] at the index [813805] in this snapshot
#
# Found the id [13442273] at the index [813806] in this snapshot
#
# Found the id [15683027] at the index [813809] in this snapshot
#
# Found the id [23830710] at the index [813811] in this snapshot
#
# Found the id [35882027] at the index [813800] in this snapshot
#
# Found the id [44637212] at the index [813807] in this snapshot
#
# Found the id [47692615] at the index [813808] in this snapshot
#
# Found the id [55510626] at the index [813810] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [813805 813806 813809 813811 813800 813807 813808 813810]
#
#
# Now Matching the ids of the snapshot 599  with the cluster group id 3
# The total no. of stars in cluster id  3  is 7
# Sorted ids of this cluster is [ 6522694  9082875 17946997 19734054 29732816 40989092 57694150]
#
# Found the id [6522694] at the index [137548] in this snapshot
#
# Found the id [9082875] at the index [137547] in this snapshot
#
# Found the id [17946997] at the index [137537] in this snapshot
#
# Found the id [19734054] at the index [137535] in this snapshot
#
# Found the id [29732816] at the index [137538] in this snapshot
#
# Found the id [40989092] at the index [137539] in this snapshot
#
# Found the id [57694150] at the index [137549] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [137548 137547 137537 137535 137538 137539 137549]
#
#
# Now Matching the ids of the snapshot 599  with the cluster group id 4
# The total no. of stars in cluster id  4  is 7
# Sorted ids of this cluster is [31895283 48004469 51588915 60048561 63871484 68625169 74584151]
#
# Found the id [31895283] at the index [5438773] in this snapshot
#
# Found the id [48004469] at the index [5438774] in this snapshot
#
# Found the id [51588915] at the index [5438776] in this snapshot
#
# Found the id [60048561] at the index [5438777] in this snapshot
#
# Found the id [63871484] at the index [5438775] in this snapshot
#
# Found the id [68625169] at the index [5438772] in this snapshot
#
# Found the id [74584151] at the index [5438780] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [5438773 5438774 5438776 5438777 5438775 5438772 5438780]
#
#
# Now Matching the ids of the snapshot 599  with the cluster group id 5
# The total no. of stars in cluster id  5  is 7
# Sorted ids of this cluster is [17432067 18309009 43044321 46292834 54644758 60039322 79765310]
#
# Found the id [17432067] at the index [11400734] in this snapshot
#
# Found the id [18309009] at the index [11400730] in this snapshot
#
# Found the id [43044321] at the index [11400726] in this snapshot
#
# Found the id [46292834] at the index [11400733] in this snapshot
#
# Found the id [54644758] at the index [11400732] in this snapshot
#
# Found the id [60039322] at the index [11400737] in this snapshot
#
# Found the id [79765310] at the index [11400727] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [11400734 11400730 11400726 11400733 11400732 11400737 11400727]
#
#
# Now Matching the ids of the snapshot 599  with the cluster group id 6
# The total no. of stars in cluster id  6  is 7
# Sorted ids of this cluster is [14946122 17736446 19224491 24150783 42481897 43565926 45006599]
#
# Found the id [14946122] at the index [4876273] in this snapshot
#
# Found the id [17736446] at the index [4876270] in this snapshot
#
# Found the id [19224491] at the index [4876271] in this snapshot
#
# Found the id [24150783] at the index [4876283] in this snapshot
#
# Found the id [42481897] at the index [4876268] in this snapshot
#
# Found the id [43565926] at the index [4876282] in this snapshot
#
# Found the id [45006599] at the index [4876272] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [4876273 4876270 4876271 4876283 4876268 4876282 4876272]
#
#
# Now Matching the ids of the snapshot 599  with the cluster group id 7
# The total no. of stars in cluster id  7  is 6
# Sorted ids of this cluster is [26799622 31366904 33517759 43344184 59273944 66179841]
#
# Found the id [26799622] at the index [16875284] in this snapshot
#
# Found the id [31366904] at the index [16875282] in this snapshot
#
# Found the id [33517759] at the index [16875285] in this snapshot
#
# Found the id [43344184] at the index [16875286] in this snapshot
#
# Found the id [59273944] at the index [16874920] in this snapshot
#
# Found the id [66179841] at the index [16875283] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [16875284 16875282 16875285 16875286 16874920 16875283]
#
#
# Now Matching the ids of the snapshot 599  with the cluster group id 8
# The total no. of stars in cluster id  8  is 6
# Sorted ids of this cluster is [ 8078634 30501388 37124620 59473105 63656844 73852946]
#
# Found the id [8078634] at the index [14817611] in this snapshot
#
# Found the id [30501388] at the index [14817612] in this snapshot
#
# Found the id [37124620] at the index [14817610] in this snapshot
#
# Found the id [59473105] at the index [14817613] in this snapshot
#
# Found the id [63656844] at the index [14817609] in this snapshot
#
# Found the id [73852946] at the index [14817617] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [14817611 14817612 14817610 14817613 14817609 14817617]
#
#
# Now Matching the ids of the snapshot 599  with the cluster group id 9
# The total no. of stars in cluster id  9  is 5
# Sorted ids of this cluster is [22688626 25015777 32104848 55232462 65198437]
#
# Found the id [22688626] at the index [7242608] in this snapshot
#
# Found the id [25015777] at the index [7242607] in this snapshot
#
# Found the id [32104848] at the index [7242606] in this snapshot
#
# Found the id [55232462] at the index [7242604] in this snapshot
#
# Found the id [65198437] at the index [7242605] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [7242608 7242607 7242606 7242604 7242605]
#
#
# Now Matching the ids of the snapshot 599  with the cluster group id 10
# The total no. of stars in cluster id  10  is 5
# Sorted ids of this cluster is [ 9748455  9749625 13096782 20388585 35390117]
#
# Found the id [9748455] at the index [583659] in this snapshot
#
# Found the id [9749625] at the index [583668] in this snapshot
#
# Found the id [13096782] at the index [583660] in this snapshot
#
# Found the id [20388585] at the index [583662] in this snapshot
#
# Found the id [35390117] at the index [583661] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [583659 583668 583660 583662 583661]
#
#
# Now Matching the ids of the snapshot 599  with the cluster group id 11
# The total no. of stars in cluster id  11  is 5
# Sorted ids of this cluster is [11552938 18551404 23608604 36698843 68738504]
#
# Found the id [11552938] at the index [5868957] in this snapshot
#
# Found the id [18551404] at the index [5868954] in this snapshot
#
# Found the id [23608604] at the index [5868952] in this snapshot
#
# Found the id [36698843] at the index [5868950] in this snapshot
#
# Found the id [68738504] at the index [5868951] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [5868957 5868954 5868952 5868950 5868951]
#
#
# Now Matching the ids of the snapshot 599  with the cluster group id 12
# The total no. of stars in cluster id  12  is 5
# Sorted ids of this cluster is [11705068 36488475 39925280 40237329 71222733]
#
# Found the id [11705068] at the index [9962704] in this snapshot
#
# Found the id [36488475] at the index [9962607] in this snapshot
#
# Found the id [39925280] at the index [9962701] in this snapshot
#
# Found the id [40237329] at the index [9962702] in this snapshot
#
# Found the id [71222733] at the index [9962705] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [9962704 9962607 9962701 9962702 9962705]
#
#
# Now Matching the ids of the snapshot 599  with the cluster group id 13
# The total no. of stars in cluster id  13  is 5
# Sorted ids of this cluster is [27767024 59622229 62412117 69193608 75470406]
#
# Found the id [27767024] at the index [12047626] in this snapshot
#
# Found the id [59622229] at the index [12047627] in this snapshot
#
# Found the id [62412117] at the index [12047624] in this snapshot
#
# Found the id [69193608] at the index [12047221] in this snapshot
#
# Found the id [75470406] at the index [12047625] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [12047626 12047627 12047624 12047221 12047625]
#
#
# Now Matching the ids of the snapshot 599  with the cluster group id 14
# The total no. of stars in cluster id  14  is 5
# Sorted ids of this cluster is [ 9910784 31078456 35148679 54122687 67035242]
#
# Found the id [9910784] at the index [2955665] in this snapshot
#
# Found the id [31078456] at the index [2955664] in this snapshot
#
# Found the id [35148679] at the index [2955689] in this snapshot
#
# Found the id [54122687] at the index [2955673] in this snapshot
#
# Found the id [67035242] at the index [2955690] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [2955665 2955664 2955689 2955673 2955690]
#
#  Stored tracked data of all stars clusters in the snapshot no. 599 to filename: tracked_clusters_at_snapshot_599.pkl
# #####
#
#
# # in utilities.simulation.Snapshot():
# * reading:  scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/snapshot_times.txt
#
#   using snapshot index = 600, redshift = 0.007
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/output/snapshot_600.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 81363848 particles
#     dark2     (id = 2): 7086235 particles
#     gas       (id = 0): 64162982 particles
#     star      (id = 4): 17788189 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['star']
# * reading particles from:
#     scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/output/snapshot_600.hdf5
#
# * reading cosmological parameters from:  scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
# ! warning: star id.child [min, max] = [0.000, 4.254e9]
# ! warning: star mass [min, med, max] = [3245.210, 5412.002, 1.375e5]
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/track/host_coordinates.hdf5
#   host1 position = (38723.34, 47658.55, 46754.76) [kpc comoving]
#   host1 velocity = (-157.9, 165.7, 106.5) [km / s]
#   host1 axis ratios = (0.18, 0.19, 0.96)
#   host1 R_90 = 12.1 kpc
#   host1 M_90 = 7.5e+10 Msun
#
#
# #########
# ############
# Loaded id,id_child,age,x,y,z,vx,vy,vz,mass, cylindrical velocities and number of particles for snapshot no. 600
# Total no of particles in this shapshot no. 600 is 17788189
#
#
# Now Matching the ids of the snapshot 600  with the cluster group id 1
# The total no. of stars in cluster id  1  is 9
# Sorted ids of this cluster is [12233101 15939420 16676135 21789997 35600867 36199746 38743397 52460765
#  79474586]
#
# Found the id [12233101] at the index [3719382] in this snapshot
#
# Found the id [15939420] at the index [3719387] in this snapshot
#
# Found the id [16676135] at the index [3719388] in this snapshot
#
# Found the id [21789997] at the index [3719421] in this snapshot
#
# Found the id [35600867] at the index [3719385] in this snapshot
#
# Found the id [36199746] at the index [3719389] in this snapshot
#
# Found the id [38743397] at the index [3719381] in this snapshot
#
# Found the id [52460765] at the index [3719383] in this snapshot
#
# Found the id [79474586] at the index [3719424] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [3719382 3719387 3719388 3719421 3719385 3719389 3719381 3719383 3719424]
#
#
# Now Matching the ids of the snapshot 600  with the cluster group id 2
# The total no. of stars in cluster id  2  is 8
# Sorted ids of this cluster is [ 6288525 13442273 15683027 23830710 35882027 44637212 47692615 55510626]
#
# Found the id [6288525] at the index [630092] in this snapshot
#
# Found the id [13442273] at the index [630101] in this snapshot
#
# Found the id [15683027] at the index [630096] in this snapshot
#
# Found the id [23830710] at the index [630097] in this snapshot
#
# Found the id [35882027] at the index [630094] in this snapshot
#
# Found the id [44637212] at the index [630098] in this snapshot
#
# Found the id [47692615] at the index [630100] in this snapshot
#
# Found the id [55510626] at the index [630099] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [630092 630101 630096 630097 630094 630098 630100 630099]
#
#
# Now Matching the ids of the snapshot 600  with the cluster group id 3
# The total no. of stars in cluster id  3  is 7
# Sorted ids of this cluster is [ 6522694  9082875 17946997 19734054 29732816 40989092 57694150]
#
# Found the id [6522694] at the index [2896862] in this snapshot
#
# Found the id [9082875] at the index [2896863] in this snapshot
#
# Found the id [17946997] at the index [2896883] in this snapshot
#
# Found the id [19734054] at the index [2896865] in this snapshot
#
# Found the id [29732816] at the index [2896885] in this snapshot
#
# Found the id [40989092] at the index [2896884] in this snapshot
#
# Found the id [57694150] at the index [2896861] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [2896862 2896863 2896883 2896865 2896885 2896884 2896861]
#
#
# Now Matching the ids of the snapshot 600  with the cluster group id 4
# The total no. of stars in cluster id  4  is 7
# Sorted ids of this cluster is [31895283 48004469 51588915 60048561 63871484 68625169 74584151]
#
# Found the id [31895283] at the index [3174911] in this snapshot
#
# Found the id [48004469] at the index [3174901] in this snapshot
#
# Found the id [51588915] at the index [3174910] in this snapshot
#
# Found the id [60048561] at the index [3174909] in this snapshot
#
# Found the id [63871484] at the index [3174913] in this snapshot
#
# Found the id [68625169] at the index [3174912] in this snapshot
#
# Found the id [74584151] at the index [3174917] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [3174911 3174901 3174910 3174909 3174913 3174912 3174917]
#
#
# Now Matching the ids of the snapshot 600  with the cluster group id 5
# The total no. of stars in cluster id  5  is 7
# Sorted ids of this cluster is [17432067 18309009 43044321 46292834 54644758 60039322 79765310]
#
# Found the id [17432067] at the index [8078112] in this snapshot
#
# Found the id [18309009] at the index [8078107] in this snapshot
#
# Found the id [43044321] at the index [8078111] in this snapshot
#
# Found the id [46292834] at the index [8078104] in this snapshot
#
# Found the id [54644758] at the index [8078103] in this snapshot
#
# Found the id [60039322] at the index [8077462] in this snapshot
#
# Found the id [79765310] at the index [8078113] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [8078112 8078107 8078111 8078104 8078103 8077462 8078113]
#
#
# Now Matching the ids of the snapshot 600  with the cluster group id 6
# The total no. of stars in cluster id  6  is 7
# Sorted ids of this cluster is [14946122 17736446 19224491 24150783 42481897 43565926 45006599]
#
# Found the id [14946122] at the index [640956] in this snapshot
#
# Found the id [17736446] at the index [640958] in this snapshot
#
# Found the id [19224491] at the index [640957] in this snapshot
#
# Found the id [24150783] at the index [640947] in this snapshot
#
# Found the id [42481897] at the index [641200] in this snapshot
#
# Found the id [43565926] at the index [640948] in this snapshot
#
# Found the id [45006599] at the index [640955] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [640956 640958 640957 640947 641200 640948 640955]
#
#
# Now Matching the ids of the snapshot 600  with the cluster group id 7
# The total no. of stars in cluster id  7  is 6
# Sorted ids of this cluster is [26799622 31366904 33517759 43344184 59273944 66179841]
#
# Found the id [26799622] at the index [13777811] in this snapshot
#
# Found the id [31366904] at the index [14916075] in this snapshot
#
# Found the id [33517759] at the index [13777810] in this snapshot
#
# Found the id [43344184] at the index [13777809] in this snapshot
#
# Found the id [59273944] at the index [13777813] in this snapshot
#
# Found the id [66179841] at the index [13777812] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [13777811 14916075 13777810 13777809 13777813 13777812]
#
#
# Now Matching the ids of the snapshot 600  with the cluster group id 8
# The total no. of stars in cluster id  8  is 6
# Sorted ids of this cluster is [ 8078634 30501388 37124620 59473105 63656844 73852946]
#
# Found the id [8078634] at the index [13693169] in this snapshot
#
# Found the id [30501388] at the index [13693167] in this snapshot
#
# Found the id [37124620] at the index [13693166] in this snapshot
#
# Found the id [59473105] at the index [13693168] in this snapshot
#
# Found the id [63656844] at the index [13693210] in this snapshot
#
# Found the id [73852946] at the index [13693213] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [13693169 13693167 13693166 13693168 13693210 13693213]
#
#
# Now Matching the ids of the snapshot 600  with the cluster group id 9
# The total no. of stars in cluster id  9  is 5
# Sorted ids of this cluster is [22688626 25015777 32104848 55232462 65198437]
#
# Found the id [22688626] at the index [14902175] in this snapshot
#
# Found the id [25015777] at the index [14902182] in this snapshot
#
# Found the id [32104848] at the index [14902183] in this snapshot
#
# Found the id [55232462] at the index [14902176] in this snapshot
#
# Found the id [65198437] at the index [14902177] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [14902175 14902182 14902183 14902176 14902177]
#
#
# Now Matching the ids of the snapshot 600  with the cluster group id 10
# The total no. of stars in cluster id  10  is 5
# Sorted ids of this cluster is [ 9748455  9749625 13096782 20388585 35390117]
#
# Found the id [9748455] at the index [13783154] in this snapshot
#
# Found the id [9749625] at the index [13783157] in this snapshot
#
# Found the id [13096782] at the index [13783151] in this snapshot
#
# Found the id [20388585] at the index [13783148] in this snapshot
#
# Found the id [35390117] at the index [13783152] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [13783154 13783157 13783151 13783148 13783152]
#
#
# Now Matching the ids of the snapshot 600  with the cluster group id 11
# The total no. of stars in cluster id  11  is 5
# Sorted ids of this cluster is [11552938 18551404 23608604 36698843 68738504]
#
# Found the id [11552938] at the index [11800380] in this snapshot
#
# Found the id [18551404] at the index [11800373] in this snapshot
#
# Found the id [23608604] at the index [11800381] in this snapshot
#
# Found the id [36698843] at the index [11800363] in this snapshot
#
# Found the id [68738504] at the index [11800382] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [11800380 11800373 11800381 11800363 11800382]
#
#
# Now Matching the ids of the snapshot 600  with the cluster group id 12
# The total no. of stars in cluster id  12  is 5
# Sorted ids of this cluster is [11705068 36488475 39925280 40237329 71222733]
#
# Found the id [11705068] at the index [593638] in this snapshot
#
# Found the id [36488475] at the index [593658] in this snapshot
#
# Found the id [39925280] at the index [593640] in this snapshot
#
# Found the id [40237329] at the index [593641] in this snapshot
#
# Found the id [71222733] at the index [593637] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [593638 593658 593640 593641 593637]
#
#
# Now Matching the ids of the snapshot 600  with the cluster group id 13
# The total no. of stars in cluster id  13  is 5
# Sorted ids of this cluster is [27767024 59622229 62412117 69193608 75470406]
#
# Found the id [27767024] at the index [3377512] in this snapshot
#
# Found the id [59622229] at the index [3377513] in this snapshot
#
# Found the id [62412117] at the index [3377514] in this snapshot
#
# Found the id [69193608] at the index [3377510] in this snapshot
#
# Found the id [75470406] at the index [3377511] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [3377512 3377513 3377514 3377510 3377511]
#
#
# Now Matching the ids of the snapshot 600  with the cluster group id 14
# The total no. of stars in cluster id  14  is 5
# Sorted ids of this cluster is [ 9910784 31078456 35148679 54122687 67035242]
#
# Found the id [9910784] at the index [4930568] in this snapshot
#
# Found the id [31078456] at the index [4930569] in this snapshot
#
# Found the id [35148679] at the index [4930576] in this snapshot
#
# Found the id [54122687] at the index [4930575] in this snapshot
#
# Found the id [67035242] at the index [4930574] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [4930568 4930569 4930576 4930575 4930574]
#
#  Stored tracked data of all stars clusters in the snapshot no. 600 to filename: tracked_clusters_at_snapshot_600.pkl
# #####

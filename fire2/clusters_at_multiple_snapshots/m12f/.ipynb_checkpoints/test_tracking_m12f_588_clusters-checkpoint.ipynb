# %%
#!/usr/bin/env python
# coding: utf-8

#this file will load snapshots and store details of the tracked star cluster thoroughout the snapshots into individual files available at ./data

import gizmo_analysis as gizmo
import utilities as ut
from matplotlib import pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
from sl_utilities import distinct_colours as dc
from sl_utilities import distance_functions
import os
import pickle

# %%
simname = 'm12f_res7100_mhdcv'
simdir = '/scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/'

# %%
snapshot_start=597
snapshot_end=696 #ran out of memory after 646


#Loading the sample cluster to be tracked and sorting its id and id_child
snapnumber=588 #Remember to change it if you  are changing the star cluster you are tracking in given snapshot

path="/home1/07428/binod/work2/data/m12f_588_clusters_tracked_data_b4n5_pkl/" #creating a path to store the data only if it does not exist
if not os.path.exists(path):
  os.makedirs(path)




###############################################
###############################################
#loading data of all clusters (id, id_children and all)

cluster_file_name="fire2_clusters_"+simname+"_snapshot_"+str(snapnumber)+"_b4n5.pkl" 
with open(path+cluster_file_name, "rb") as fp:
    import_cluster = pickle.load(fp)

'''
import_cluster is a dictionary which is a collection of dictionaries for each cluster.
It was exported as follows from the program that tracked the clusters.
Note keys might have changed. Make a test run by importing the pkl file that contains the cluster info. 

cluster1={"cluster_groupid":grpid1,"no_of_star":nstar1,"id":id1,"id_children":id_children1}
cluster2={"cluster_groupid":grpid2,"no_of_star":nstar2,"id":id2,"id_children":id_children2}
cluster3={"cluster_groupid":grpid3,"no_of_star":nstar3,"id":id3,"id_children":id_children3} and so on
export_cluster={1:cluster1,2:cluster2,3:cluster3,4:cluster4,5:cluster5,6:cluster6,7:cluster7,8:cluster8,9:cluster9,10:cluster10}
path="./"
file_name="clusters_"+simname+"_snapshot_"+str(snapshot) 
with open(path+file_name, 'wb') as output:
    pickle.dump(export_cluster, output)

#####3
To access id from say cluster 2, use import_cluster[2]["id"]
'''
################################################################
################################################################





################################################################
################################################################
###Now let's create a function for find the matching ids in the next snapshot using a function
def matchids(id_current,id_child_current,id_next,id_child_next,id_generation_next): #this function returns the index of the ids in the next snapshot that match with the current
  ind=np.array(0)
  for i in range(len(id_current)):
    match=np.where((id_next==id_current[i])&(id_child_next==id_child_current[i])&(id_generation_next<30)) #Also add id_generations<30
    print("\nFound the id",id_next[match],"at the index",match[0],"in this snapshot")
    ind=np.append(ind,match)
  ind_tracked_id_next=ind[1:len(ind)]  #The extra element in the beginning is removed by this process
  print("\nThese are the indices of the ids that matched in current snapshot\n",ind_tracked_id_next)
  return ind_tracked_id_next  
################################################################
################################################################


total_clusters=len(import_cluster)         #count the total no. of clusters we have in clusters file
total_snaps=snapshot_end-snapshot_start+1  #count the total no. of snapshots we are going to track
snap=snapshot_start                        #Mark the beginning of the snapshot
test_cluster=1                             #Mark the beginning of the cluster that we would be tracking
ind_tracked={}                             #finding the indices of the tracked stars in each snapshot for each cluster.

tracked_data_all_clusters_each_snap={}     #dictionary for storing data from all clusters and in each snapshot


#Algorithm followed for scanning each snapshot for all given star clusters is as follows
'''
Step1: Load the star clusters from the given file
Step2: snap=snapshot to begin with
Step3: Load id, id_child, id_genearation, age, mass, positoins, velocities and everything you want form the snapshot snap
Step4: Now assign test_cluster=1 which is the star cluster to begin with for tracking
Step5: Track the stars from the test_cluster using the id, id_child and id_generation
Step6: Get the information of the tracked stars id, id_child, id_genearation, age, mass, positoins, velocities and everything you want form the snapshot snap
        Save the information you gathered into a dictionary tracked_data_all_clusters
        test_cluster+=1
Step7: Is test_cluster<total_clusters? If yes goto step 5 else goto step 8
Step8: All clusters were tracked for the given snapshot
        Store the data gathered from all clusters in given snapshot to a dictionary tracked_data_all_clusters_each_snap
        It has the format {596:{1:{"x_tracked":[array],...},2:{"x_tracked":[array],...}},597:{1:{"x_tracked":[array],..},2:{"x_tracked":[array],..}..}}
        snap+=1
        Is snap<total_snaps? If yes goto step 3 else goto Step 9
Step9: End

'''




for i in range(total_snaps):               #we run a for loop until the end of all snapshots
  part=gizmo.io.Read.read_snapshots(['star'],'snapshot_index', snap, simulation_name=simname, simulation_directory=simdir, assign_hosts=True, assign_hosts_rotation=True)               #snap is the snapshot number here that changes everytime the loop iterates. It starts with sanpshot_start
  
  id=part['star'].prop('id')
  id_child=part['star'].prop('id.child')
  id_generation=part['star'].prop('id.generation')
  age=part['star'].prop('age')
  x=part['star'].prop('host.distance.principal')[:,0] #x component of the position of all stars 
  y=part['star'].prop('host.distance.principal')[:,1] #y component of the position of all stars
  z=part['star'].prop('host.distance.principal')[:,2] #z component of the position of all stars
  n=len(x) # counting the total no. of star particles
  vx=part['star'].prop('host.velocity.principal')[:,0]
  vy=part['star'].prop('host.velocity.principal')[:,1]
  vz=part['star'].prop('host.velocity.principal')[:,2]
  mass=part['star']['mass'] #mass of all stars in snapshot 691
  # compute 3-D velocity in cylindrical coordinates
  # first value is along the major axes (positive definite)
  # secod value is azimuthal velocity in the plane of the disk (positive definite)
  # third value is vertical velocity wrt the disk (signed)
  vR_cyl=part['star'].prop('host.velocity.principal.cylindrical')[:,0]
  vphi_cyl=part['star'].prop('host.velocity.principal.cylindrical')[:,1]
  vz_cyl=part['star'].prop('host.velocity.principal.cylindrical')[:,2]
  print("\n#########\n############\nLoaded id,id_child,age,x,y,z,vx,vy,vz,mass, cylindrical velocities and number of particles for snapshot no.",snap)
  print("Total no of particles in this shapshot no.",snap,"is",n)
  
  
  
  
  
  ################################################################
  ################################################################
  ### Now matching the IDs of this snapshot with the ids of all clusters
  test_cluster=1                       #This is the test cluster to begin with. It resets to 1 at each snapshot 
  tracked_data_all_clusters={}         #This dictionary keeps the tracked information for all star clusters in given snapshot. It also resets with snapshots.
  for j in range(total_clusters):
    tracked_data={}                    #This dictionary holds the tracked information for a cluster temporarily until it is pushed to tracked_data_all_clusters
    print("\n\nNow Matching the ids of the snapshot",snap," with the cluster group id",test_cluster)
    id_test_cluster=import_cluster[test_cluster]["id"]
    id_child_test_cluster=import_cluster[test_cluster]["id_children"]
    sortind=np.argsort(id_test_cluster)
    id_test_cluster_sorted=id_test_cluster[sortind]
    id_child_test_cluster_sorted=id_child_test_cluster[sortind]
    print("The total no. of stars in cluster id ",test_cluster," is",len(id_test_cluster_sorted))
    print("Sorted ids of this cluster is",id_test_cluster_sorted)
    ind_tracked=matchids(id_test_cluster_sorted,id_child_test_cluster_sorted,id,id_child,id_generation)
    
    ################################################################
    ################################################################
    #Now finding the postion, velocities, age and mass of the tracked stars in each snapshots
    age_tracked=age[ind_tracked]
    x_tracked=x[ind_tracked]
    y_tracked=y[ind_tracked]
    z_tracked=z[ind_tracked]
    vx_tracked=vx[ind_tracked]
    vy_tracked=vy[ind_tracked]
    vz_tracked=vz[ind_tracked]
    mass_tracked=mass[ind_tracked]
    vR_cyl_tracked=vR_cyl[ind_tracked]
    vphi_cyl_tracked=vphi_cyl[ind_tracked]
    vz_cyl_tracked=vz_cyl[ind_tracked]
    
    
    ################################################################
    ################################################################
    #Now calculating center of mass and realted properties  
    xcm=distance_functions.cm(x_tracked,mass_tracked)
    ycm=distance_functions.cm(y_tracked,mass_tracked)
    zcm=distance_functions.cm(z_tracked,mass_tracked)
    delta_rxyz=distance_functions.dr(x_tracked,y_tracked,z_tracked,mass_tracked)
    rmax=distance_functions.drmax(x_tracked,y_tracked,z_tracked,mass_tracked)
    ymax=(ycm+1.1*rmax)
    ymin=(ycm-1.1*rmax)
    xmax=(xcm+1.1*rmax)
    xmin=(xcm-1.1*rmax)
    avg_delta_rxyz=np.mean(np.absolute(delta_rxyz))
  
  
    ################################################################
    ################################################################
    #Now lets write our tracked data from each snapshots to a file
    tracked_data={"ind_tracked":ind_tracked,"age_tracked":age_tracked,"x_tracked":x_tracked,"y_tracked":y_tracked,"z_tracked":z_tracked,
    "vx_tracked":vx_tracked,"vy_tracked":vy_tracked,"vz_tracked":vz_tracked,
    "mass_tracked":mass_tracked,"xcm":xcm,"ycm":ycm,"zcm":zcm,"delta_rxyz":delta_rxyz,"rmax":rmax,
    "ymax":ymax,"ymin":ymin,"xmax":xmax,"xmin":xmin,"avg_delta_rxyz":avg_delta_rxyz,
    "vR_cyl_tracked":vR_cyl_tracked,"vphi_cyl_tracked":vphi_cyl_tracked,"vz_cyl_tracked":vz_cyl_tracked}
    
    
    tracked_data_all_clusters.update({test_cluster:tracked_data}) #access it using tracked_data_all_clusters[clusterid]["key"]
    test_cluster+=1
  
  #We have collected all tracked information for our test clusters for one snapshot now which is in dictionary tracked_data_all_clusters.
  #We would store that dictionary in a pickle file as a backup data from each snapshot about or all star cluster.
  ###Now moving out of the j loop. We scanned all clusters and stored the tracked data into a dictionary tracked_data_all_clusters  
  file_name="tracked_clusters_at_snapshot_"+str(snap)+".pkl"
  with open(path+file_name, 'wb') as output:
    pickle.dump(tracked_data_all_clusters, output)
  print("\n Stored tracked data of all stars clusters in the snapshot no.",snap,"to filename:",file_name,"\n#####\n")
  #Note we are still in i loop which is scanning each snapshot !!!!!!!!!!!!!!!!!!
  tracked_data_all_clusters_each_snap.update({snap:tracked_data_all_clusters}) 
  snap=snap+1

#Came out of i loop 
  
#Finally we scanned through all the snapshots and now we come out of the loop to store the final file that contains all the tracked information of all clusters 
#Now we store the tracked data of all clusters into a dictionary with snapshot number as the key. This would be our final dictionary of dictinaries. 
with open(path+"total_data_tracked_clusters_all_snapshots.pkl", 'wb') as output:
  pickle.dump(tracked_data_all_clusters_each_snap, output) #access the data using tracked_data_all_clusters_each_snap[snapshot][cluster_id]["x_tracked"])
  
#Expected Result: tracked_data_all_clusters_each_snap={596:{1:tracked_data,2:tracked_data..},597:{1:tracked_data,2:tracked_data..upto total clusters},598....     upto total snapshots}
# Out:
# # in utilities.simulation.Snapshot():
# * reading:  scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/snapshot_times.txt
#
#   using snapshot index = 589, redshift = 0.008
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/output/snapshot_589.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 81363848 particles
#     dark2     (id = 2): 7086235 particles
#     gas       (id = 0): 64174479 particles
#     star      (id = 4): 17776692 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['star']
# * reading particles from:
#     scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/output/snapshot_589.hdf5
#
# * reading cosmological parameters from:  scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
# ! warning: star id.child [min, max] = [0.000, 4.254e9]
# ! warning: star mass [min, med, max] = [3245.210, 5412.044, 1.375e5]
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/track/host_coordinates.hdf5
#   host1 position = (38725.18, 47656.63, 46753.48) [kpc comoving]
#   host1 velocity = (-157.2, 165.5, 108.1) [km / s]
#   host1 axis ratios = (0.18, 0.19, 0.96)
#   host1 R_90 = 12.1 kpc
#   host1 M_90 = 7.4e+10 Msun
#
#
# #########
# ############
# Loaded id,id_child,age,x,y,z,vx,vy,vz,mass, cylindrical velocities and number of particles for snapshot no. 589
# Total no of particles in this shapshot no. 589 is 17776692
#
#
# Now Matching the ids of the snapshot 589  with the cluster group id 1
# The total no. of stars in cluster id  1  is 9
# Sorted ids of this cluster is [12233101 15939420 16676135 21789997 35600867 36199746 38743397 52460765
#  79474586]
#
# Found the id [12233101] at the index [3035416] in this snapshot
#
# Found the id [15939420] at the index [3035417] in this snapshot
#
# Found the id [16676135] at the index [3035421] in this snapshot
#
# Found the id [21789997] at the index [3035400] in this snapshot
#
# Found the id [35600867] at the index [3035423] in this snapshot
#
# Found the id [36199746] at the index [3035420] in this snapshot
#
# Found the id [38743397] at the index [3035414] in this snapshot
#
# Found the id [52460765] at the index [3035415] in this snapshot
#
# Found the id [79474586] at the index [3035419] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [3035416 3035417 3035421 3035400 3035423 3035420 3035414 3035415 3035419]
#
#
# Now Matching the ids of the snapshot 589  with the cluster group id 2
# The total no. of stars in cluster id  2  is 8
# Sorted ids of this cluster is [ 6288525 13442273 15683027 23830710 35882027 44637212 47692615 55510626]
#
# Found the id [6288525] at the index [4797828] in this snapshot
#
# Found the id [13442273] at the index [4797825] in this snapshot
#
# Found the id [15683027] at the index [4797822] in this snapshot
#
# Found the id [23830710] at the index [4797829] in this snapshot
#
# Found the id [35882027] at the index [4797824] in this snapshot
#
# Found the id [44637212] at the index [4797830] in this snapshot
#
# Found the id [47692615] at the index [4797826] in this snapshot
#
# Found the id [55510626] at the index [4797823] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [4797828 4797825 4797822 4797829 4797824 4797830 4797826 4797823]
#
#
# Now Matching the ids of the snapshot 589  with the cluster group id 3
# The total no. of stars in cluster id  3  is 7
# Sorted ids of this cluster is [ 6522694  9082875 17946997 19734054 29732816 40989092 57694150]
#
# Found the id [6522694] at the index [7239169] in this snapshot
#
# Found the id [9082875] at the index [7239170] in this snapshot
#
# Found the id [17946997] at the index [7239160] in this snapshot
#
# Found the id [19734054] at the index [7239164] in this snapshot
#
# Found the id [29732816] at the index [7239163] in this snapshot
#
# Found the id [40989092] at the index [7239162] in this snapshot
#
# Found the id [57694150] at the index [7239165] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [7239169 7239170 7239160 7239164 7239163 7239162 7239165]
#
#
# Now Matching the ids of the snapshot 589  with the cluster group id 4
# The total no. of stars in cluster id  4  is 7
# Sorted ids of this cluster is [31895283 48004469 51588915 60048561 63871484 68625169 74584151]
#
# Found the id [31895283] at the index [11593887] in this snapshot
#
# Found the id [48004469] at the index [11593894] in this snapshot
#
# Found the id [51588915] at the index [11593886] in this snapshot
#
# Found the id [60048561] at the index [11593885] in this snapshot
#
# Found the id [63871484] at the index [11593893] in this snapshot
#
# Found the id [68625169] at the index [11593888] in this snapshot
#
# Found the id [74584151] at the index [11593881] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [11593887 11593894 11593886 11593885 11593893 11593888 11593881]
#
#
# Now Matching the ids of the snapshot 589  with the cluster group id 5
# The total no. of stars in cluster id  5  is 7
# Sorted ids of this cluster is [17432067 18309009 43044321 46292834 54644758 60039322 79765310]
#
# Found the id [17432067] at the index [10203370] in this snapshot
#
# Found the id [18309009] at the index [10203412] in this snapshot
#
# Found the id [43044321] at the index [10203414] in this snapshot
#
# Found the id [46292834] at the index [10203410] in this snapshot
#
# Found the id [54644758] at the index [10203415] in this snapshot
#
# Found the id [60039322] at the index [8985432] in this snapshot
#
# Found the id [79765310] at the index [10203413] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [10203370 10203412 10203414 10203410 10203415  8985432 10203413]
#
#
# Now Matching the ids of the snapshot 589  with the cluster group id 6
# The total no. of stars in cluster id  6  is 7
# Sorted ids of this cluster is [14946122 17736446 19224491 24150783 42481897 43565926 45006599]
#
# Found the id [14946122] at the index [490660] in this snapshot
#
# Found the id [17736446] at the index [490664] in this snapshot
#
# Found the id [19224491] at the index [490661] in this snapshot
#
# Found the id [24150783] at the index [490653] in this snapshot
#
# Found the id [42481897] at the index [490665] in this snapshot
#
# Found the id [43565926] at the index [490652] in this snapshot
#
# Found the id [45006599] at the index [490662] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [490660 490664 490661 490653 490665 490652 490662]
#
#
# Now Matching the ids of the snapshot 589  with the cluster group id 7
# The total no. of stars in cluster id  7  is 6
# Sorted ids of this cluster is [26799622 31366904 33517759 43344184 59273944 66179841]
#
# Found the id [26799622] at the index [10757576] in this snapshot
#
# Found the id [31366904] at the index [10757572] in this snapshot
#
# Found the id [33517759] at the index [10757577] in this snapshot
#
# Found the id [43344184] at the index [10757575] in this snapshot
#
# Found the id [59273944] at the index [10757574] in this snapshot
#
# Found the id [66179841] at the index [10757573] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [10757576 10757572 10757577 10757575 10757574 10757573]
#
#
# Now Matching the ids of the snapshot 589  with the cluster group id 8
# The total no. of stars in cluster id  8  is 6
# Sorted ids of this cluster is [ 8078634 30501388 37124620 59473105 63656844 73852946]
#
# Found the id [8078634] at the index [3213863] in this snapshot
#
# Found the id [30501388] at the index [3213861] in this snapshot
#
# Found the id [37124620] at the index [3213859] in this snapshot
#
# Found the id [59473105] at the index [3213864] in this snapshot
#
# Found the id [63656844] at the index [3213862] in this snapshot
#
# Found the id [73852946] at the index [3213858] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [3213863 3213861 3213859 3213864 3213862 3213858]
#
#
# Now Matching the ids of the snapshot 589  with the cluster group id 9
# The total no. of stars in cluster id  9  is 5
# Sorted ids of this cluster is [22688626 25015777 32104848 55232462 65198437]
#
# Found the id [22688626] at the index [3088465] in this snapshot
#
# Found the id [25015777] at the index [3088468] in this snapshot
#
# Found the id [32104848] at the index [3088469] in this snapshot
#
# Found the id [55232462] at the index [3088467] in this snapshot
#
# Found the id [65198437] at the index [3088466] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [3088465 3088468 3088469 3088467 3088466]
#
#
# Now Matching the ids of the snapshot 589  with the cluster group id 10
# The total no. of stars in cluster id  10  is 5
# Sorted ids of this cluster is [ 9748455  9749625 13096782 20388585 35390117]
#
# Found the id [9748455] at the index [8762649] in this snapshot
#
# Found the id [9749625] at the index [8762680] in this snapshot
#
# Found the id [13096782] at the index [8762665] in this snapshot
#
# Found the id [20388585] at the index [8762671] in this snapshot
#
# Found the id [35390117] at the index [8762670] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [8762649 8762680 8762665 8762671 8762670]
#
#
# Now Matching the ids of the snapshot 589  with the cluster group id 11
# The total no. of stars in cluster id  11  is 5
# Sorted ids of this cluster is [11552938 18551404 23608604 36698843 68738504]
#
# Found the id [11552938] at the index [758770] in this snapshot
#
# Found the id [18551404] at the index [758769] in this snapshot
#
# Found the id [23608604] at the index [758763] in this snapshot
#
# Found the id [36698843] at the index [758764] in this snapshot
#
# Found the id [68738504] at the index [758767] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [758770 758769 758763 758764 758767]
#
#
# Now Matching the ids of the snapshot 589  with the cluster group id 12
# The total no. of stars in cluster id  12  is 5
# Sorted ids of this cluster is [11705068 36488475 39925280 40237329 71222733]
#
# Found the id [11705068] at the index [11680500] in this snapshot
#
# Found the id [36488475] at the index [11680507] in this snapshot
#
# Found the id [39925280] at the index [11680501] in this snapshot
#
# Found the id [40237329] at the index [11680503] in this snapshot
#
# Found the id [71222733] at the index [11680502] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [11680500 11680507 11680501 11680503 11680502]
#
#
# Now Matching the ids of the snapshot 589  with the cluster group id 13
# The total no. of stars in cluster id  13  is 5
# Sorted ids of this cluster is [27767024 59622229 62412117 69193608 75470406]
#
# Found the id [27767024] at the index [2928034] in this snapshot
#
# Found the id [59622229] at the index [2928032] in this snapshot
#
# Found the id [62412117] at the index [2928031] in this snapshot
#
# Found the id [69193608] at the index [2928030] in this snapshot
#
# Found the id [75470406] at the index [2928033] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [2928034 2928032 2928031 2928030 2928033]
#
#
# Now Matching the ids of the snapshot 589  with the cluster group id 14
# The total no. of stars in cluster id  14  is 5
# Sorted ids of this cluster is [ 9910784 31078456 35148679 54122687 67035242]
#
# Found the id [9910784] at the index [5622581] in this snapshot
#
# Found the id [31078456] at the index [5622579] in this snapshot
#
# Found the id [35148679] at the index [5622585] in this snapshot
#
# Found the id [54122687] at the index [5622571] in this snapshot
#
# Found the id [67035242] at the index [5622584] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [5622581 5622579 5622585 5622571 5622584]
#
#  Stored tracked data of all stars clusters in the snapshot no. 589 to filename: tracked_clusters_at_snapshot_589.pkl
# #####
#
#
# # in utilities.simulation.Snapshot():
# * reading:  scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/snapshot_times.txt
#
#   using snapshot index = 590, redshift = 0.008
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/output/snapshot_590.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 81363848 particles
#     dark2     (id = 2): 7086235 particles
#     gas       (id = 0): 64173477 particles
#     star      (id = 4): 17777694 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['star']
# * reading particles from:
#     scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/output/snapshot_590.hdf5
#
# * reading cosmological parameters from:  scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
# ! warning: star id.child [min, max] = [0.000, 4.254e9]
# ! warning: star mass [min, med, max] = [3245.210, 5412.034, 1.375e5]
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/track/host_coordinates.hdf5
#   host1 position = (38725.02, 47656.80, 46753.60) [kpc comoving]
#   host1 velocity = (-157.3, 165.6, 107.9) [km / s]
#   host1 axis ratios = (0.18, 0.19, 0.96)
#   host1 R_90 = 12.1 kpc
#   host1 M_90 = 7.4e+10 Msun
#
#
# #########
# ############
# Loaded id,id_child,age,x,y,z,vx,vy,vz,mass, cylindrical velocities and number of particles for snapshot no. 590
# Total no of particles in this shapshot no. 590 is 17777694
#
#
# Now Matching the ids of the snapshot 590  with the cluster group id 1
# The total no. of stars in cluster id  1  is 9
# Sorted ids of this cluster is [12233101 15939420 16676135 21789997 35600867 36199746 38743397 52460765
#  79474586]
#
# Found the id [12233101] at the index [12227806] in this snapshot
#
# Found the id [15939420] at the index [12227813] in this snapshot
#
# Found the id [16676135] at the index [12227818] in this snapshot
#
# Found the id [21789997] at the index [12227809] in this snapshot
#
# Found the id [35600867] at the index [12227815] in this snapshot
#
# Found the id [36199746] at the index [12227817] in this snapshot
#
# Found the id [38743397] at the index [12227807] in this snapshot
#
# Found the id [52460765] at the index [12227805] in this snapshot
#
# Found the id [79474586] at the index [12227812] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [12227806 12227813 12227818 12227809 12227815 12227817 12227807 12227805
#  12227812]
#
#
# Now Matching the ids of the snapshot 590  with the cluster group id 2
# The total no. of stars in cluster id  2  is 8
# Sorted ids of this cluster is [ 6288525 13442273 15683027 23830710 35882027 44637212 47692615 55510626]
#
# Found the id [6288525] at the index [16366276] in this snapshot
#
# Found the id [13442273] at the index [16366274] in this snapshot
#
# Found the id [15683027] at the index [16366279] in this snapshot
#
# Found the id [23830710] at the index [16366275] in this snapshot
#
# Found the id [35882027] at the index [16366270] in this snapshot
#
# Found the id [44637212] at the index [16366273] in this snapshot
#
# Found the id [47692615] at the index [16366271] in this snapshot
#
# Found the id [55510626] at the index [16366277] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [16366276 16366274 16366279 16366275 16366270 16366273 16366271 16366277]
#
#
# Now Matching the ids of the snapshot 590  with the cluster group id 3
# The total no. of stars in cluster id  3  is 7
# Sorted ids of this cluster is [ 6522694  9082875 17946997 19734054 29732816 40989092 57694150]
#
# Found the id [6522694] at the index [8623959] in this snapshot
#
# Found the id [9082875] at the index [17236025] in this snapshot
#
# Found the id [17946997] at the index [8623969] in this snapshot
#
# Found the id [19734054] at the index [8623966] in this snapshot
#
# Found the id [29732816] at the index [8623964] in this snapshot
#
# Found the id [40989092] at the index [8623967] in this snapshot
#
# Found the id [57694150] at the index [8623962] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [ 8623959 17236025  8623969  8623966  8623964  8623967  8623962]
#
#
# Now Matching the ids of the snapshot 590  with the cluster group id 4
# The total no. of stars in cluster id  4  is 7
# Sorted ids of this cluster is [31895283 48004469 51588915 60048561 63871484 68625169 74584151]
#
# Found the id [31895283] at the index [397269] in this snapshot
#
# Found the id [48004469] at the index [397261] in this snapshot
#
# Found the id [51588915] at the index [397268] in this snapshot
#
# Found the id [60048561] at the index [397259] in this snapshot
#
# Found the id [63871484] at the index [397262] in this snapshot
#
# Found the id [68625169] at the index [397258] in this snapshot
#
# Found the id [74584151] at the index [397263] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [397269 397261 397268 397259 397262 397258 397263]
#
#
# Now Matching the ids of the snapshot 590  with the cluster group id 5
# The total no. of stars in cluster id  5  is 7
# Sorted ids of this cluster is [17432067 18309009 43044321 46292834 54644758 60039322 79765310]
#
# Found the id [17432067] at the index [7563187] in this snapshot
#
# Found the id [18309009] at the index [7563196] in this snapshot
#
# Found the id [43044321] at the index [7563195] in this snapshot
#
# Found the id [46292834] at the index [7563201] in this snapshot
#
# Found the id [54644758] at the index [7563200] in this snapshot
#
# Found the id [60039322] at the index [7563170] in this snapshot
#
# Found the id [79765310] at the index [7563193] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [7563187 7563196 7563195 7563201 7563200 7563170 7563193]
#
#
# Now Matching the ids of the snapshot 590  with the cluster group id 6
# The total no. of stars in cluster id  6  is 7
# Sorted ids of this cluster is [14946122 17736446 19224491 24150783 42481897 43565926 45006599]
#
# Found the id [14946122] at the index [107553] in this snapshot
#
# Found the id [17736446] at the index [107560] in this snapshot
#
# Found the id [19224491] at the index [107564] in this snapshot
#
# Found the id [24150783] at the index [107562] in this snapshot
#
# Found the id [42481897] at the index [107559] in this snapshot
#
# Found the id [43565926] at the index [107565] in this snapshot
#
# Found the id [45006599] at the index [107561] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [107553 107560 107564 107562 107559 107565 107561]
#
#
# Now Matching the ids of the snapshot 590  with the cluster group id 7
# The total no. of stars in cluster id  7  is 6
# Sorted ids of this cluster is [26799622 31366904 33517759 43344184 59273944 66179841]
#
# Found the id [26799622] at the index [13691853] in this snapshot
#
# Found the id [31366904] at the index [13691846] in this snapshot
#
# Found the id [33517759] at the index [13691855] in this snapshot
#
# Found the id [43344184] at the index [13691854] in this snapshot
#
# Found the id [59273944] at the index [13691862] in this snapshot
#
# Found the id [66179841] at the index [13691845] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [13691853 13691846 13691855 13691854 13691862 13691845]
#
#
# Now Matching the ids of the snapshot 590  with the cluster group id 8
# The total no. of stars in cluster id  8  is 6
# Sorted ids of this cluster is [ 8078634 30501388 37124620 59473105 63656844 73852946]
#
# Found the id [8078634] at the index [7746729] in this snapshot
#
# Found the id [30501388] at the index [15826397] in this snapshot
#
# Found the id [37124620] at the index [7746734] in this snapshot
#
# Found the id [59473105] at the index [7746724] in this snapshot
#
# Found the id [63656844] at the index [7746735] in this snapshot
#
# Found the id [73852946] at the index [7746722] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [ 7746729 15826397  7746734  7746724  7746735  7746722]
#
#
# Now Matching the ids of the snapshot 590  with the cluster group id 9
# The total no. of stars in cluster id  9  is 5
# Sorted ids of this cluster is [22688626 25015777 32104848 55232462 65198437]
#
# Found the id [22688626] at the index [13404618] in this snapshot
#
# Found the id [25015777] at the index [13404616] in this snapshot
#
# Found the id [32104848] at the index [13404614] in this snapshot
#
# Found the id [55232462] at the index [13404619] in this snapshot
#
# Found the id [65198437] at the index [13404615] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [13404618 13404616 13404614 13404619 13404615]
#
#
# Now Matching the ids of the snapshot 590  with the cluster group id 10
# The total no. of stars in cluster id  10  is 5
# Sorted ids of this cluster is [ 9748455  9749625 13096782 20388585 35390117]
#
# Found the id [9748455] at the index [11397009] in this snapshot
#
# Found the id [9749625] at the index [11396949] in this snapshot
#
# Found the id [13096782] at the index [11397016] in this snapshot
#
# Found the id [20388585] at the index [11397057] in this snapshot
#
# Found the id [35390117] at the index [11397067] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [11397009 11396949 11397016 11397057 11397067]
#
#
# Now Matching the ids of the snapshot 590  with the cluster group id 11
# The total no. of stars in cluster id  11  is 5
# Sorted ids of this cluster is [11552938 18551404 23608604 36698843 68738504]
#
# Found the id [11552938] at the index [3949726] in this snapshot
#
# Found the id [18551404] at the index [3949708] in this snapshot
#
# Found the id [23608604] at the index [3949709] in this snapshot
#
# Found the id [36698843] at the index [3949714] in this snapshot
#
# Found the id [68738504] at the index [3949713] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [3949726 3949708 3949709 3949714 3949713]
#
#
# Now Matching the ids of the snapshot 590  with the cluster group id 12
# The total no. of stars in cluster id  12  is 5
# Sorted ids of this cluster is [11705068 36488475 39925280 40237329 71222733]
#
# Found the id [11705068] at the index [15113522] in this snapshot
#
# Found the id [36488475] at the index [15113542] in this snapshot
#
# Found the id [39925280] at the index [15113526] in this snapshot
#
# Found the id [40237329] at the index [15113523] in this snapshot
#
# Found the id [71222733] at the index [15113527] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [15113522 15113542 15113526 15113523 15113527]
#
#
# Now Matching the ids of the snapshot 590  with the cluster group id 13
# The total no. of stars in cluster id  13  is 5
# Sorted ids of this cluster is [27767024 59622229 62412117 69193608 75470406]
#
# Found the id [27767024] at the index [4500742] in this snapshot
#
# Found the id [59622229] at the index [4500741] in this snapshot
#
# Found the id [62412117] at the index [4500740] in this snapshot
#
# Found the id [69193608] at the index [4500744] in this snapshot
#
# Found the id [75470406] at the index [4500743] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [4500742 4500741 4500740 4500744 4500743]
#
#
# Now Matching the ids of the snapshot 590  with the cluster group id 14
# The total no. of stars in cluster id  14  is 5
# Sorted ids of this cluster is [ 9910784 31078456 35148679 54122687 67035242]
#
# Found the id [9910784] at the index [490621] in this snapshot
#
# Found the id [31078456] at the index [490625] in this snapshot
#
# Found the id [35148679] at the index [490628] in this snapshot
#
# Found the id [54122687] at the index [490623] in this snapshot
#
# Found the id [67035242] at the index [490624] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [490621 490625 490628 490623 490624]
#
#  Stored tracked data of all stars clusters in the snapshot no. 590 to filename: tracked_clusters_at_snapshot_590.pkl
# #####
#
#
# # in utilities.simulation.Snapshot():
# * reading:  scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/snapshot_times.txt
#
#   using snapshot index = 591, redshift = 0.008
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/output/snapshot_591.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 81363848 particles
#     dark2     (id = 2): 7086235 particles
#     gas       (id = 0): 64172385 particles
#     star      (id = 4): 17778786 particles
#     blackhole (id = 5): 0 particles
#
# * reading species: ['star']
# * reading particles from:
#     scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/output/snapshot_591.hdf5
#
# * reading cosmological parameters from:  scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
# ! warning: star id.child [min, max] = [0.000, 4.254e9]
# ! warning: star mass [min, med, max] = [3245.210, 5412.025, 1.375e5]
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/track/host_coordinates.hdf5
#   host1 position = (38724.84, 47656.97, 46753.71) [kpc comoving]
#   host1 velocity = (-157.4, 165.6, 107.7) [km / s]
#   host1 axis ratios = (0.18, 0.19, 0.96)
#   host1 R_90 = 12.1 kpc
#   host1 M_90 = 7.4e+10 Msun
#
#
# #########
# ############
# Loaded id,id_child,age,x,y,z,vx,vy,vz,mass, cylindrical velocities and number of particles for snapshot no. 591
# Total no of particles in this shapshot no. 591 is 17778786
#
#
# Now Matching the ids of the snapshot 591  with the cluster group id 1
# The total no. of stars in cluster id  1  is 9
# Sorted ids of this cluster is [12233101 15939420 16676135 21789997 35600867 36199746 38743397 52460765
#  79474586]
#
# Found the id [12233101] at the index [9453663] in this snapshot
#
# Found the id [15939420] at the index [12743108] in this snapshot
#
# Found the id [16676135] at the index [9453660] in this snapshot
#
# Found the id [21789997] at the index [12743106] in this snapshot
#
# Found the id [35600867] at the index [9453662] in this snapshot
#
# Found the id [36199746] at the index [9453661] in this snapshot
#
# Found the id [38743397] at the index [12743111] in this snapshot
#
# Found the id [52460765] at the index [9453664] in this snapshot
#
# Found the id [79474586] at the index [12743110] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [ 9453663 12743108  9453660 12743106  9453662  9453661 12743111  9453664
#  12743110]
#
#
# Now Matching the ids of the snapshot 591  with the cluster group id 2
# The total no. of stars in cluster id  2  is 8
# Sorted ids of this cluster is [ 6288525 13442273 15683027 23830710 35882027 44637212 47692615 55510626]
#
# Found the id [6288525] at the index [1231834] in this snapshot
#
# Found the id [13442273] at the index [1231843] in this snapshot
#
# Found the id [15683027] at the index [1231845] in this snapshot
#
# Found the id [23830710] at the index [1231840] in this snapshot
#
# Found the id [35882027] at the index [1231844] in this snapshot
#
# Found the id [44637212] at the index [1231841] in this snapshot
#
# Found the id [47692615] at the index [1231842] in this snapshot
#
# Found the id [55510626] at the index [1231839] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [1231834 1231843 1231845 1231840 1231844 1231841 1231842 1231839]
#
#
# Now Matching the ids of the snapshot 591  with the cluster group id 3
# The total no. of stars in cluster id  3  is 7
# Sorted ids of this cluster is [ 6522694  9082875 17946997 19734054 29732816 40989092 57694150]
#
# Found the id [6522694] at the index [8757977] in this snapshot
#
# Found the id [9082875] at the index [8757978] in this snapshot
#
# Found the id [17946997] at the index [8757988] in this snapshot
#
# Found the id [19734054] at the index [8757974] in this snapshot
#
# Found the id [29732816] at the index [8757985] in this snapshot
#
# Found the id [40989092] at the index [8757984] in this snapshot
#
# Found the id [57694150] at the index [8757975] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [8757977 8757978 8757988 8757974 8757985 8757984 8757975]
#
#
# Now Matching the ids of the snapshot 591  with the cluster group id 4
# The total no. of stars in cluster id  4  is 7
# Sorted ids of this cluster is [31895283 48004469 51588915 60048561 63871484 68625169 74584151]
#
# Found the id [31895283] at the index [2032533] in this snapshot
#
# Found the id [48004469] at the index [2032536] in this snapshot
#
# Found the id [51588915] at the index [2032532] in this snapshot
#
# Found the id [60048561] at the index [2032534] in this snapshot
#
# Found the id [63871484] at the index [2032537] in this snapshot
#
# Found the id [68625169] at the index [2032535] in this snapshot
#
# Found the id [74584151] at the index [2032540] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [2032533 2032536 2032532 2032534 2032537 2032535 2032540]
#
#
# Now Matching the ids of the snapshot 591  with the cluster group id 5
# The total no. of stars in cluster id  5  is 7
# Sorted ids of this cluster is [17432067 18309009 43044321 46292834 54644758 60039322 79765310]
#
# Found the id [17432067] at the index [9767305] in this snapshot
#
# Found the id [18309009] at the index [9767299] in this snapshot
#
# Found the id [43044321] at the index [9767303] in this snapshot
#
# Found the id [46292834] at the index [9767297] in this snapshot
#
# Found the id [54644758] at the index [9767307] in this snapshot
#
# Found the id [60039322] at the index [9767291] in this snapshot
#
# Found the id [79765310] at the index [9767304] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [9767305 9767299 9767303 9767297 9767307 9767291 9767304]
#
#
# Now Matching the ids of the snapshot 591  with the cluster group id 6
# The total no. of stars in cluster id  6  is 7
# Sorted ids of this cluster is [14946122 17736446 19224491 24150783 42481897 43565926 45006599]
#
# Found the id [14946122] at the index [6462503] in this snapshot
#
# Found the id [17736446] at the index [6462500] in this snapshot
#
# Found the id [19224491] at the index [6462502] in this snapshot
#
# Found the id [24150783] at the index [1475144] in this snapshot
#
# Found the id [42481897] at the index [6462508] in this snapshot
#
# Found the id [43565926] at the index [1475143] in this snapshot
#
# Found the id [45006599] at the index [6462499] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [6462503 6462500 6462502 1475144 6462508 1475143 6462499]
#
#
# Now Matching the ids of the snapshot 591  with the cluster group id 7
# The total no. of stars in cluster id  7  is 6
# Sorted ids of this cluster is [26799622 31366904 33517759 43344184 59273944 66179841]
#
# Found the id [26799622] at the index [6845470] in this snapshot
#
# Found the id [31366904] at the index [6845475] in this snapshot
#
# Found the id [33517759] at the index [6845469] in this snapshot
#
# Found the id [43344184] at the index [6845468] in this snapshot
#
# Found the id [59273944] at the index [6845437] in this snapshot
#
# Found the id [66179841] at the index [6845467] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [6845470 6845475 6845469 6845468 6845437 6845467]
#
#
# Now Matching the ids of the snapshot 591  with the cluster group id 8
# The total no. of stars in cluster id  8  is 6
# Sorted ids of this cluster is [ 8078634 30501388 37124620 59473105 63656844 73852946]
#
# Found the id [8078634] at the index [7588672] in this snapshot
#
# Found the id [30501388] at the index [7588674] in this snapshot
#
# Found the id [37124620] at the index [7588667] in this snapshot
#
# Found the id [59473105] at the index [7588675] in this snapshot
#
# Found the id [63656844] at the index [7588671] in this snapshot
#
# Found the id [73852946] at the index [7588670] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [7588672 7588674 7588667 7588675 7588671 7588670]
#
#
# Now Matching the ids of the snapshot 591  with the cluster group id 9
# The total no. of stars in cluster id  9  is 5
# Sorted ids of this cluster is [22688626 25015777 32104848 55232462 65198437]
#
# Found the id [22688626] at the index [16509035] in this snapshot
#
# Found the id [25015777] at the index [16509047] in this snapshot
#
# Found the id [32104848] at the index [16509048] in this snapshot
#
# Found the id [55232462] at the index [16509046] in this snapshot
#
# Found the id [65198437] at the index [16509034] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [16509035 16509047 16509048 16509046 16509034]
#
#
# Now Matching the ids of the snapshot 591  with the cluster group id 10
# The total no. of stars in cluster id  10  is 5
# Sorted ids of this cluster is [ 9748455  9749625 13096782 20388585 35390117]
#
# Found the id [9748455] at the index [14694800] in this snapshot
#
# Found the id [9749625] at the index [14694809] in this snapshot
#
# Found the id [13096782] at the index [14694790] in this snapshot
#
# Found the id [20388585] at the index [14694793] in this snapshot
#
# Found the id [35390117] at the index [14694786] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [14694800 14694809 14694790 14694793 14694786]
#
#
# Now Matching the ids of the snapshot 591  with the cluster group id 11
# The total no. of stars in cluster id  11  is 5
# Sorted ids of this cluster is [11552938 18551404 23608604 36698843 68738504]
#
# Found the id [11552938] at the index [12893419] in this snapshot
#
# Found the id [18551404] at the index [12893420] in this snapshot
#
# Found the id [23608604] at the index [12893415] in this snapshot
#
# Found the id [36698843] at the index [12893412] in this snapshot
#
# Found the id [68738504] at the index [12893417] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [12893419 12893420 12893415 12893412 12893417]
#
#
# Now Matching the ids of the snapshot 591  with the cluster group id 12
# The total no. of stars in cluster id  12  is 5
# Sorted ids of this cluster is [11705068 36488475 39925280 40237329 71222733]
#
# Found the id [11705068] at the index [9315460] in this snapshot
#
# Found the id [36488475] at the index [9315452] in this snapshot
#
# Found the id [39925280] at the index [9315455] in this snapshot
#
# Found the id [40237329] at the index [9315458] in this snapshot
#
# Found the id [71222733] at the index [9315457] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [9315460 9315452 9315455 9315458 9315457]
#
#
# Now Matching the ids of the snapshot 591  with the cluster group id 13
# The total no. of stars in cluster id  13  is 5
# Sorted ids of this cluster is [27767024 59622229 62412117 69193608 75470406]
#
# Found the id [27767024] at the index [6122226] in this snapshot
#
# Found the id [59622229] at the index [6122223] in this snapshot
#
# Found the id [62412117] at the index [6122224] in this snapshot
#
# Found the id [69193608] at the index [6122227] in this snapshot
#
# Found the id [75470406] at the index [6122225] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [6122226 6122223 6122224 6122227 6122225]
#
#
# Now Matching the ids of the snapshot 591  with the cluster group id 14
# The total no. of stars in cluster id  14  is 5
# Sorted ids of this cluster is [ 9910784 31078456 35148679 54122687 67035242]
#
# Found the id [9910784] at the index [15361107] in this snapshot
#
# Found the id [31078456] at the index [15361110] in this snapshot
#
# Found the id [35148679] at the index [1503497] in this snapshot
#
# Found the id [54122687] at the index [1503500] in this snapshot
#
# Found the id [67035242] at the index [15361106] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [15361107 15361110  1503497  1503500 15361106]
#
#  Stored tracked data of all stars clusters in the snapshot no. 591 to filename: tracked_clusters_at_snapshot_591.pkl
# #####

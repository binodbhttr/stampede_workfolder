# %%
#!/usr/bin/env python
# coding: utf-8

#this file will load snapshots and store details of the tracked star cluster thoroughout the snapshots into individual files available at ./data

import gizmo_analysis as gizmo
import utilities as ut
from matplotlib import pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
from sl_utilities import distinct_colours as dc
from sl_utilities import distance_functions
import os
import pickle

# %%
simname = 'm12f_res7100_mhdcv'
simdir = '/scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/'

# %%
## NOTE: Inputs can be either position or velocity in the "Translated Box Coordinate Frame"
## If inputs are positions in the "Translated Box Coordinate Frame", outputs will be positions in the "Loebman Lab Coordinate Frame"
## If inputs are velocities in the "Translated Box Coordinate Frame", outputs will be velocities in the "Loebman Lab Coordinate Frame"

def ll_coordinate_transformation(rotation_matrix, x_translated_box_coordinate, y_translated_box_coordinate, z_translated_box_coordinate):
    
    # identifying the elements of the True Rotation Matrix
    rot_mat11 = rotation_matrix[0][0][0]
    rot_mat12 = rotation_matrix[0][0][1]
    rot_mat13 = rotation_matrix[0][0][2]
    
    rot_mat21 = rotation_matrix[0][1][0]
    rot_mat22 = rotation_matrix[0][1][1]
    rot_mat23 = rotation_matrix[0][1][2]
    
    rot_mat31 = rotation_matrix[0][2][0]
    rot_mat32 = rotation_matrix[0][2][1]
    rot_mat33 = rotation_matrix[0][2][2]
    
    ''' 
        Finding the three "True Rotation Angles": rot_angle_0, rot_angle_1 and rot_angle_2
        
        Note that there are eight possible sets of rotation angles.

        We use the following approach to know which set of rotation angles is the "True Rotation Angles" set.
        For each of the eight possible sets of rotation angles, 
        we compute the rotation matrix (let's call it the Recovered Rotation Matrix), 
        and we check which of these "Recovered Rotation Matrices" matches the "True Rotation Matrix."
        
    '''
    
    rot_angle_0 = [] 
    rot_angle_1 = []
    rot_angle_2 = []

    for k in range (2):
        for j in range (2):
            for i in range (2):
                recovered_rotation_angles = [0, 0, 0]
                recovered_rotation_angles[0] =  np.arctan(-rot_mat32/rot_mat33) + (i*np.pi)
                recovered_rotation_angles[1] =  np.arctan(rot_mat31/(np.sqrt(1- (rot_mat31**2)))) + (j*np.pi)
                recovered_rotation_angles[2] =  np.arctan(-rot_mat21/rot_mat11) + (k*np.pi)

                recovered_rot_mat11 = np.cos(recovered_rotation_angles[1]) * np.cos(recovered_rotation_angles[2])
                recovered_rot_mat12 = np.cos(recovered_rotation_angles[0]) * np.sin(recovered_rotation_angles[2]) + np.sin(recovered_rotation_angles[0]) * np.sin(recovered_rotation_angles[1]) * np.cos(recovered_rotation_angles[2])
                recovered_rot_mat13 = np.sin(recovered_rotation_angles[0]) * np.sin(recovered_rotation_angles[2]) - np.cos(recovered_rotation_angles[0]) * np.sin(recovered_rotation_angles[1]) * np.cos(recovered_rotation_angles[2])
                recovered_rot_mat21 = -np.cos(recovered_rotation_angles[1]) * np.sin(recovered_rotation_angles[2])
                recovered_rot_mat22 = np.cos(recovered_rotation_angles[0]) * np.cos(recovered_rotation_angles[2]) - np.sin(recovered_rotation_angles[0]) * np.sin(recovered_rotation_angles[1]) * np.sin(recovered_rotation_angles[2])
                recovered_rot_mat23 = np.sin(recovered_rotation_angles[0]) * np.cos(recovered_rotation_angles[2]) + np.cos(recovered_rotation_angles[0]) * np.sin(recovered_rotation_angles[1]) * np.sin(recovered_rotation_angles[2])
                recovered_rot_mat31 = np.sin(recovered_rotation_angles[1])
                recovered_rot_mat32 = -np.sin(recovered_rotation_angles[0]) * np.cos(recovered_rotation_angles[1])
                recovered_rot_mat33 = np.cos(recovered_rotation_angles[0]) * np.cos(recovered_rotation_angles[1])

                if ((np.round(recovered_rot_mat11.astype('float64'), 3) == np.round(rot_mat11.astype('float64'), 3)) & 
                    (np.round(recovered_rot_mat12.astype('float64'), 3) == np.round(rot_mat12.astype('float64'), 3)) & 
                    (np.round(recovered_rot_mat13.astype('float64'), 3) == np.round(rot_mat13.astype('float64'), 3)) &
                    (np.round(recovered_rot_mat21.astype('float64'), 3) == np.round(rot_mat21.astype('float64'), 3)) &
                    (np.round(recovered_rot_mat22.astype('float64'), 3) == np.round(rot_mat22.astype('float64'), 3)) &
                    (np.round(recovered_rot_mat23.astype('float64'), 3) == np.round(rot_mat23.astype('float64'), 3)) &
                    (np.round(recovered_rot_mat31.astype('float64'), 3) == np.round(rot_mat31.astype('float64'), 3)) &
                    (np.round(recovered_rot_mat32.astype('float64'), 3) == np.round(rot_mat32.astype('float64'), 3)) &
                    (np.round(recovered_rot_mat33.astype('float64'), 3) == np.round(rot_mat33.astype('float64'), 3))):

                    rot_angle_0.append(recovered_rotation_angles[0])
                    rot_angle_1.append(recovered_rotation_angles[1])
                    rot_angle_2.append(recovered_rotation_angles[2])

                    break
                    del(recovered_rotation_angles)
                    
    ''' 
        Constructing the "Loebman Lab Transformation Matrix": ll_tans_matij   
    '''
    
    ll_trans_mat11 = np.cos(rot_angle_1)
    ll_trans_mat12 = np.sin(rot_angle_0) * np.sin(rot_angle_1)
    ll_trans_mat13 = - np.cos(rot_angle_0) * np.sin(rot_angle_1)
    ll_trans_mat21 = np.zeros(1)
    ll_trans_mat22 = np.cos(rot_angle_0)
    ll_trans_mat23 = np.sin(rot_angle_0) 
    ll_trans_mat31 = np.sin(rot_angle_1)
    ll_trans_mat32 = -np.sin(rot_angle_0) * np.cos(rot_angle_1)
    ll_trans_mat33 = np.cos(rot_angle_0) * np.cos(rot_angle_1)
    
    '''
        Finding coordinate of particles in the "Loebman Lab Coordinate System": x_ll, y_ll and z_ll
    '''
    
    x_ll = (ll_trans_mat11*x_translated_box_coordinate) + (ll_trans_mat12*y_translated_box_coordinate) + (ll_trans_mat13*z_translated_box_coordinate)
    y_ll = (ll_trans_mat21*x_translated_box_coordinate) + (ll_trans_mat22*y_translated_box_coordinate) + (ll_trans_mat23*z_translated_box_coordinate)
    z_ll = (ll_trans_mat31*x_translated_box_coordinate) + (ll_trans_mat32*y_translated_box_coordinate) + (ll_trans_mat33*z_translated_box_coordinate)
    
    position_ll = np.asarray((x_ll, y_ll, z_ll)).T
    
    return position_ll

# %%
snapshot_start=680
snapshot_end=696 #ran out of memory after 646


#Loading the sample cluster to be tracked and sorting its id and id_child
snapnumber=588 #Remember to change it if you  are changing the star cluster you are tracking in given snapshot

path="/home1/07428/binod/work2/data/m12f_588_clusters_tracked_data_b4n5_pkl_llc_fixed/" #creating a path to store the data only if it does not exist
if not os.path.exists(path):
    os.makedirs(path)

###############################################
###############################################
#loading data of all clusters (id, id_children and all)

cluster_file_name="fire2_clusters_"+simname+"_snapshot_"+str(snapnumber)+"_b4n5_llc_fixed.pkl"

with open(path+cluster_file_name, "rb") as fp:
    import_cluster = pickle.load(fp)

'''
import_cluster is a dictionary which is a collection of dictionaries for each cluster.
It was exported as follows from the program that tracked the clusters.
Note keys might have changed. Make a test run by importing the pkl file that contains the cluster info. 

cluster1={"cluster_groupid":grpid1,"no_of_star":nstar1,"id":id1,"id_children":id_children1}
cluster2={"cluster_groupid":grpid2,"no_of_star":nstar2,"id":id2,"id_children":id_children2}
cluster3={"cluster_groupid":grpid3,"no_of_star":nstar3,"id":id3,"id_children":id_children3} and so on
export_cluster={1:cluster1,2:cluster2,3:cluster3,4:cluster4,5:cluster5,6:cluster6,7:cluster7,8:cluster8,9:cluster9,10:cluster10}
path="./"
file_name="clusters_"+simname+"_snapshot_"+str(snapshot) 
with open(path+file_name, 'wb') as output:
    pickle.dump(export_cluster, output)

#####3
To access id from say cluster 2, use import_cluster[2]["id"]
'''
################################################################
################################################################





################################################################
################################################################
###Now let's create a function for find the matching ids in the next snapshot using a function
def matchids(id_current,id_child_current,id_next,id_child_next,id_generation_next): #this function returns the index of the ids in the next snapshot that match with the current
    ind=np.array(0)
    for i in range(len(id_current)):
        match=np.where((id_next==id_current[i])&(id_child_next==id_child_current[i])&(id_generation_next<30)) #Also add id_generations<30
        print("\nFound the id",id_next[match],"at the index",match[0],"in this snapshot")
        ind=np.append(ind,match)
    ind_tracked_id_next=ind[1:len(ind)]  #The extra element in the beginning is removed by this process
    print("\nThese are the indices of the ids that matched in current snapshot\n",ind_tracked_id_next)
    return ind_tracked_id_next  
################################################################
################################################################


total_clusters=len(import_cluster)         #count the total no. of clusters we have in clusters file
total_snaps=snapshot_end-snapshot_start+1  #count the total no. of snapshots we are going to track
snap=snapshot_start                        #Mark the beginning of the snapshot
test_cluster=1                             #Mark the beginning of the cluster that we would be tracking
ind_tracked={}                             #finding the indices of the tracked stars in each snapshot for each cluster.

tracked_data_all_clusters_each_snap={}     #dictionary for storing data from all clusters and in each snapshot


#Algorithm followed for scanning each snapshot for all given star clusters is as follows
'''
Step1: Load the star clusters from the given file
Step2: snap=snapshot to begin with
Step3: Load id, id_child, id_genearation, age, mass, positoins, velocities and everything you want form the snapshot snap
Step4: Now assign test_cluster=1 which is the star cluster to begin with for tracking
Step5: Track the stars from the test_cluster using the id, id_child and id_generation
Step6: Get the information of the tracked stars id, id_child, id_genearation, age, mass, positoins, velocities and everything you want form the snapshot snap
        Save the information you gathered into a dictionary tracked_data_all_clusters
        test_cluster+=1
Step7: Is test_cluster<total_clusters? If yes goto step 5 else goto step 8
Step8: All clusters were tracked for the given snapshot
        Store the data gathered from all clusters in given snapshot to a dictionary tracked_data_all_clusters_each_snap
        It has the format {596:{1:{"x_tracked":[array],...},2:{"x_tracked":[array],...}},597:{1:{"x_tracked":[array],..},2:{"x_tracked":[array],..}..}}
        snap+=1
        Is snap<total_snaps? If yes goto step 3 else goto Step 9
Step9: End

'''




for i in range(total_snaps):               #we run a for loop until the end of all snapshots
    part=gizmo.io.Read.read_snapshots(['star'],'snapshot_index', snap, simulation_name=simname, simulation_directory=simdir, assign_hosts=True, assign_hosts_rotation=True)               #snap is the snapshot number here that changes everytime the loop iterates. It starts with sanpshot_start

    id=part['star'].prop('id')
    id_child=part['star'].prop('id.child')
    id_generation=part['star'].prop('id.generation')
    age=part['star'].prop('age')
    #x=part['star'].prop('host.distance.principal')[:,0] #x component of the position of all stars 
    #y=part['star'].prop('host.distance.principal')[:,1] #y component of the position of all stars
    #z=part['star'].prop('host.distance.principal')[:,2] #z component of the position of all stars
    x_box=part['star'].prop('host.distance')[:,0]
    y_box=part['star'].prop('host.distance')[:,1]
    #z=part['star'].prop('host.distance.principal')[:,2] 
    z_box=part['star'].prop('host.distance')[:,2]
    
    n=len(x_box) # counting the total no. of star particles
    #vx=part['star'].prop('host.velocity.principal')[:,0]
    #vy=part['star'].prop('host.velocity.principal')[:,1]
    #vz=part['star'].prop('host.velocity.principal')[:,2]
    
    vx_box=part['star'].prop('host.velocity')[:,0]
    vy_box=part['star'].prop('host.velocity')[:,1]
    vz_box=part['star'].prop('host.velocity')[:,2]
    
    
    mass=part['star']['mass'] #mass of all stars in snapshot 691
    # compute 3-D velocity in cylindrical coordinates
    # first value is along the major axes (positive definite)
    # secod value is azimuthal velocity in the plane of the disk (positive definite)
    # third value is vertical velocity wrt the disk (signed)
    vR_cyl=part['star'].prop('host.velocity.principal.cylindrical')[:,0]
    vphi_cyl=part['star'].prop('host.velocity.principal.cylindrical')[:,1]
    vz_cyl=part['star'].prop('host.velocity.principal.cylindrical')[:,2]
    print("\n#########\n############\nLoaded id,id_child,age,x,y,z,vx,vy,vz,mass, cylindrical velocities and number of particles for snapshot no.",snap)
    print("Total no of particles in this shapshot no.",snap,"is",n)


    #Converting x,y,z and vx,vy,vz into llc
    rm = part.host['rotation']     

    x_llc=ll_coordinate_transformation(rm, x_box, y_box, z_box)[:,0]
    y_llc=ll_coordinate_transformation(rm, x_box, y_box, z_box)[:,1]
    z_llc=ll_coordinate_transformation(rm, x_box, y_box, z_box)[:,2]
    
    
    vx_llc=ll_coordinate_transformation(rm, vx_box, vy_box, vz_box)[:,0]
    vy_llc=ll_coordinate_transformation(rm, vx_box, vy_box, vz_box)[:,1]
    vz_llc=ll_coordinate_transformation(rm, vx_box, vy_box, vz_box)[:,2]


    ################################################################
    ################################################################
    ### Now matching the IDs of this snapshot with the ids of all clusters
    test_cluster=1                       #This is the test cluster to begin with. It resets to 1 at each snapshot 
    tracked_data_all_clusters={}         #This dictionary keeps the tracked information for all star clusters in given snapshot. It also resets with snapshots.
    for j in range(total_clusters):
        tracked_data={}                    #This dictionary holds the tracked information for a cluster temporarily until it is pushed to tracked_data_all_clusters
        print("\n\nNow Matching the ids of the snapshot",snap," with the cluster group id",test_cluster)
        id_test_cluster=import_cluster[test_cluster]["id"]
        id_child_test_cluster=import_cluster[test_cluster]["id_children"]
        sortind=np.argsort(id_test_cluster)
        id_test_cluster_sorted=id_test_cluster[sortind]
        id_child_test_cluster_sorted=id_child_test_cluster[sortind]
        print("The total no. of stars in cluster id ",test_cluster," is",len(id_test_cluster_sorted))
        print("Sorted ids of this cluster is",id_test_cluster_sorted)
        ind_tracked=matchids(id_test_cluster_sorted,id_child_test_cluster_sorted,id,id_child,id_generation)

        ################################################################
        ################################################################
        #Now finding the postion, velocities, age and mass of the tracked stars in each snapshots
        age_tracked=age[ind_tracked]
        x_tracked=x_llc[ind_tracked]
        y_tracked=y_llc[ind_tracked]
        z_tracked=z_llc[ind_tracked]
        vx_tracked=vx_llc[ind_tracked]
        vy_tracked=vy_llc[ind_tracked]
        vz_tracked=vz_llc[ind_tracked]
        mass_tracked=mass[ind_tracked]
        vR_cyl_tracked=vR_cyl[ind_tracked]
        vphi_cyl_tracked=vphi_cyl[ind_tracked]
        vz_cyl_tracked=vz_cyl[ind_tracked]


        ################################################################
        ################################################################
        #Now calculating center of mass and realted properties  
        xcm=distance_functions.cm(x_tracked,mass_tracked)
        ycm=distance_functions.cm(y_tracked,mass_tracked)
        zcm=distance_functions.cm(z_tracked,mass_tracked)
        delta_rxyz=distance_functions.dr(x_tracked,y_tracked,z_tracked,mass_tracked)
        rmax=distance_functions.drmax(x_tracked,y_tracked,z_tracked,mass_tracked)
        ymax=(ycm+1.1*rmax)
        ymin=(ycm-1.1*rmax)
        xmax=(xcm+1.1*rmax)
        xmin=(xcm-1.1*rmax)
        avg_delta_rxyz=np.mean(np.absolute(delta_rxyz))


        ################################################################
        ################################################################
        #Now lets write our tracked data from each snapshots to a file
        tracked_data={"ind_tracked":ind_tracked,"age_tracked":age_tracked,"x_tracked":x_tracked,"y_tracked":y_tracked,"z_tracked":z_tracked,
        "vx_tracked":vx_tracked,"vy_tracked":vy_tracked,"vz_tracked":vz_tracked,
        "mass_tracked":mass_tracked,"xcm":xcm,"ycm":ycm,"zcm":zcm,"delta_rxyz":delta_rxyz,"rmax":rmax,
        "ymax":ymax,"ymin":ymin,"xmax":xmax,"xmin":xmin,"avg_delta_rxyz":avg_delta_rxyz,
        "vR_cyl_tracked":vR_cyl_tracked,"vphi_cyl_tracked":vphi_cyl_tracked,"vz_cyl_tracked":vz_cyl_tracked}


        tracked_data_all_clusters.update({test_cluster:tracked_data}) #access it using tracked_data_all_clusters[clusterid]["key"]
        test_cluster+=1

        #We have collected all tracked information for our test clusters for one snapshot now which is in dictionary tracked_data_all_clusters.
        #We would store that dictionary in a pickle file as a backup data from each snapshot about or all star cluster.
        ###Now moving out of the j loop. We scanned all clusters and stored the tracked data into a dictionary tracked_data_all_clusters  
    file_name="tracked_clusters_at_snapshot_"+str(snap)+"_llc_fix.pkl"
    with open(path+file_name, 'wb') as output:
        pickle.dump(tracked_data_all_clusters, output)
    print("\n Stored tracked data of all stars clusters in the snapshot no.",snap,"to filename:",file_name,"\n#####\n")
    #Note we are still in i loop which is scanning each snapshot !!!!!!!!!!!!!!!!!!
    tracked_data_all_clusters_each_snap.update({snap:tracked_data_all_clusters}) 
    snap=snap+1

    #Came out of i loop 
  
#Finally we scanned through all the snapshots and now we come out of the loop to store the final file that contains all the tracked information of all clusters 
#Now we store the tracked data of all clusters into a dictionary with snapshot number as the key. This would be our final dictionary of dictinaries. 
with open(path+"total_data_tracked_clusters_all_snapshots.pkl", 'wb') as output:
    pickle.dump(tracked_data_all_clusters_each_snap, output) #access the data using tracked_data_all_clusters_each_snap[snapshot][cluster_id]["x_tracked"])
  
#Expected Result: tracked_data_all_clusters_each_snap={596:{1:tracked_data,2:tracked_data..},597:{1:tracked_data,2:tracked_data..upto total clusters},598....     upto total snapshots}
# Out:
# # in utilities.simulation.Snapshot():
# * reading:  scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/snapshot_times.txt
#
#   using snapshot index = 680, redshift = 0.001
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/output/snapshot_680.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 81363848 particles
#     dark2     (id = 2): 7086235 particles
#     gas       (id = 0): 64081646 particles
#     star      (id = 4): 17869525 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['star']
#
# * reading particles from:
#     scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/output/snapshot_680.hdf5
#
# * reading cosmological parameters from:  scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
# ! warning: star id.child [min, max] = [0.000, 4.254e9]
# ! warning: star mass [min, med, max] = [3245.210, 5411.753, 1.375e5]
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/track/host_coordinates.hdf5
#   host1 position = (38709.92, 47672.47, 46763.67) [kpc comoving]
#   host1 velocity = (-161.3, 168.1, 104.1) [km / s]
#   host1 axis ratios = (0.19, 0.19, 0.99)
#   host1 R_90 = 12.3 kpc
#   host1 M_90 = 7.5e+10 Msun
#
#
# #########
# ############
# Loaded id,id_child,age,x,y,z,vx,vy,vz,mass, cylindrical velocities and number of particles for snapshot no. 680
# Total no of particles in this shapshot no. 680 is 17869525
#
#
# Now Matching the ids of the snapshot 680  with the cluster group id 1
# The total no. of stars in cluster id  1  is 9
# Sorted ids of this cluster is [12233101 15939420 16676135 21789997 35600867 36199746 38743397 52460765
#  79474586]
#
# Found the id [12233101] at the index [12389726] in this snapshot
#
# Found the id [15939420] at the index [12389727] in this snapshot
#
# Found the id [16676135] at the index [12389608] in this snapshot
#
# Found the id [21789997] at the index [10354530] in this snapshot
#
# Found the id [35600867] at the index [12389700] in this snapshot
#
# Found the id [36199746] at the index [12389609] in this snapshot
#
# Found the id [38743397] at the index [12389732] in this snapshot
#
# Found the id [52460765] at the index [12389728] in this snapshot
#
# Found the id [79474586] at the index [12389731] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [12389726 12389727 12389608 10354530 12389700 12389609 12389732 12389728
#  12389731]
#
#
# Now Matching the ids of the snapshot 680  with the cluster group id 2
# The total no. of stars in cluster id  2  is 8
# Sorted ids of this cluster is [ 6288525 13442273 15683027 23830710 35882027 44637212 47692615 55510626]
#
# Found the id [6288525] at the index [1546902] in this snapshot
#
# Found the id [13442273] at the index [1546909] in this snapshot
#
# Found the id [15683027] at the index [1546898] in this snapshot
#
# Found the id [23830710] at the index [1546910] in this snapshot
#
# Found the id [35882027] at the index [1546903] in this snapshot
#
# Found the id [44637212] at the index [1546900] in this snapshot
#
# Found the id [47692615] at the index [1546901] in this snapshot
#
# Found the id [55510626] at the index [1546908] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [1546902 1546909 1546898 1546910 1546903 1546900 1546901 1546908]
#
#
# Now Matching the ids of the snapshot 680  with the cluster group id 3
# The total no. of stars in cluster id  3  is 7
# Sorted ids of this cluster is [ 6522694  9082875 17946997 19734054 29732816 40989092 57694150]
#
# Found the id [6522694] at the index [7091391] in this snapshot
#
# Found the id [9082875] at the index [7091485] in this snapshot
#
# Found the id [17946997] at the index [7091065] in this snapshot
#
# Found the id [19734054] at the index [7091482] in this snapshot
#
# Found the id [29732816] at the index [7091066] in this snapshot
#
# Found the id [40989092] at the index [7091064] in this snapshot
#
# Found the id [57694150] at the index [7091390] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [7091391 7091485 7091065 7091482 7091066 7091064 7091390]
#
#
# Now Matching the ids of the snapshot 680  with the cluster group id 4
# The total no. of stars in cluster id  4  is 7
# Sorted ids of this cluster is [31895283 48004469 51588915 60048561 63871484 68625169 74584151]
#
# Found the id [31895283] at the index [15927888] in this snapshot
#
# Found the id [48004469] at the index [15927989] in this snapshot
#
# Found the id [51588915] at the index [15927886] in this snapshot
#
# Found the id [60048561] at the index [15927887] in this snapshot
#
# Found the id [63871484] at the index [15927883] in this snapshot
#
# Found the id [68625169] at the index [15927890] in this snapshot
#
# Found the id [74584151] at the index [15927861] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [15927888 15927989 15927886 15927887 15927883 15927890 15927861]
#
#
# Now Matching the ids of the snapshot 680  with the cluster group id 5
# The total no. of stars in cluster id  5  is 7
# Sorted ids of this cluster is [17432067 18309009 43044321 46292834 54644758 60039322 79765310]
#
# Found the id [17432067] at the index [15696184] in this snapshot
#
# Found the id [18309009] at the index [15696187] in this snapshot
#
# Found the id [43044321] at the index [15696183] in this snapshot
#
# Found the id [46292834] at the index [15696179] in this snapshot
#
# Found the id [54644758] at the index [15696185] in this snapshot
#
# Found the id [60039322] at the index [15696235] in this snapshot
#
# Found the id [79765310] at the index [15696181] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [15696184 15696187 15696183 15696179 15696185 15696235 15696181]
#
#
# Now Matching the ids of the snapshot 680  with the cluster group id 6
# The total no. of stars in cluster id  6  is 7
# Sorted ids of this cluster is [14946122 17736446 19224491 24150783 42481897 43565926 45006599]
#
# Found the id [14946122] at the index [16896451] in this snapshot
#
# Found the id [17736446] at the index [16896449] in this snapshot
#
# Found the id [19224491] at the index [16896452] in this snapshot
#
# Found the id [24150783] at the index [16896338] in this snapshot
#
# Found the id [42481897] at the index [16896463] in this snapshot
#
# Found the id [43565926] at the index [16896337] in this snapshot
#
# Found the id [45006599] at the index [16896450] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [16896451 16896449 16896452 16896338 16896463 16896337 16896450]
#
#
# Now Matching the ids of the snapshot 680  with the cluster group id 7
# The total no. of stars in cluster id  7  is 6
# Sorted ids of this cluster is [26799622 31366904 33517759 43344184 59273944 66179841]
#
# Found the id [26799622] at the index [7092072] in this snapshot
#
# Found the id [31366904] at the index [7092089] in this snapshot
#
# Found the id [33517759] at the index [7092074] in this snapshot
#
# Found the id [43344184] at the index [7092073] in this snapshot
#
# Found the id [59273944] at the index [7092934] in this snapshot
#
# Found the id [66179841] at the index [7093005] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [7092072 7092089 7092074 7092073 7092934 7093005]
#
#
# Now Matching the ids of the snapshot 680  with the cluster group id 8
# The total no. of stars in cluster id  8  is 6
# Sorted ids of this cluster is [ 8078634 30501388 37124620 59473105 63656844 73852946]
#
# Found the id [8078634] at the index [10591782] in this snapshot
#
# Found the id [30501388] at the index [10591786] in this snapshot
#
# Found the id [37124620] at the index [10591784] in this snapshot
#
# Found the id [59473105] at the index [10591781] in this snapshot
#
# Found the id [63656844] at the index [10591783] in this snapshot
#
# Found the id [73852946] at the index [10591734] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [10591782 10591786 10591784 10591781 10591783 10591734]
#
#
# Now Matching the ids of the snapshot 680  with the cluster group id 9
# The total no. of stars in cluster id  9  is 5
# Sorted ids of this cluster is [22688626 25015777 32104848 55232462 65198437]
#
# Found the id [22688626] at the index [10551401] in this snapshot
#
# Found the id [25015777] at the index [10550927] in this snapshot
#
# Found the id [32104848] at the index [10551402] in this snapshot
#
# Found the id [55232462] at the index [10551403] in this snapshot
#
# Found the id [65198437] at the index [10551404] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [10551401 10550927 10551402 10551403 10551404]
#
#
# Now Matching the ids of the snapshot 680  with the cluster group id 10
# The total no. of stars in cluster id  10  is 5
# Sorted ids of this cluster is [ 9748455  9749625 13096782 20388585 35390117]
#
# Found the id [9748455] at the index [9691953] in this snapshot
#
# Found the id [9749625] at the index [9691951] in this snapshot
#
# Found the id [13096782] at the index [9691950] in this snapshot
#
# Found the id [20388585] at the index [9691949] in this snapshot
#
# Found the id [35390117] at the index [9691957] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [9691953 9691951 9691950 9691949 9691957]
#
#
# Now Matching the ids of the snapshot 680  with the cluster group id 11
# The total no. of stars in cluster id  11  is 5
# Sorted ids of this cluster is [11552938 18551404 23608604 36698843 68738504]
#
# Found the id [11552938] at the index [11146560] in this snapshot
#
# Found the id [18551404] at the index [11146559] in this snapshot
#
# Found the id [23608604] at the index [11146577] in this snapshot
#
# Found the id [36698843] at the index [11146575] in this snapshot
#
# Found the id [68738504] at the index [11146576] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [11146560 11146559 11146577 11146575 11146576]
#
#
# Now Matching the ids of the snapshot 680  with the cluster group id 12
# The total no. of stars in cluster id  12  is 5
# Sorted ids of this cluster is [11705068 36488475 39925280 40237329 71222733]
#
# Found the id [11705068] at the index [11238925] in this snapshot
#
# Found the id [36488475] at the index [12566188] in this snapshot
#
# Found the id [39925280] at the index [11238927] in this snapshot
#
# Found the id [40237329] at the index [11238924] in this snapshot
#
# Found the id [71222733] at the index [11238926] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [11238925 12566188 11238927 11238924 11238926]
#
#
# Now Matching the ids of the snapshot 680  with the cluster group id 13
# The total no. of stars in cluster id  13  is 5
# Sorted ids of this cluster is [27767024 59622229 62412117 69193608 75470406]
#
# Found the id [27767024] at the index [6576180] in this snapshot
#
# Found the id [59622229] at the index [6576176] in this snapshot
#
# Found the id [62412117] at the index [6576179] in this snapshot
#
# Found the id [69193608] at the index [6576121] in this snapshot
#
# Found the id [75470406] at the index [6576178] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [6576180 6576176 6576179 6576121 6576178]
#
#
# Now Matching the ids of the snapshot 680  with the cluster group id 14
# The total no. of stars in cluster id  14  is 5
# Sorted ids of this cluster is [ 9910784 31078456 35148679 54122687 67035242]
#
# Found the id [9910784] at the index [10351900] in this snapshot
#
# Found the id [31078456] at the index [10351898] in this snapshot
#
# Found the id [35148679] at the index [292455] in this snapshot
#
# Found the id [54122687] at the index [292456] in this snapshot
#
# Found the id [67035242] at the index [1778987] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [10351900 10351898   292455   292456  1778987]
#
#  Stored tracked data of all stars clusters in the snapshot no. 680 to filename: tracked_clusters_at_snapshot_680_llc_fix.pkl
# #####
#
#
# # in utilities.simulation.Snapshot():
# * reading:  scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/snapshot_times.txt
#
#   using snapshot index = 681, redshift = 0.001
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/output/snapshot_681.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 81363848 particles
#     dark2     (id = 2): 7086235 particles
#     gas       (id = 0): 64080387 particles
#     star      (id = 4): 17870784 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['star']
#
# * reading particles from:
#     scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/output/snapshot_681.hdf5
#
# * reading cosmological parameters from:  scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
# ! warning: star id.child [min, max] = [0.000, 4.254e9]
# ! warning: star mass [min, med, max] = [3245.210, 5411.765, 1.375e5]
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/track/host_coordinates.hdf5
#   host1 position = (38709.76, 47672.64, 46763.78) [kpc comoving]
#   host1 velocity = (-161.4, 168.1, 104.1) [km / s]
#   host1 axis ratios = (0.19, 0.19, 0.99)
#   host1 R_90 = 12.3 kpc
#   host1 M_90 = 7.5e+10 Msun
#
#
# #########
# ############
# Loaded id,id_child,age,x,y,z,vx,vy,vz,mass, cylindrical velocities and number of particles for snapshot no. 681
# Total no of particles in this shapshot no. 681 is 17870784
#
#
# Now Matching the ids of the snapshot 681  with the cluster group id 1
# The total no. of stars in cluster id  1  is 9
# Sorted ids of this cluster is [12233101 15939420 16676135 21789997 35600867 36199746 38743397 52460765
#  79474586]
#
# Found the id [12233101] at the index [16745636] in this snapshot
#
# Found the id [15939420] at the index [16745637] in this snapshot
#
# Found the id [16676135] at the index [16745600] in this snapshot
#
# Found the id [21789997] at the index [16192011] in this snapshot
#
# Found the id [35600867] at the index [16745638] in this snapshot
#
# Found the id [36199746] at the index [16745599] in this snapshot
#
# Found the id [38743397] at the index [16745633] in this snapshot
#
# Found the id [52460765] at the index [16745634] in this snapshot
#
# Found the id [79474586] at the index [16745631] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [16745636 16745637 16745600 16192011 16745638 16745599 16745633 16745634
#  16745631]
#
#
# Now Matching the ids of the snapshot 681  with the cluster group id 2
# The total no. of stars in cluster id  2  is 8
# Sorted ids of this cluster is [ 6288525 13442273 15683027 23830710 35882027 44637212 47692615 55510626]
#
# Found the id [6288525] at the index [782644] in this snapshot
#
# Found the id [13442273] at the index [782652] in this snapshot
#
# Found the id [15683027] at the index [782645] in this snapshot
#
# Found the id [23830710] at the index [782653] in this snapshot
#
# Found the id [35882027] at the index [783093] in this snapshot
#
# Found the id [44637212] at the index [782651] in this snapshot
#
# Found the id [47692615] at the index [782648] in this snapshot
#
# Found the id [55510626] at the index [782650] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [782644 782652 782645 782653 783093 782651 782648 782650]
#
#
# Now Matching the ids of the snapshot 681  with the cluster group id 3
# The total no. of stars in cluster id  3  is 7
# Sorted ids of this cluster is [ 6522694  9082875 17946997 19734054 29732816 40989092 57694150]
#
# Found the id [6522694] at the index [16671889] in this snapshot
#
# Found the id [9082875] at the index [16671614] in this snapshot
#
# Found the id [17946997] at the index [16671682] in this snapshot
#
# Found the id [19734054] at the index [16671895] in this snapshot
#
# Found the id [29732816] at the index [16671681] in this snapshot
#
# Found the id [40989092] at the index [16671719] in this snapshot
#
# Found the id [57694150] at the index [16671890] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [16671889 16671614 16671682 16671895 16671681 16671719 16671890]
#
#
# Now Matching the ids of the snapshot 681  with the cluster group id 4
# The total no. of stars in cluster id  4  is 7
# Sorted ids of this cluster is [31895283 48004469 51588915 60048561 63871484 68625169 74584151]
#
# Found the id [31895283] at the index [16786550] in this snapshot
#
# Found the id [48004469] at the index [16786541] in this snapshot
#
# Found the id [51588915] at the index [16786551] in this snapshot
#
# Found the id [60048561] at the index [16786549] in this snapshot
#
# Found the id [63871484] at the index [16786548] in this snapshot
#
# Found the id [68625169] at the index [16786547] in this snapshot
#
# Found the id [74584151] at the index [16786537] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [16786550 16786541 16786551 16786549 16786548 16786547 16786537]
#
#
# Now Matching the ids of the snapshot 681  with the cluster group id 5
# The total no. of stars in cluster id  5  is 7
# Sorted ids of this cluster is [17432067 18309009 43044321 46292834 54644758 60039322 79765310]
#
# Found the id [17432067] at the index [5741324] in this snapshot
#
# Found the id [18309009] at the index [5741330] in this snapshot
#
# Found the id [43044321] at the index [5741323] in this snapshot
#
# Found the id [46292834] at the index [5741326] in this snapshot
#
# Found the id [54644758] at the index [5741321] in this snapshot
#
# Found the id [60039322] at the index [5741382] in this snapshot
#
# Found the id [79765310] at the index [5741322] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [5741324 5741330 5741323 5741326 5741321 5741382 5741322]
#
#
# Now Matching the ids of the snapshot 681  with the cluster group id 6
# The total no. of stars in cluster id  6  is 7
# Sorted ids of this cluster is [14946122 17736446 19224491 24150783 42481897 43565926 45006599]
#
# Found the id [14946122] at the index [9475021] in this snapshot
#
# Found the id [17736446] at the index [9475035] in this snapshot
#
# Found the id [19224491] at the index [9475020] in this snapshot
#
# Found the id [24150783] at the index [9474903] in this snapshot
#
# Found the id [42481897] at the index [9475034] in this snapshot
#
# Found the id [43565926] at the index [9474902] in this snapshot
#
# Found the id [45006599] at the index [9475019] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [9475021 9475035 9475020 9474903 9475034 9474902 9475019]
#
#
# Now Matching the ids of the snapshot 681  with the cluster group id 7
# The total no. of stars in cluster id  7  is 6
# Sorted ids of this cluster is [26799622 31366904 33517759 43344184 59273944 66179841]
#
# Found the id [26799622] at the index [2734185] in this snapshot
#
# Found the id [31366904] at the index [2734224] in this snapshot
#
# Found the id [33517759] at the index [2734184] in this snapshot
#
# Found the id [43344184] at the index [2734186] in this snapshot
#
# Found the id [59273944] at the index [2735451] in this snapshot
#
# Found the id [66179841] at the index [2734187] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [2734185 2734224 2734184 2734186 2735451 2734187]
#
#
# Now Matching the ids of the snapshot 681  with the cluster group id 8
# The total no. of stars in cluster id  8  is 6
# Sorted ids of this cluster is [ 8078634 30501388 37124620 59473105 63656844 73852946]
#
# Found the id [8078634] at the index [3206634] in this snapshot
#
# Found the id [30501388] at the index [3206632] in this snapshot
#
# Found the id [37124620] at the index [2594756] in this snapshot
#
# Found the id [59473105] at the index [3206944] in this snapshot
#
# Found the id [63656844] at the index [3206633] in this snapshot
#
# Found the id [73852946] at the index [10463603] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [ 3206634  3206632  2594756  3206944  3206633 10463603]
#
#
# Now Matching the ids of the snapshot 681  with the cluster group id 9
# The total no. of stars in cluster id  9  is 5
# Sorted ids of this cluster is [22688626 25015777 32104848 55232462 65198437]
#
# Found the id [22688626] at the index [8581099] in this snapshot
#
# Found the id [25015777] at the index [8581047] in this snapshot
#
# Found the id [32104848] at the index [8581090] in this snapshot
#
# Found the id [55232462] at the index [8581088] in this snapshot
#
# Found the id [65198437] at the index [8581091] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [8581099 8581047 8581090 8581088 8581091]
#
#
# Now Matching the ids of the snapshot 681  with the cluster group id 10
# The total no. of stars in cluster id  10  is 5
# Sorted ids of this cluster is [ 9748455  9749625 13096782 20388585 35390117]
#
# Found the id [9748455] at the index [10120787] in this snapshot
#
# Found the id [9749625] at the index [10120800] in this snapshot
#
# Found the id [13096782] at the index [10120801] in this snapshot
#
# Found the id [20388585] at the index [10120785] in this snapshot
#
# Found the id [35390117] at the index [10120789] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [10120787 10120800 10120801 10120785 10120789]
#
#
# Now Matching the ids of the snapshot 681  with the cluster group id 11
# The total no. of stars in cluster id  11  is 5
# Sorted ids of this cluster is [11552938 18551404 23608604 36698843 68738504]
#
# Found the id [11552938] at the index [11354582] in this snapshot
#
# Found the id [18551404] at the index [11354581] in this snapshot
#
# Found the id [23608604] at the index [11354363] in this snapshot
#
# Found the id [36698843] at the index [11354583] in this snapshot
#
# Found the id [68738504] at the index [11354584] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [11354582 11354581 11354363 11354583 11354584]
#
#
# Now Matching the ids of the snapshot 681  with the cluster group id 12
# The total no. of stars in cluster id  12  is 5
# Sorted ids of this cluster is [11705068 36488475 39925280 40237329 71222733]
#
# Found the id [11705068] at the index [13366105] in this snapshot
#
# Found the id [36488475] at the index [5891840] in this snapshot
#
# Found the id [39925280] at the index [13366107] in this snapshot
#
# Found the id [40237329] at the index [13366109] in this snapshot
#
# Found the id [71222733] at the index [13366108] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [13366105  5891840 13366107 13366109 13366108]
#
#
# Now Matching the ids of the snapshot 681  with the cluster group id 13
# The total no. of stars in cluster id  13  is 5
# Sorted ids of this cluster is [27767024 59622229 62412117 69193608 75470406]
#
# Found the id [27767024] at the index [4127161] in this snapshot
#
# Found the id [59622229] at the index [4127163] in this snapshot
#
# Found the id [62412117] at the index [4127159] in this snapshot
#
# Found the id [69193608] at the index [4127695] in this snapshot
#
# Found the id [75470406] at the index [4127162] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [4127161 4127163 4127159 4127695 4127162]
#
#
# Now Matching the ids of the snapshot 681  with the cluster group id 14
# The total no. of stars in cluster id  14  is 5
# Sorted ids of this cluster is [ 9910784 31078456 35148679 54122687 67035242]
#
# Found the id [9910784] at the index [7594511] in this snapshot
#
# Found the id [31078456] at the index [7594513] in this snapshot
#
# Found the id [35148679] at the index [12312268] in this snapshot
#
# Found the id [54122687] at the index [12312269] in this snapshot
#
# Found the id [67035242] at the index [12313527] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [ 7594511  7594513 12312268 12312269 12313527]
#
#  Stored tracked data of all stars clusters in the snapshot no. 681 to filename: tracked_clusters_at_snapshot_681_llc_fix.pkl
# #####
#
#
# # in utilities.simulation.Snapshot():
# * reading:  scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/snapshot_times.txt
#
#   using snapshot index = 682, redshift = 0.001
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/output/snapshot_682.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 81363848 particles
#     dark2     (id = 2): 7086235 particles
#     gas       (id = 0): 64079228 particles
#     star      (id = 4): 17871943 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['star']
#
# * reading particles from:
#     scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/output/snapshot_682.hdf5
#
# * reading cosmological parameters from:  scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
# ! warning: star id.child [min, max] = [0.000, 4.254e9]
# ! warning: star mass [min, med, max] = [3245.210, 5411.791, 1.375e5]
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/track/host_coordinates.hdf5
#   host1 position = (38709.59, 47672.81, 46763.89) [kpc comoving]
#   host1 velocity = (-161.6, 168.2, 104.1) [km / s]
#   host1 axis ratios = (0.19, 0.19, 0.99)
#   host1 R_90 = 12.3 kpc
#   host1 M_90 = 7.6e+10 Msun
#
#
# #########
# ############
# Loaded id,id_child,age,x,y,z,vx,vy,vz,mass, cylindrical velocities and number of particles for snapshot no. 682
# Total no of particles in this shapshot no. 682 is 17871943
#
#
# Now Matching the ids of the snapshot 682  with the cluster group id 1
# The total no. of stars in cluster id  1  is 9
# Sorted ids of this cluster is [12233101 15939420 16676135 21789997 35600867 36199746 38743397 52460765
#  79474586]
#
# Found the id [12233101] at the index [8751711] in this snapshot
#
# Found the id [15939420] at the index [8751706] in this snapshot
#
# Found the id [16676135] at the index [14675180] in this snapshot
#
# Found the id [21789997] at the index [11808589] in this snapshot
#
# Found the id [35600867] at the index [8751705] in this snapshot
#
# Found the id [36199746] at the index [14675181] in this snapshot
#
# Found the id [38743397] at the index [8751708] in this snapshot
#
# Found the id [52460765] at the index [8751707] in this snapshot
#
# Found the id [79474586] at the index [8751741] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [ 8751711  8751706 14675180 11808589  8751705 14675181  8751708  8751707
#   8751741]
#
#
# Now Matching the ids of the snapshot 682  with the cluster group id 2
# The total no. of stars in cluster id  2  is 8
# Sorted ids of this cluster is [ 6288525 13442273 15683027 23830710 35882027 44637212 47692615 55510626]
#
# Found the id [6288525] at the index [5235591] in this snapshot
#
# Found the id [13442273] at the index [5235587] in this snapshot
#
# Found the id [15683027] at the index [5235596] in this snapshot
#
# Found the id [23830710] at the index [5235592] in this snapshot
#
# Found the id [35882027] at the index [5235590] in this snapshot
#
# Found the id [44637212] at the index [5235594] in this snapshot
#
# Found the id [47692615] at the index [5235593] in this snapshot
#
# Found the id [55510626] at the index [5235595] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [5235591 5235587 5235596 5235592 5235590 5235594 5235593 5235595]
#
#
# Now Matching the ids of the snapshot 682  with the cluster group id 3
# The total no. of stars in cluster id  3  is 7
# Sorted ids of this cluster is [ 6522694  9082875 17946997 19734054 29732816 40989092 57694150]
#
# Found the id [6522694] at the index [13613084] in this snapshot
#
# Found the id [9082875] at the index [13613101] in this snapshot
#
# Found the id [17946997] at the index [5289572] in this snapshot
#
# Found the id [19734054] at the index [13613194] in this snapshot
#
# Found the id [29732816] at the index [5289574] in this snapshot
#
# Found the id [40989092] at the index [5289573] in this snapshot
#
# Found the id [57694150] at the index [13613103] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [13613084 13613101  5289572 13613194  5289574  5289573 13613103]
#
#
# Now Matching the ids of the snapshot 682  with the cluster group id 4
# The total no. of stars in cluster id  4  is 7
# Sorted ids of this cluster is [31895283 48004469 51588915 60048561 63871484 68625169 74584151]
#
# Found the id [31895283] at the index [9925422] in this snapshot
#
# Found the id [48004469] at the index [9925424] in this snapshot
#
# Found the id [51588915] at the index [9925419] in this snapshot
#
# Found the id [60048561] at the index [9925420] in this snapshot
#
# Found the id [63871484] at the index [9925421] in this snapshot
#
# Found the id [68625169] at the index [9925425] in this snapshot
#
# Found the id [74584151] at the index [9925342] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [9925422 9925424 9925419 9925420 9925421 9925425 9925342]
#
#
# Now Matching the ids of the snapshot 682  with the cluster group id 5
# The total no. of stars in cluster id  5  is 7
# Sorted ids of this cluster is [17432067 18309009 43044321 46292834 54644758 60039322 79765310]
#
# Found the id [17432067] at the index [5600001] in this snapshot
#
# Found the id [18309009] at the index [5599994] in this snapshot
#
# Found the id [43044321] at the index [5600000] in this snapshot
#
# Found the id [46292834] at the index [5599997] in this snapshot
#
# Found the id [54644758] at the index [5600003] in this snapshot
#
# Found the id [60039322] at the index [5597234] in this snapshot
#
# Found the id [79765310] at the index [5599999] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [5600001 5599994 5600000 5599997 5600003 5597234 5599999]
#
#
# Now Matching the ids of the snapshot 682  with the cluster group id 6
# The total no. of stars in cluster id  6  is 7
# Sorted ids of this cluster is [14946122 17736446 19224491 24150783 42481897 43565926 45006599]
#
# Found the id [14946122] at the index [11938820] in this snapshot
#
# Found the id [17736446] at the index [11938849] in this snapshot
#
# Found the id [19224491] at the index [11938821] in this snapshot
#
# Found the id [24150783] at the index [11938712] in this snapshot
#
# Found the id [42481897] at the index [11938848] in this snapshot
#
# Found the id [43565926] at the index [11938711] in this snapshot
#
# Found the id [45006599] at the index [11938822] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [11938820 11938849 11938821 11938712 11938848 11938711 11938822]
#
#
# Now Matching the ids of the snapshot 682  with the cluster group id 7
# The total no. of stars in cluster id  7  is 6
# Sorted ids of this cluster is [26799622 31366904 33517759 43344184 59273944 66179841]
#
# Found the id [26799622] at the index [17531569] in this snapshot
#
# Found the id [31366904] at the index [17531496] in this snapshot
#
# Found the id [33517759] at the index [17531570] in this snapshot
#
# Found the id [43344184] at the index [17531571] in this snapshot
#
# Found the id [59273944] at the index [17531890] in this snapshot
#
# Found the id [66179841] at the index [17531572] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [17531569 17531496 17531570 17531571 17531890 17531572]
#
#
# Now Matching the ids of the snapshot 682  with the cluster group id 8
# The total no. of stars in cluster id  8  is 6
# Sorted ids of this cluster is [ 8078634 30501388 37124620 59473105 63656844 73852946]
#
# Found the id [8078634] at the index [6379318] in this snapshot
#
# Found the id [30501388] at the index [6379321] in this snapshot
#
# Found the id [37124620] at the index [6379293] in this snapshot
#
# Found the id [59473105] at the index [6379319] in this snapshot
#
# Found the id [63656844] at the index [6379320] in this snapshot
#
# Found the id [73852946] at the index [5814430] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [6379318 6379321 6379293 6379319 6379320 5814430]
#
#
# Now Matching the ids of the snapshot 682  with the cluster group id 9
# The total no. of stars in cluster id  9  is 5
# Sorted ids of this cluster is [22688626 25015777 32104848 55232462 65198437]
#
# Found the id [22688626] at the index [5775799] in this snapshot
#
# Found the id [25015777] at the index [5775805] in this snapshot
#
# Found the id [32104848] at the index [5775797] in this snapshot
#
# Found the id [55232462] at the index [5775796] in this snapshot
#
# Found the id [65198437] at the index [5775800] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [5775799 5775805 5775797 5775796 5775800]
#
#
# Now Matching the ids of the snapshot 682  with the cluster group id 10
# The total no. of stars in cluster id  10  is 5
# Sorted ids of this cluster is [ 9748455  9749625 13096782 20388585 35390117]
#
# Found the id [9748455] at the index [7257953] in this snapshot
#
# Found the id [9749625] at the index [7257950] in this snapshot
#
# Found the id [13096782] at the index [7257958] in this snapshot
#
# Found the id [20388585] at the index [7257948] in this snapshot
#
# Found the id [35390117] at the index [7257954] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [7257953 7257950 7257958 7257948 7257954]
#
#
# Now Matching the ids of the snapshot 682  with the cluster group id 11
# The total no. of stars in cluster id  11  is 5
# Sorted ids of this cluster is [11552938 18551404 23608604 36698843 68738504]
#
# Found the id [11552938] at the index [11591585] in this snapshot
#
# Found the id [18551404] at the index [11591586] in this snapshot
#
# Found the id [23608604] at the index [11591602] in this snapshot
#
# Found the id [36698843] at the index [11591603] in this snapshot
#
# Found the id [68738504] at the index [11591604] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [11591585 11591586 11591602 11591603 11591604]
#
#
# Now Matching the ids of the snapshot 682  with the cluster group id 12
# The total no. of stars in cluster id  12  is 5
# Sorted ids of this cluster is [11705068 36488475 39925280 40237329 71222733]
#
# Found the id [11705068] at the index [4667589] in this snapshot
#
# Found the id [36488475] at the index [13972651] in this snapshot
#
# Found the id [39925280] at the index [4667588] in this snapshot
#
# Found the id [40237329] at the index [4667587] in this snapshot
#
# Found the id [71222733] at the index [4667602] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [ 4667589 13972651  4667588  4667587  4667602]
#
#
# Now Matching the ids of the snapshot 682  with the cluster group id 13
# The total no. of stars in cluster id  13  is 5
# Sorted ids of this cluster is [27767024 59622229 62412117 69193608 75470406]
#
# Found the id [27767024] at the index [4058557] in this snapshot
#
# Found the id [59622229] at the index [4058558] in this snapshot
#
# Found the id [62412117] at the index [4058559] in this snapshot
#
# Found the id [69193608] at the index [4058522] in this snapshot
#
# Found the id [75470406] at the index [4058560] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [4058557 4058558 4058559 4058522 4058560]
#
#
# Now Matching the ids of the snapshot 682  with the cluster group id 14
# The total no. of stars in cluster id  14  is 5
# Sorted ids of this cluster is [ 9910784 31078456 35148679 54122687 67035242]
#
# Found the id [9910784] at the index [11979257] in this snapshot
#
# Found the id [31078456] at the index [11979258] in this snapshot
#
# Found the id [35148679] at the index [5652256] in this snapshot
#
# Found the id [54122687] at the index [5652255] in this snapshot
#
# Found the id [67035242] at the index [5652200] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [11979257 11979258  5652256  5652255  5652200]
#
#  Stored tracked data of all stars clusters in the snapshot no. 682 to filename: tracked_clusters_at_snapshot_682_llc_fix.pkl
# #####
#
#
# # in utilities.simulation.Snapshot():
# * reading:  scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/snapshot_times.txt
#
#   using snapshot index = 683, redshift = 0.001
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/output/snapshot_683.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 81363848 particles
#     dark2     (id = 2): 7086235 particles
#     gas       (id = 0): 64078090 particles
#     star      (id = 4): 17873081 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['star']
#
# * reading particles from:
#     scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/output/snapshot_683.hdf5
#
# * reading cosmological parameters from:  scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
# ! warning: star id.child [min, max] = [0.000, 4.254e9]
# ! warning: star mass [min, med, max] = [3245.210, 5411.798, 1.375e5]
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/track/host_coordinates.hdf5
#   host1 position = (38709.44, 47672.98, 46764.01) [kpc comoving]
#   host1 velocity = (-161.7, 168.3, 104.2) [km / s]
#   host1 axis ratios = (0.19, 0.19, 0.99)
#   host1 R_90 = 12.3 kpc
#   host1 M_90 = 7.6e+10 Msun
#
#
# #########
# ############
# Loaded id,id_child,age,x,y,z,vx,vy,vz,mass, cylindrical velocities and number of particles for snapshot no. 683
# Total no of particles in this shapshot no. 683 is 17873081
#
#
# Now Matching the ids of the snapshot 683  with the cluster group id 1
# The total no. of stars in cluster id  1  is 9
# Sorted ids of this cluster is [12233101 15939420 16676135 21789997 35600867 36199746 38743397 52460765
#  79474586]
#
# Found the id [12233101] at the index [9873617] in this snapshot
#
# Found the id [15939420] at the index [9873615] in this snapshot
#
# Found the id [16676135] at the index [9873512] in this snapshot
#
# Found the id [21789997] at the index [4563892] in this snapshot
#
# Found the id [35600867] at the index [9873618] in this snapshot
#
# Found the id [36199746] at the index [9873511] in this snapshot
#
# Found the id [38743397] at the index [9873616] in this snapshot
#
# Found the id [52460765] at the index [9873611] in this snapshot
#
# Found the id [79474586] at the index [9873612] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [9873617 9873615 9873512 4563892 9873618 9873511 9873616 9873611 9873612]
#
#
# Now Matching the ids of the snapshot 683  with the cluster group id 2
# The total no. of stars in cluster id  2  is 8
# Sorted ids of this cluster is [ 6288525 13442273 15683027 23830710 35882027 44637212 47692615 55510626]
#
# Found the id [6288525] at the index [11117817] in this snapshot
#
# Found the id [13442273] at the index [11117809] in this snapshot
#
# Found the id [15683027] at the index [11117820] in this snapshot
#
# Found the id [23830710] at the index [11117811] in this snapshot
#
# Found the id [35882027] at the index [11117812] in this snapshot
#
# Found the id [44637212] at the index [11117816] in this snapshot
#
# Found the id [47692615] at the index [11117821] in this snapshot
#
# Found the id [55510626] at the index [11117819] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [11117817 11117809 11117820 11117811 11117812 11117816 11117821 11117819]
#
#
# Now Matching the ids of the snapshot 683  with the cluster group id 3
# The total no. of stars in cluster id  3  is 7
# Sorted ids of this cluster is [ 6522694  9082875 17946997 19734054 29732816 40989092 57694150]
#
# Found the id [6522694] at the index [13087096] in this snapshot
#
# Found the id [9082875] at the index [13087100] in this snapshot
#
# Found the id [17946997] at the index [13087141] in this snapshot
#
# Found the id [19734054] at the index [13087229] in this snapshot
#
# Found the id [29732816] at the index [13087140] in this snapshot
#
# Found the id [40989092] at the index [13087142] in this snapshot
#
# Found the id [57694150] at the index [13087097] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [13087096 13087100 13087141 13087229 13087140 13087142 13087097]
#
#
# Now Matching the ids of the snapshot 683  with the cluster group id 4
# The total no. of stars in cluster id  4  is 7
# Sorted ids of this cluster is [31895283 48004469 51588915 60048561 63871484 68625169 74584151]
#
# Found the id [31895283] at the index [2435790] in this snapshot
#
# Found the id [48004469] at the index [2435658] in this snapshot
#
# Found the id [51588915] at the index [2435786] in this snapshot
#
# Found the id [60048561] at the index [2435787] in this snapshot
#
# Found the id [63871484] at the index [2435791] in this snapshot
#
# Found the id [68625169] at the index [2435776] in this snapshot
#
# Found the id [74584151] at the index [2435666] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [2435790 2435658 2435786 2435787 2435791 2435776 2435666]
#
#
# Now Matching the ids of the snapshot 683  with the cluster group id 5
# The total no. of stars in cluster id  5  is 7
# Sorted ids of this cluster is [17432067 18309009 43044321 46292834 54644758 60039322 79765310]
#
# Found the id [17432067] at the index [8909365] in this snapshot
#
# Found the id [18309009] at the index [8909360] in this snapshot
#
# Found the id [43044321] at the index [8909366] in this snapshot
#
# Found the id [46292834] at the index [8909367] in this snapshot
#
# Found the id [54644758] at the index [8909363] in this snapshot
#
# Found the id [60039322] at the index [1138751] in this snapshot
#
# Found the id [79765310] at the index [8909369] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [8909365 8909360 8909366 8909367 8909363 1138751 8909369]
#
#
# Now Matching the ids of the snapshot 683  with the cluster group id 6
# The total no. of stars in cluster id  6  is 7
# Sorted ids of this cluster is [14946122 17736446 19224491 24150783 42481897 43565926 45006599]
#
# Found the id [14946122] at the index [15494819] in this snapshot
#
# Found the id [17736446] at the index [10512605] in this snapshot
#
# Found the id [19224491] at the index [15494821] in this snapshot
#
# Found the id [24150783] at the index [10512114] in this snapshot
#
# Found the id [42481897] at the index [10512603] in this snapshot
#
# Found the id [43565926] at the index [10512113] in this snapshot
#
# Found the id [45006599] at the index [15494820] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [15494819 10512605 15494821 10512114 10512603 10512113 15494820]
#
#
# Now Matching the ids of the snapshot 683  with the cluster group id 7
# The total no. of stars in cluster id  7  is 6
# Sorted ids of this cluster is [26799622 31366904 33517759 43344184 59273944 66179841]
#
# Found the id [26799622] at the index [17691296] in this snapshot
#
# Found the id [31366904] at the index [17691226] in this snapshot
#
# Found the id [33517759] at the index [17691297] in this snapshot
#
# Found the id [43344184] at the index [17691298] in this snapshot
#
# Found the id [59273944] at the index [7796527] in this snapshot
#
# Found the id [66179841] at the index [17691295] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [17691296 17691226 17691297 17691298  7796527 17691295]
#
#
# Now Matching the ids of the snapshot 683  with the cluster group id 8
# The total no. of stars in cluster id  8  is 6
# Sorted ids of this cluster is [ 8078634 30501388 37124620 59473105 63656844 73852946]
#
# Found the id [8078634] at the index [394705] in this snapshot
#
# Found the id [30501388] at the index [394708] in this snapshot
#
# Found the id [37124620] at the index [394677] in this snapshot
#
# Found the id [59473105] at the index [394706] in this snapshot
#
# Found the id [63656844] at the index [394707] in this snapshot
#
# Found the id [73852946] at the index [394637] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [394705 394708 394677 394706 394707 394637]
#
#
# Now Matching the ids of the snapshot 683  with the cluster group id 9
# The total no. of stars in cluster id  9  is 5
# Sorted ids of this cluster is [22688626 25015777 32104848 55232462 65198437]
#
# Found the id [22688626] at the index [9952599] in this snapshot
#
# Found the id [25015777] at the index [9952605] in this snapshot
#
# Found the id [32104848] at the index [9952819] in this snapshot
#
# Found the id [55232462] at the index [9952598] in this snapshot
#
# Found the id [65198437] at the index [9952820] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [9952599 9952605 9952819 9952598 9952820]
#
#
# Now Matching the ids of the snapshot 683  with the cluster group id 10
# The total no. of stars in cluster id  10  is 5
# Sorted ids of this cluster is [ 9748455  9749625 13096782 20388585 35390117]
#
# Found the id [9748455] at the index [1436318] in this snapshot
#
# Found the id [9749625] at the index [1436322] in this snapshot
#
# Found the id [13096782] at the index [1436314] in this snapshot
#
# Found the id [20388585] at the index [1436321] in this snapshot
#
# Found the id [35390117] at the index [1436319] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [1436318 1436322 1436314 1436321 1436319]
#
#
# Now Matching the ids of the snapshot 683  with the cluster group id 11
# The total no. of stars in cluster id  11  is 5
# Sorted ids of this cluster is [11552938 18551404 23608604 36698843 68738504]
#
# Found the id [11552938] at the index [16054966] in this snapshot
#
# Found the id [18551404] at the index [16054967] in this snapshot
#
# Found the id [23608604] at the index [16054992] in this snapshot
#
# Found the id [36698843] at the index [16054989] in this snapshot
#
# Found the id [68738504] at the index [16054990] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [16054966 16054967 16054992 16054989 16054990]
#
#
# Now Matching the ids of the snapshot 683  with the cluster group id 12
# The total no. of stars in cluster id  12  is 5
# Sorted ids of this cluster is [11705068 36488475 39925280 40237329 71222733]
#
# Found the id [11705068] at the index [10033526] in this snapshot
#
# Found the id [36488475] at the index [14883819] in this snapshot
#
# Found the id [39925280] at the index [10033527] in this snapshot
#
# Found the id [40237329] at the index [10033528] in this snapshot
#
# Found the id [71222733] at the index [10033529] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [10033526 14883819 10033527 10033528 10033529]
#
#
# Now Matching the ids of the snapshot 683  with the cluster group id 13
# The total no. of stars in cluster id  13  is 5
# Sorted ids of this cluster is [27767024 59622229 62412117 69193608 75470406]
#
# Found the id [27767024] at the index [11302259] in this snapshot
#
# Found the id [59622229] at the index [11302260] in this snapshot
#
# Found the id [62412117] at the index [11302258] in this snapshot
#
# Found the id [69193608] at the index [11302244] in this snapshot
#
# Found the id [75470406] at the index [11302261] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [11302259 11302260 11302258 11302244 11302261]
#
#
# Now Matching the ids of the snapshot 683  with the cluster group id 14
# The total no. of stars in cluster id  14  is 5
# Sorted ids of this cluster is [ 9910784 31078456 35148679 54122687 67035242]
#
# ...
# The total no. of stars in cluster id  9  is 5
# Sorted ids of this cluster is [22688626 25015777 32104848 55232462 65198437]
#
# Found the id [22688626] at the index [4747483] in this snapshot
#
# Found the id [25015777] at the index [4747788] in this snapshot
#
# Found the id [32104848] at the index [4747484] in this snapshot
#
# Found the id [55232462] at the index [4747481] in this snapshot
#
# Found the id [65198437] at the index [4747482] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [4747483 4747788 4747484 4747481 4747482]
#
#
# Now Matching the ids of the snapshot 695  with the cluster group id 10
# The total no. of stars in cluster id  10  is 5
# Sorted ids of this cluster is [ 9748455  9749625 13096782 20388585 35390117]
#
# Found the id [9748455] at the index [8390045] in this snapshot
#
# Found the id [9749625] at the index [8390051] in this snapshot
#
# Found the id [13096782] at the index [8390041] in this snapshot
#
# Found the id [20388585] at the index [8390042] in this snapshot
#
# Found the id [35390117] at the index [8390049] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [8390045 8390051 8390041 8390042 8390049]
#
#
# Now Matching the ids of the snapshot 695  with the cluster group id 11
# The total no. of stars in cluster id  11  is 5
# Sorted ids of this cluster is [11552938 18551404 23608604 36698843 68738504]
#
# Found the id [11552938] at the index [8236521] in this snapshot
#
# Found the id [18551404] at the index [8236522] in this snapshot
#
# Found the id [23608604] at the index [8236515] in this snapshot
#
# Found the id [36698843] at the index [8236513] in this snapshot
#
# Found the id [68738504] at the index [8236512] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [8236521 8236522 8236515 8236513 8236512]
#
#
# Now Matching the ids of the snapshot 695  with the cluster group id 12
# The total no. of stars in cluster id  12  is 5
# Sorted ids of this cluster is [11705068 36488475 39925280 40237329 71222733]
#
# Found the id [11705068] at the index [5289917] in this snapshot
#
# Found the id [36488475] at the index [333679] in this snapshot
#
# Found the id [39925280] at the index [5289914] in this snapshot
#
# Found the id [40237329] at the index [5289916] in this snapshot
#
# Found the id [71222733] at the index [5289915] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [5289917  333679 5289914 5289916 5289915]
#
#
# Now Matching the ids of the snapshot 695  with the cluster group id 13
# The total no. of stars in cluster id  13  is 5
# Sorted ids of this cluster is [27767024 59622229 62412117 69193608 75470406]
#
# Found the id [27767024] at the index [12859790] in this snapshot
#
# Found the id [59622229] at the index [12859791] in this snapshot
#
# Found the id [62412117] at the index [12859788] in this snapshot
#
# Found the id [69193608] at the index [12859743] in this snapshot
#
# Found the id [75470406] at the index [12859759] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [12859790 12859791 12859788 12859743 12859759]
#
#
# Now Matching the ids of the snapshot 695  with the cluster group id 14
# The total no. of stars in cluster id  14  is 5
# Sorted ids of this cluster is [ 9910784 31078456 35148679 54122687 67035242]
#
# Found the id [9910784] at the index [16243830] in this snapshot
#
# Found the id [31078456] at the index [16243856] in this snapshot
#
# Found the id [35148679] at the index [1717796] in this snapshot
#
# Found the id [54122687] at the index [1717797] in this snapshot
#
# Found the id [67035242] at the index [6766760] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [16243830 16243856  1717796  1717797  6766760]
#
#  Stored tracked data of all stars clusters in the snapshot no. 695 to filename: tracked_clusters_at_snapshot_695_llc_fix.pkl
# #####
#
#
# # in utilities.simulation.Snapshot():
# * reading:  scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/snapshot_times.txt
#
#   using snapshot index = 696, redshift = 0.000
#
#
# # in gizmo_analysis.gizmo_io.Read():
# * reading header from:  scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/output/snapshot_696.hdf5
#   snapshot contains the following number of particles:
#     dark      (id = 1): 81363848 particles
#     dark2     (id = 2): 7086235 particles
#     gas       (id = 0): 64065747 particles
#     star      (id = 4): 17885424 particles
#     blackhole (id = 5): 0 particles
#
# * reading the following
#   species: ['star']
#
# * reading particles from:
#     scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/output/snapshot_696.hdf5
#
# * reading cosmological parameters from:  scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/initial_condition/ic_agora_m12f.conf
#
# * checking sanity of particle properties
# ! warning: star id.child [min, max] = [0.000, 4.254e9]
# ! warning: star mass [min, med, max] = [3245.210, 5411.728, 1.375e5]
#
#
# # in gizmo_analysis.gizmo_track.ParticleCoordinate():
#   read 1 host (position, velocity, principal axes) from:  scratch/projects/xsede/GalaxiesOnFIRE/cr_suite/m12f_r7100/mhdcv/1Myr/track/host_coordinates.hdf5
#   host1 position = (38707.28, 47675.24, 46765.46) [kpc comoving]
#   host1 velocity = (-162.7, 169.0, 103.0) [km / s]
#   host1 axis ratios = (0.18, 0.19, 0.97)
#   host1 R_90 = 12.3 kpc
#   host1 M_90 = 7.6e+10 Msun
#
#
# #########
# ############
# Loaded id,id_child,age,x,y,z,vx,vy,vz,mass, cylindrical velocities and number of particles for snapshot no. 696
# Total no of particles in this shapshot no. 696 is 17885424
#
#
# Now Matching the ids of the snapshot 696  with the cluster group id 1
# The total no. of stars in cluster id  1  is 9
# Sorted ids of this cluster is [12233101 15939420 16676135 21789997 35600867 36199746 38743397 52460765
#  79474586]
#
# Found the id [12233101] at the index [729540] in this snapshot
#
# Found the id [15939420] at the index [729538] in this snapshot
#
# Found the id [16676135] at the index [729274] in this snapshot
#
# Found the id [21789997] at the index [4532343] in this snapshot
#
# Found the id [35600867] at the index [729512] in this snapshot
#
# Found the id [36199746] at the index [729275] in this snapshot
#
# Found the id [38743397] at the index [729482] in this snapshot
#
# Found the id [52460765] at the index [729537] in this snapshot
#
# Found the id [79474586] at the index [729535] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [ 729540  729538  729274 4532343  729512  729275  729482  729537  729535]
#
#
# Now Matching the ids of the snapshot 696  with the cluster group id 2
# The total no. of stars in cluster id  2  is 8
# Sorted ids of this cluster is [ 6288525 13442273 15683027 23830710 35882027 44637212 47692615 55510626]
#
# Found the id [6288525] at the index [3201081] in this snapshot
#
# Found the id [13442273] at the index [3201077] in this snapshot
#
# Found the id [15683027] at the index [3201084] in this snapshot
#
# Found the id [23830710] at the index [3201083] in this snapshot
#
# Found the id [35882027] at the index [3201085] in this snapshot
#
# Found the id [44637212] at the index [3201082] in this snapshot
#
# Found the id [47692615] at the index [3201078] in this snapshot
#
# Found the id [55510626] at the index [3201080] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [3201081 3201077 3201084 3201083 3201085 3201082 3201078 3201080]
#
#
# Now Matching the ids of the snapshot 696  with the cluster group id 3
# The total no. of stars in cluster id  3  is 7
# Sorted ids of this cluster is [ 6522694  9082875 17946997 19734054 29732816 40989092 57694150]
#
# Found the id [6522694] at the index [10898830] in this snapshot
#
# Found the id [9082875] at the index [10898828] in this snapshot
#
# Found the id [17946997] at the index [15359906] in this snapshot
#
# Found the id [19734054] at the index [9501151] in this snapshot
#
# Found the id [29732816] at the index [15359905] in this snapshot
#
# Found the id [40989092] at the index [15359909] in this snapshot
#
# Found the id [57694150] at the index [10898831] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [10898830 10898828 15359906  9501151 15359905 15359909 10898831]
#
#
# Now Matching the ids of the snapshot 696  with the cluster group id 4
# The total no. of stars in cluster id  4  is 7
# Sorted ids of this cluster is [31895283 48004469 51588915 60048561 63871484 68625169 74584151]
#
# Found the id [31895283] at the index [15542532] in this snapshot
#
# Found the id [48004469] at the index [15542539] in this snapshot
#
# Found the id [51588915] at the index [15542535] in this snapshot
#
# Found the id [60048561] at the index [15542533] in this snapshot
#
# Found the id [63871484] at the index [15542530] in this snapshot
#
# Found the id [68625169] at the index [15542536] in this snapshot
#
# Found the id [74584151] at the index [15542457] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [15542532 15542539 15542535 15542533 15542530 15542536 15542457]
#
#
# Now Matching the ids of the snapshot 696  with the cluster group id 5
# The total no. of stars in cluster id  5  is 7
# Sorted ids of this cluster is [17432067 18309009 43044321 46292834 54644758 60039322 79765310]
#
# Found the id [17432067] at the index [14188452] in this snapshot
#
# Found the id [18309009] at the index [14188457] in this snapshot
#
# Found the id [43044321] at the index [14188454] in this snapshot
#
# Found the id [46292834] at the index [14188458] in this snapshot
#
# Found the id [54644758] at the index [14188451] in this snapshot
#
# Found the id [60039322] at the index [14188508] in this snapshot
#
# Found the id [79765310] at the index [14188455] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [14188452 14188457 14188454 14188458 14188451 14188508 14188455]
#
#
# Now Matching the ids of the snapshot 696  with the cluster group id 6
# The total no. of stars in cluster id  6  is 7
# Sorted ids of this cluster is [14946122 17736446 19224491 24150783 42481897 43565926 45006599]
#
# Found the id [14946122] at the index [183835] in this snapshot
#
# Found the id [17736446] at the index [7326047] in this snapshot
#
# Found the id [19224491] at the index [183834] in this snapshot
#
# Found the id [24150783] at the index [183748] in this snapshot
#
# Found the id [42481897] at the index [7326045] in this snapshot
#
# Found the id [43565926] at the index [183747] in this snapshot
#
# Found the id [45006599] at the index [183833] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [ 183835 7326047  183834  183748 7326045  183747  183833]
#
#
# Now Matching the ids of the snapshot 696  with the cluster group id 7
# The total no. of stars in cluster id  7  is 6
# Sorted ids of this cluster is [26799622 31366904 33517759 43344184 59273944 66179841]
#
# Found the id [26799622] at the index [1245821] in this snapshot
#
# Found the id [31366904] at the index [1245673] in this snapshot
#
# Found the id [33517759] at the index [1245822] in this snapshot
#
# Found the id [43344184] at the index [1245823] in this snapshot
#
# Found the id [59273944] at the index [1245178] in this snapshot
#
# Found the id [66179841] at the index [1245824] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [1245821 1245673 1245822 1245823 1245178 1245824]
#
#
# Now Matching the ids of the snapshot 696  with the cluster group id 8
# The total no. of stars in cluster id  8  is 6
# Sorted ids of this cluster is [ 8078634 30501388 37124620 59473105 63656844 73852946]
#
# Found the id [8078634] at the index [8375514] in this snapshot
#
# Found the id [30501388] at the index [8375516] in this snapshot
#
# Found the id [37124620] at the index [8375519] in this snapshot
#
# Found the id [59473105] at the index [8375513] in this snapshot
#
# Found the id [63656844] at the index [8375515] in this snapshot
#
# Found the id [73852946] at the index [8373697] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [8375514 8375516 8375519 8375513 8375515 8373697]
#
#
# Now Matching the ids of the snapshot 696  with the cluster group id 9
# The total no. of stars in cluster id  9  is 5
# Sorted ids of this cluster is [22688626 25015777 32104848 55232462 65198437]
#
# Found the id [22688626] at the index [15703587] in this snapshot
#
# Found the id [25015777] at the index [15703680] in this snapshot
#
# Found the id [32104848] at the index [15703588] in this snapshot
#
# Found the id [55232462] at the index [15703586] in this snapshot
#
# Found the id [65198437] at the index [15703589] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [15703587 15703680 15703588 15703586 15703589]
#
#
# Now Matching the ids of the snapshot 696  with the cluster group id 10
# The total no. of stars in cluster id  10  is 5
# Sorted ids of this cluster is [ 9748455  9749625 13096782 20388585 35390117]
#
# Found the id [9748455] at the index [13493627] in this snapshot
#
# Found the id [9749625] at the index [13493626] in this snapshot
#
# Found the id [13096782] at the index [13493534] in this snapshot
#
# Found the id [20388585] at the index [13493533] in this snapshot
#
# Found the id [35390117] at the index [13493632] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [13493627 13493626 13493534 13493533 13493632]
#
#
# Now Matching the ids of the snapshot 696  with the cluster group id 11
# The total no. of stars in cluster id  11  is 5
# Sorted ids of this cluster is [11552938 18551404 23608604 36698843 68738504]
#
# Found the id [11552938] at the index [4522423] in this snapshot
#
# Found the id [18551404] at the index [4522422] in this snapshot
#
# Found the id [23608604] at the index [7143384] in this snapshot
#
# Found the id [36698843] at the index [7144758] in this snapshot
#
# Found the id [68738504] at the index [7144757] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [4522423 4522422 7143384 7144758 7144757]
#
#
# Now Matching the ids of the snapshot 696  with the cluster group id 12
# The total no. of stars in cluster id  12  is 5
# Sorted ids of this cluster is [11705068 36488475 39925280 40237329 71222733]
#
# Found the id [11705068] at the index [9098205] in this snapshot
#
# Found the id [36488475] at the index [7878746] in this snapshot
#
# Found the id [39925280] at the index [9097966] in this snapshot
#
# Found the id [40237329] at the index [9098204] in this snapshot
#
# Found the id [71222733] at the index [9097967] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [9098205 7878746 9097966 9098204 9097967]
#
#
# Now Matching the ids of the snapshot 696  with the cluster group id 13
# The total no. of stars in cluster id  13  is 5
# Sorted ids of this cluster is [27767024 59622229 62412117 69193608 75470406]
#
# Found the id [27767024] at the index [9050325] in this snapshot
#
# Found the id [59622229] at the index [9050324] in this snapshot
#
# Found the id [62412117] at the index [9050326] in this snapshot
#
# Found the id [69193608] at the index [9050336] in this snapshot
#
# Found the id [75470406] at the index [9050327] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [9050325 9050324 9050326 9050336 9050327]
#
#
# Now Matching the ids of the snapshot 696  with the cluster group id 14
# The total no. of stars in cluster id  14  is 5
# Sorted ids of this cluster is [ 9910784 31078456 35148679 54122687 67035242]
#
# Found the id [9910784] at the index [4757679] in this snapshot
#
# Found the id [31078456] at the index [4757665] in this snapshot
#
# Found the id [35148679] at the index [9689599] in this snapshot
#
# Found the id [54122687] at the index [9689600] in this snapshot
#
# Found the id [67035242] at the index [4021238] in this snapshot
#
# These are the indices of the ids that matched in current snapshot
#  [4757679 4757665 9689599 9689600 4021238]
#
#  Stored tracked data of all stars clusters in the snapshot no. 696 to filename: tracked_clusters_at_snapshot_696_llc_fix.pkl
# #####

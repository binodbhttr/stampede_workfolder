# %%
###################################################
###################################################
####Loading the data from the pkl files #############
from matplotlib import pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
#from sl_utilities import distinct_colours as dc
#from sl_utilities import distance_functions
import os
import pickle
import imageio

path="./fire2_data_pkl/"
snap=596
simname = 'm12i_res7100_mhdcv'
#simdir = '/scratch/projects/xsede/GalaxiesOnFIRE/mhdcv/m12i_res7100_mhdcv/1Myr/1Myr_fire2'
file_name="total_data_all_clusters_all_snapshots.pkl"
snapshot_start=596
snapshot_end=690



with open(path+file_name, "rb") as input:
    importdata = pickle.load(input)

print("Testing if the loading of data was successful !! \n")
print("x_tracked of snapshot 596 for cluster 1",importdata[596][1]["x_tracked"])
print("x_cm of snapshot 596 for cluster 1",importdata[596][1]["xcm"])
print("x_tracked of snapshot 597 for cluster 1",importdata[597][1]["x_tracked"])
print("x_cm of snapshot 597 for cluster 1",importdata[597][1]["xcm"])
print("x_tracked of snapshot 597 for cluster 2",importdata[597][2]["x_tracked"])
print("x_cm of snapshot 597 for cluster 2",importdata[597][2]["xcm"])



cluster_groupid=[]
total_clusters=len(importdata[snapshot_start])
for i in range(total_clusters):
    cluster_groupid.append("snapshot"+str(snapshot_start)+"_cluster_group"+str(i+1))

print("These are the clusters groups we have tracked data of:\n",cluster_groupid)
# Out:
# Testing if the loading of data was successful !!
#
# x_tracked of snapshot 596 for cluster 1 [-6.00513891 -6.00509183 -6.00239829 -6.01305976 -6.00702558 -6.00990916
#  -6.00309596 -6.00452512 -6.0039977  -6.00854992 -6.00393315 -6.00829482
#  -6.00636014 -6.00444464 -6.00841607 -6.00854442 -6.00197996 -6.00850992
#  -6.00568745 -6.00840539 -6.00982215 -6.0013967  -6.00854318 -6.01197897
#  -5.9995058  -5.99878137 -6.00698328 -6.00869882 -6.00844468 -6.00558671
#  -6.00536959 -6.01049269 -6.00218807 -6.0006008  -6.00652576 -6.00544892
#  -6.00667422 -6.00743993 -6.00588704 -6.00958322 -6.01424892 -6.00430563
#  -6.00200992]
# x_cm of snapshot 596 for cluster 1 -6.006235802999383
# x_tracked of snapshot 597 for cluster 1 [-6.01601537 -6.01287714 -6.01442506 -5.99648041 -6.00928859 -6.01037169
#  -6.01620249 -6.01430355 -6.01481366 -6.01071521 -6.00793953 -6.01023188
#  -6.00759919 -6.01196177 -6.0119816  -6.01126726 -6.01338726 -6.01036839
#  -6.01142382 -6.01040229 -6.00814754 -6.03227893 -6.01148209 -6.00743434
#  -6.02313196 -6.01941446 -6.00948887 -6.00970945 -6.01239606 -6.01183728
#  -6.00989226 -6.00878692 -6.01517223 -6.00814197 -6.01138944 -6.01431921
#  -6.00370448 -6.01118078 -6.01223339 -5.99972739 -6.00549727 -6.01360732
#  -6.01334439]
# x_cm of snapshot 597 for cluster 1 -6.011554058648143
# x_tracked of snapshot 597 for cluster 2 [-5.9489193  -5.93894069 -5.946881   -5.93339307 -5.96726817 -5.94041421
#  -5.94756465 -5.95800607 -5.94516274 -5.94342346 -5.9362367  -5.95629846
#  -5.93847075 -5.94928088 -5.94225617 -5.94267776 -5.96254183 -5.94351425
#  -5.94493434 -5.9552221  -5.95537666 -5.95275027 -5.93648536 -5.95238609
#  -5.95768418 -5.94324913 -5.94037642 -5.94688838 -5.95036681 -5.95625294
#  -5.94041917 -5.94865361 -5.94505131 -5.94284083 -5.93976208 -5.94501179
#  -5.95461548 -5.94453029 -5.936574   -5.95599568]
# x_cm of snapshot 597 for cluster 2 -5.946826858213976
# These are the clusters groups we have tracked data of:
#  ['snapshot596_cluster_group1', 'snapshot596_cluster_group2', 'snapshot596_cluster_group3', 'snapshot596_cluster_group4', 'snapshot596_cluster_group5', 'snapshot596_cluster_group6', 'snapshot596_cluster_group7', 'snapshot596_cluster_group8', 'snapshot596_cluster_group9', 'snapshot596_cluster_group10', 'snapshot596_cluster_group11', 'snapshot596_cluster_group12', 'snapshot596_cluster_group13', 'snapshot596_cluster_group14', 'snapshot596_cluster_group15', 'snapshot596_cluster_group16', 'snapshot596_cluster_group17']

# %%
plot_path="./plots_pkl/animation_plots/" #creating a path to store the plots only if it does not exist
if not os.path.exists(plot_path):
  os.makedirs(plot_path)


n=snapshot_end-snapshot_start+1
n_uf=n-5
colors=['cyan','blue','green','magenta','yellow','teal','brown','tan','lime','red']

total_clusters=10
#fig1.suptitle("Cylindrical component of the velocity of Cluster Groups from Snapshot 596")
plot_count=0
#plot_count=0
snapshot_list=np.arange(snapshot_start,snapshot_end+1) #create a list of snapshots to plot
time=snapshot_list-snapshot_start #time starts from zero here where t=0 is at the snapshot where we start from
#time=[[0],[20],[40],[60],[80],[100]]
for i in range(len(time)):
    
    fig1=plt.figure(figsize=(8,5))
    ax = fig1.add_subplot(1,1,1)
    cluster_count=0
    for j in range(total_clusters):
        
        x=importdata[time[i]+snapshot_start][cluster_count+1]["x_tracked"]
        y=importdata[time[i]+snapshot_start][cluster_count+1]["y_tracked"]
        xcm=importdata[time[i]+snapshot_start][cluster_count+1]["xcm"]
        ycm=importdata[time[i]+snapshot_start][cluster_count+1]["ycm"]
        z=importdata[time[i]+snapshot_start][cluster_count+1]["z_tracked"]
        
        s1=ax.scatter(x,y,label="cluster_group"+str(cluster_count+1),c=colors[cluster_count])
        #ax.scatter(np.abs(xcm),np.abs(ycm),c="black")
        ax.minorticks_on()
        ax.set_xlabel("x position in kpc")
        ax.set_ylabel("y position in kpc")
        ax.set_title("Clusters at T="+str(time[plot_count])+" in Myr")
        cluster_count+=1
    
    ax.legend(bbox_to_anchor=(1,0.5), loc='center left')
    plt.tight_layout()
    fig1.savefig(plot_path+"snap"+str(plot_count)+".png",bbox_inches='tight',dpi=200)
    plot_count+=1
    fig1.clf()
    plt.close()
     
    
#fig1.subplots_adjust(right=1.5)    
#fig11.legend((s1), ("vphi_cyl"),"lower right")
#fig11.suptitle("This is the title \n")

# %%
images=[]
for k in range(0,n_uf):
    images.append(imageio.imread(plot_path+"snap"+str(k) + '.png'))
    os.remove(plot_path+"snap"+str(k) + ".png")
imageio.mimsave(plot_path+"flipping_fixed_snapshots.gif", images, duration = 1/8)

# %%
#Here we track a star cluster keeping the axes limits fixed
#we calculated the maximum and minimum possible values for x and y axes and set the limits accordingly
plot_path="./plots_pkl/animation_plots/" #creating a path to store the plots only if it does not exist
if not os.path.exists(plot_path):
  os.makedirs(plot_path)


n=snapshot_end-snapshot_start+1
colors=['cyan','blue','green','magenta','yellow','teal','brown','tan','lime','red']

total_clusters=1
#fig1.suptitle("Cylindrical component of the velocity of Cluster Groups from Snapshot 596")
plot_count=0
#plot_count=0
snapshot_list=np.arange(snapshot_start,snapshot_end+1) #create a list of snapshots to plot
time=snapshot_list-snapshot_start #time starts from zero here where t=0 is at the snapshot where we start from
#time=[[0],[20],[40],[60],[80],[100]]

xmax=np.amax(importdata[time[1]+snapshot_start][1]["x_tracked"])
xmin=np.amin(importdata[time[1]+snapshot_start][1]["x_tracked"])
ymax=np.amax(importdata[time[1]+snapshot_start][1]["y_tracked"])
ymin=np.amin(importdata[time[1]+snapshot_start][1]["y_tracked"])
for i in range(len(time)-10):
    cluster_count=0
    
    for j in range(total_clusters):
        x=importdata[time[i]+snapshot_start][cluster_count+1]["x_tracked"]
        xmax_new=np.amax(x)
        print(xmax_new)
        xmin_new=np.amin(x)
        if xmax_new>xmax:
            xmax=xmax_new
        if xmin_new<xmin:
            xmin=xmin_new
        
        y=importdata[time[i]+snapshot_start][cluster_count+1]["y_tracked"]
        ymax_new=np.amax(y)
        ymin_new=np.amin(y)
        if ymax_new>ymax:
            ymax=ymax_new
        if ymin_new<ymin:
            ymin=ymin_new

print(xmax,xmin,"ymaxmin",ymax,ymin)
for i in range(len(time)):
    
    fig2=plt.figure(figsize=(8,5))
    ax = fig2.add_subplot(1,1,1)
    cluster_count=0
    for j in range(total_clusters):
        
        x=importdata[time[i]+snapshot_start][cluster_count+1]["x_tracked"]
        y=importdata[time[i]+snapshot_start][cluster_count+1]["y_tracked"]
        xcm=importdata[time[i]+snapshot_start][cluster_count+1]["xcm"]
        ycm=importdata[time[i]+snapshot_start][cluster_count+1]["ycm"]
        z=importdata[time[i]+snapshot_start][cluster_count+1]["z_tracked"]
        
        ax.scatter(x,y,label="cluster_group"+str(cluster_count+1),c=x)
        ax.scatter(xcm,ycm,c="black")
        ax.minorticks_on()
        ax.set_xlabel("x position in kpc")
        ax.set_ylabel("y position in kpc")
        ax.set_title("Clusters at T="+str(time[plot_count])+" in Myr")
        ax.set_xlim(xmin-abs(xmin/10),xmax+abs(xmax/10))
        ax.set_ylim(ymin-abs(ymin/10),ymax+abs(ymax/10))
        cluster_count+=1
    
    ax.legend(bbox_to_anchor=(1,0.5), loc='center left')
    plt.tight_layout()
    fig2.savefig(plot_path+"cluster_1_snap"+str(plot_count)+".png",bbox_inches='tight',dpi=200)
    plot_count+=1
    fig2.clf()
    plt.close()
        
#fig1.subplots_adjust(right=1.5)    
#fig11.legend((s1), ("vphi_cyl"),"lower right")
#fig11.suptitle("This is the title \n")

cluster1_snaps=[]
for k in range(0,101):
    cluster1_snaps.append(imageio.imread(plot_path+"cluster_1_snap"+str(k) + '.png'))
    os.remove(plot_path+"cluster_1_snap"+str(k) + ".png")
imageio.mimsave(plot_path+"cluster1.gif", cluster1_snaps, duration = 1/8)
# Out:
# -5.99878137206444
# -5.996480406201754
# -6.010809052694551
# -6.021626334850726
# -6.038259221019609
# -6.069563586024877
# -6.097365431382942
# -6.125457936670069
# -6.139731962371394
# -6.152721098032575
# -6.160228803431775
# -6.171259611021345
# -6.187833640864167
# -6.208996332561177
# -6.226343078164862
# -6.2495566657378
# -6.266589099538845
# -6.277431772257724
# -6.294810777311444
# -6.297140104389605
# -6.305852545870835
# -6.312832934384712
# -6.31426773433521
# -6.3224043988619965
# -6.333285930360485
# -6.332134386111723
# -6.340567577808784
# -6.35234947496551
# -6.354987981352022
# -6.363044469207665
# -6.369525277843707
# -6.36431761671281
# -6.3686374615420736
# -6.3724657369117175
# -6.375223544612083
# -6.383143324968536
# -6.389462825554583
# -6.408047990226469
# -6.42938469019571
# -6.44774964248237
# -6.488737660294194
# -6.5307302349129985
# -6.5759859747927205
# -6.637668535120366
# -6.711119593430974
# -6.775627652545161
# -6.836153150974172
# -6.91739737172596
# -6.988531900651265
# -7.044383319694201
# -7.095389762981357
# -7.180271767226838
# -7.234523745453089
# -7.286586109652883
# -7.343498964908856
# -7.387217719989187
# -7.429442326030709
# -7.46745849310872
# -7.4873394938747255
# -7.5009978893189215
# -7.522469836911386
# -7.525953475207745
# -7.539345772692481
# -7.5581425001896525
# -7.557259963230873
# -7.5542863635959385
# -7.575399061155274
# -7.581936537984032
# -7.590104885583364
# -7.566136899648499
# -7.558379370709416
# -7.600642889775523
# -7.631085925001264
# -7.653729491822444
# -7.6916946233284245
# -7.752737848048687
# -7.787874794282985
# -7.829574712319439
# -7.892163320502365
# -7.961552392758264
# -8.013018672986053
# -8.090456396713073
# -8.13661409185449
# -8.222182177569069
# -8.30400597435303
# -8.396417413660815
# -8.486592878325943
# -8.623421556043724
# -8.773689760884452
# -8.916859365056432
# -9.087752046047333
# -5.996480406201754 -12.169892786021322 ymaxmin 6.087337215672603 -11.010695594770944

# %%
#Here we try to track a star cluster keeping the center of mass at the center of the plot
plot_path="./plots_pkl/animation_plots/" #creating a path to store the plots only if it does not exist
if not os.path.exists(plot_path):
  os.makedirs(plot_path)


n=snapshot_end-snapshot_start+1
colors=['cyan','blue','green','magenta','yellow','teal','brown','tan','lime','red']

total_clusters=1
#fig1.suptitle("Cylindrical component of the velocity of Cluster Groups from Snapshot 596")
plot_count=0
#plot_count=0
snapshot_list=np.arange(snapshot_start,snapshot_end+1) #create a list of snapshots to plot
time=snapshot_list-snapshot_start #time starts from zero here where t=0 is at the snapshot where we start from
#time=[[0],[20],[40],[60],[80],[100]]

#################################
################################
rmax_global=importdata[time[1]+snapshot_start][1]["rmax"]
for i in range(len(time)):
    cluster_count=4 #change it to look for cluster no cluster_count+1
    
    for j in range(total_clusters):
        r=importdata[time[i]+snapshot_start][cluster_count+1]["rmax"]
        
        if r>rmax_global:
            rmax_global=r


#######################################
######################################
print("This is the longest distance a star travelled from the CM in this cluster",rmax_global)
for i in range(len(time)):
    
    fig2=plt.figure(figsize=(7,5))
    ax = fig2.add_subplot(1,1,1)
    cluster_count=4 #change it change it to look for cluster no cluster_count+1
    for j in range(total_clusters):
        
        x=importdata[time[i]+snapshot_start][cluster_count+1]["x_tracked"]
        y=importdata[time[i]+snapshot_start][cluster_count+1]["y_tracked"]
        z=importdata[time[i]+snapshot_start][cluster_count+1]["z_tracked"]
        xcm=importdata[time[i]+snapshot_start][cluster_count+1]["xcm"]
        ycm=importdata[time[i]+snapshot_start][cluster_count+1]["ycm"]
        zcm=importdata[time[i]+snapshot_start][cluster_count+1]["zcm"]
        rmax=importdata[time[i]+snapshot_start][cluster_count+1]["rmax"]
        xlim_max=xcm+1.1*rmax_global
        xlim_min=xcm-1.1*rmax_global
        
        zlim_max=zcm+1.1*rmax_global
        zlim_min=zcm-1.1*rmax_global
        
        ylim_max=ycm+1.1*rmax_global
        ylim_min=ycm-1.1*rmax_global
        print("These are the dimensions of the plot xmax",xlim_max,"xmin",xlim_min,"ymax",ylim_max,"ymin",ylim_min)
        ax.scatter(x,y,label="cluster_group"+str(cluster_count+1),c=x)
        ax.scatter(xcm,ycm,c="black",marker='x')
        ax.minorticks_on()
        ax.set_xlabel("X")
        ax.set_ylabel("Y")
        
        ax.set_title("Cluster "+str(cluster_count+1)+" at T="+str(time[plot_count])+" in Myr")
        ax.set_xlim(xlim_min,xlim_max)
        ax.set_ylim(ylim_min,ylim_max)
        ax.set_xticks([], [])
        ax.set_yticks([], [])
        #ax.axis('off') This removes everything including the box and labels.
        ax.set_aspect('equal')
        ax.annotate('', xy=(xcm-0.5, ylim_min+0.2), xytext=(xcm+0.5, ylim_min+0.2),xycoords='data', arrowprops=dict(alpha=0.5, fc='b', ec='b', arrowstyle="<->"))
        ax.annotate('1 kpc',xy=(xcm,ylim_min+0.3),textcoords='data')
        #ax.arrow(xlim_min,ylim_min, xlim_min+0.9, 0,head_width=0.05, head_length=0.1, fc='k', ec='k')
        cluster_count+=1
    
    #ax.legend(bbox_to_anchor=(1,0.5), loc='center left')
    plt.tight_layout()
    #plt.axis('square')
    fig2.savefig(plot_path+"cluster_5_snap_fixedCM"+str(plot_count)+".png",bbox_inches='tight',dpi=200)
    plot_count+=1
    fig2.clf()
    plt.close()
        
#fig1.subplots_adjust(right=1.5)    
#fig11.legend((s1), ("vphi_cyl"),"lower right")
#fig11.suptitle("This is the title \n")

cluster1_snaps=[]
for k in range(0,101):
    cluster1_snaps.append(imageio.imread(plot_path+"cluster_5_snap_fixedCM"+str(k) + '.png'))
    os.remove(plot_path+"cluster_5_snap_fixedCM"+str(k) + ".png")

imageio.mimsave(plot_path+"cluster5_fixedCM.gif", cluster1_snaps, duration = 1/8)
# Out:
# This is the longest distance a star travelled from the CM in this cluster 0.09589847341125314
# These are the dimensions of the plot xmax -5.693100807024259 xmin -5.904077448529017 ymax 4.969111994094926 ymin 4.758135352590169
# <ipython-input-40-dad2094cccdf>:66: MatplotlibDeprecationWarning: Passing the minor parameter of set_xticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   ax.set_xticks([], [])
# <ipython-input-40-dad2094cccdf>:67: MatplotlibDeprecationWarning: Passing the minor parameter of set_yticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   ax.set_yticks([], [])
# <ipython-input-40-dad2094cccdf>:76: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# These are the dimensions of the plot xmax -5.719630824273957 xmin -5.9306074657787144 ymax 4.810404132832595 ymin 4.5994274913278375
# These are the dimensions of the plot xmax -5.752154121928559 xmin -5.963130763433316 ymax 4.653701695764654 ymin 4.442725054259896
# These are the dimensions of the plot xmax -5.773312111338661 xmin -5.984288752843418 ymax 4.499574960691895 ymin 4.2885983191871375
# These are the dimensions of the plot xmax -5.801034487807804 xmin -6.012011129312562 ymax 4.337630444064304 ymin 4.126653802559547
# These are the dimensions of the plot xmax -5.838415004176863 xmin -6.04939164568162 ymax 4.165458509877567 ymin 3.9544818683728096
# These are the dimensions of the plot xmax -5.870688892179934 xmin -6.081665533684691 ymax 3.984689943004952 ymin 3.7737133015001945
# These are the dimensions of the plot xmax -5.901078110709866 xmin -6.112054752214624 ymax 3.8027722036217613 ymin 3.591795562117005
# These are the dimensions of the plot xmax -5.921054272387635 xmin -6.132030913892392 ymax 3.6387559523876805 ymin 3.427779310882924
# These are the dimensions of the plot xmax -5.938377355697251 xmin -6.149353997202009 ymax 3.4662407091041025 ymin 3.255264067599345
# These are the dimensions of the plot xmax -5.948654365217778 xmin -6.1596310067225355 ymax 3.302287677954447 ymin 3.0913110364496905
# These are the dimensions of the plot xmax -5.960714722225879 xmin -6.171691363730637 ymax 3.1392589013434113 ymin 2.928282259838655
# These are the dimensions of the plot xmax -5.9751777446704075 xmin -6.186154386175165 ymax 2.973686178462197 ymin 2.7627095369574395
# These are the dimensions of the plot xmax -5.991532600645005 xmin -6.2025092421497625 ymax 2.8072512221715327 ymin 2.596274580666776
# These are the dimensions of the plot xmax -6.000831453257179 xmin -6.2118080947619365 ymax 2.6273188111257735 ymin 2.416342169621016
# These are the dimensions of the plot xmax -6.01256336394966 xmin -6.223540005454417 ymax 2.4463682520000365 ymin 2.23539161049528
# These are the dimensions of the plot xmax -6.015704105670476 xmin -6.226680747175234 ymax 2.261392780456454 ymin 2.0504161389516966
# These are the dimensions of the plot xmax -6.012334664544931 xmin -6.2233113060496885 ymax 2.068841426552254 ymin 1.8578647850474967
# These are the dimensions of the plot xmax -6.014184765355253 xmin -6.2251614068600105 ymax 1.8685903184752566 ymin 1.6576136769704997
# These are the dimensions of the plot xmax -5.998483097800187 xmin -6.209459739304944 ymax 1.6665328645641408 ymin 1.455556223059384
# These are the dimensions of the plot xmax -5.987580303389172 xmin -6.198556944893929 ymax 1.454363425004059 ymin 1.243386783499302
# These are the dimensions of the plot xmax -5.972512610835589 xmin -6.183489252340347 ymax 1.2510548738937017 ymin 1.0400782323889448
# These are the dimensions of the plot xmax -5.949863261930252 xmin -6.16083990343501 ymax 1.0611668428521845 ymin 0.8501902013474276
# These are the dimensions of the plot xmax -5.930589611647446 xmin -6.141566253152203 ymax 0.8591130330388199 ymin 0.648136391534063
# These are the dimensions of the plot xmax -5.912218634883359 xmin -6.123195276388117 ymax 0.6525073236155968 ymin 0.4415306821108399
# These are the dimensions of the plot xmax -5.877416649068402 xmin -6.088393290573159 ymax 0.45833722874627664 ymin 0.2473605872415197
# These are the dimensions of the plot xmax -5.850397294436391 xmin -6.061373935941148 ymax 0.23160892614853365 ymin 0.020632284643776727
# These are the dimensions of the plot xmax -5.8224806451185716 xmin -6.033457286623329 ymax 0.022683053272397724 ymin -0.1882935882323592
# These are the dimensions of the plot xmax -5.782906877851789 xmin -5.9938835193565465 ymax -0.2024326194162055 ymin -0.4134092609209624
# These are the dimensions of the plot xmax -5.743909728883012 xmin -5.9548863703877695 ymax -0.4296886690786128 ymin -0.6406653105833697
# These are the dimensions of the plot xmax -5.700057688325391 xmin -5.911034329830148 ymax -0.6559046900788515 ymin -0.8668813315836085
# These are the dimensions of the plot xmax -5.640146040896393 xmin -5.85112268240115 ymax -0.8730176722188269 ymin -1.0839943137235837
# These are the dimensions of the plot xmax -5.584326436480161 xmin -5.795303077984919 ymax -1.0942928143456965 ymin -1.3052694558504534
# These are the dimensions of the plot xmax -5.521351176751749 xmin -5.732327818256507 ymax -1.2924560110339007 ymin -1.5034326525386577
# These are the dimensions of the plot xmax -5.454934071067455 xmin -5.665910712572212 ymax -1.4932899652399656 ymin -1.7042666067447225
# These are the dimensions of the plot xmax -5.390299792756021 xmin -5.601276434260778 ymax -1.6948909755641246 ymin -1.9058676170688815
# These are the dimensions of the plot xmax -5.320743791885978 xmin -5.531720433390736 ymax -1.885945580127687 ymin -2.096922221632444
# These are the dimensions of the plot xmax -5.259329284602717 xmin -5.470305926107474 ymax -2.084389827837523 ymin -2.2953664693422793
# These are the dimensions of the plot xmax -5.19461523071714 xmin -5.405591872221898 ymax -2.260932085169906 ymin -2.4719087266746635
# These are the dimensions of the plot xmax -5.126463607044602 xmin -5.33744024854936 ymax -2.4492439262199923 ymin -2.6602205677247497
# These are the dimensions of the plot xmax -5.0738723184857975 xmin -5.284848959990555 ymax -2.6246813284713175 ymin -2.835657969976075
# These are the dimensions of the plot xmax -5.018132602100541 xmin -5.229109243605298 ymax -2.8022268553128233 ymin -3.0132034968175807
# These are the dimensions of the plot xmax -4.9613178894458505 xmin -5.172294530950608 ymax -2.973556913818106 ymin -3.1845335553228633
# These are the dimensions of the plot xmax -4.914293593913235 xmin -5.125270235417992 ymax -3.144139810665835 ymin -3.3551164521705923
# These are the dimensions of the plot xmax -4.872219640126425 xmin -5.083196281631182 ymax -3.3071605130974397 ymin -3.518137154602197
# These are the dimensions of the plot xmax -4.81940459664434 xmin -5.030381238149097 ymax -3.4699033620038744 ymin -3.680880003508631
# These are the dimensions of the plot xmax -4.760119455910627 xmin -4.971096097415384 ymax -3.6387340738798724 ymin -3.849710715384629
# These are the dimensions of the plot xmax -4.716357156522789 xmin -4.927333798027546 ymax -3.800470393544435 ymin -4.011447035049192
# These are the dimensions of the plot xmax -4.663117655586368 xmin -4.874094297091125 ymax -3.969966706954505 ymin -4.180943348459262
# These are the dimensions of the plot xmax -4.595315299235035 xmin -4.806291940739793 ymax -4.145142244121056 ymin -4.356118885625813
# These are the dimensions of the plot xmax -4.521865234912269 xmin -4.732841876417027 ymax -4.326406824514349 ymin -4.537383466019106
# These are the dimensions of the plot xmax -4.473869321072656 xmin -4.6848459625774135 ymax -4.477639963264671 ymin -4.688616604769428
# These are the dimensions of the plot xmax -4.3988390565431565 xmin -4.609815698047914 ymax -4.6529749668772284 ymin -4.863951608381986
# These are the dimensions of the plot xmax -4.320328926103211 xmin -4.531305567607968 ymax -4.817637682314199 ymin -5.028614323818957
# These are the dimensions of the plot xmax -4.244285440441133 xmin -4.45526208194589 ymax -4.977678092486043 ymin -5.1886547339908
# These are the dimensions of the plot xmax -4.1569624831051994 xmin -4.367939124609957 ymax -5.148845923324484 ymin -5.3598225648292415
# These are the dimensions of the plot xmax -4.065926133050824 xmin -4.276902774555581 ymax -5.317347538494388 ymin -5.528324179999145
# These are the dimensions of the plot xmax -3.9703754760223884 xmin -4.181352117527146 ymax -5.482352258564046 ymin -5.693328900068804
# These are the dimensions of the plot xmax -3.8602834017496006 xmin -4.071260043254358 ymax -5.649959539350146 ymin -5.860936180854903
# These are the dimensions of the plot xmax -3.744150836557692 xmin -3.9551274780624492 ymax -5.823316966504976 ymin -6.034293608009733
# These are the dimensions of the plot xmax -3.6338010647374155 xmin -3.844777706242173 ymax -5.9846723027118935 ymin -6.195648944216651
# These are the dimensions of the plot xmax -3.508180647268989 xmin -3.7191572887737463 ymax -6.145868405882546 ymin -6.356845047387304
# These are the dimensions of the plot xmax -3.391472754178441 xmin -3.602449395683198 ymax -6.302402846824754 ymin -6.5133794883295115
# These are the dimensions of the plot xmax -3.276666029512575 xmin -3.4876426710173325 ymax -6.453458299371744 ymin -6.664434940876501
# These are the dimensions of the plot xmax -3.1454005573040167 xmin -3.356377198808774 ymax -6.600306261997744 ymin -6.8112829035025015
# These are the dimensions of the plot xmax -3.0123437410328346 xmin -3.223320382537592 ymax -6.751614915773569 ymin -6.962591557278326
# These are the dimensions of the plot xmax -2.898075553410509 xmin -3.1090521949152654 ymax -6.88158784921461 ymin -7.092564490719368
# These are the dimensions of the plot xmax -2.770612076021548 xmin -2.9815887175263054 ymax -7.010234959363828 ymin -7.221211600868585
# These are the dimensions of the plot xmax -2.643758663860953 xmin -2.8547353053657094 ymax -7.135116969617089 ymin -7.346093611121846
# These are the dimensions of the plot xmax -2.4926376950095817 xmin -2.703614336514339 ymax -7.267590871871039 ymin -7.478567513375796
# These are the dimensions of the plot xmax -2.3537617212486666 xmin -2.564738362753424 ymax -7.385196455249462 ymin -7.596173096754219
# These are the dimensions of the plot xmax -2.2550300860593673 xmin -2.4660067275641238 ymax -7.484654748422348 ymin -7.695631389927105
# These are the dimensions of the plot xmax -2.1466564258785015 xmin -2.357633067383259 ymax -7.5834640695987225 ymin -7.79444071110348
# These are the dimensions of the plot xmax -2.0307195078436253 xmin -2.2416961493483827 ymax -7.679021281791937 ymin -7.889997923296694
# These are the dimensions of the plot xmax -1.9318231423552616 xmin -2.142799783860019 ymax -7.768740393068042 ymin -7.9797170345728
# These are the dimensions of the plot xmax -1.8494294427131357 xmin -2.0604060842178926 ymax -7.854512096028748 ymin -8.065488737533505
# These are the dimensions of the plot xmax -1.74713005054109 xmin -1.958106692045847 ymax -7.933928386911642 ymin -8.1449050284164
# These are the dimensions of the plot xmax -1.6478908355576833 xmin -1.8588674770624403 ymax -8.020709112880057 ymin -8.231685754384815
# These are the dimensions of the plot xmax -1.5660846086311382 xmin -1.777061250135895 ymax -8.092551108252435 ymin -8.303527749757192
# These are the dimensions of the plot xmax -1.4890652235974915 xmin -1.7000418651022484 ymax -8.158389358936699 ymin -8.369366000441456
# These are the dimensions of the plot xmax -1.3977505826536276 xmin -1.6087272241583845 ymax -8.230248927995353 ymin -8.44122556950011
# These are the dimensions of the plot xmax -1.3278619885617908 xmin -1.5388386300665478 ymax -8.283916625972113 ymin -8.49489326747687
# These are the dimensions of the plot xmax -1.2331237136894337 xmin -1.4441003551941907 ymax -8.34055109311448 ymin -8.551527734619237
# These are the dimensions of the plot xmax -1.171009465308707 xmin -1.381986106813464 ymax -8.388363191518588 ymin -8.599339833023345
# These are the dimensions of the plot xmax -1.1058130601858316 xmin -1.3167897016905885 ymax -8.438029674251872 ymin -8.64900631575663
# These are the dimensions of the plot xmax -1.0501937901490408 xmin -1.2611704316537977 ymax -8.487790972854004 ymin -8.698767614358761
# These are the dimensions of the plot xmax -0.9939446761381909 xmin -1.2049213176429479 ymax -8.53079205198045 ymin -8.741768693485207
# These are the dimensions of the plot xmax -0.9739605952417705 xmin -1.1849372367465274 ymax -8.565682103368491 ymin -8.776658744873249
# These are the dimensions of the plot xmax -0.9650915339574162 xmin -1.1760681754621731 ymax -8.596121708379073 ymin -8.80709834988383
# These are the dimensions of the plot xmax -0.951853662199347 xmin -1.162830303704104 ymax -8.632454076690937 ymin -8.843430718195695
# These are the dimensions of the plot xmax -0.9611694857403921 xmin -1.172146127245149 ymax -8.664514454817363 ymin -8.87549109632212
# These are the dimensions of the plot xmax -0.957804088157987 xmin -1.168780729662744 ymax -8.698410519916825 ymin -8.909387161421582
# These are the dimensions of the plot xmax -0.9385119991390811 xmin -1.149488640643838 ymax -8.727262501787457 ymin -8.938239143292215
# These are the dimensions of the plot xmax -0.9174011617986997 xmin -1.1283778033034566 ymax -8.755305408938293 ymin -8.96628205044305
# These are the dimensions of the plot xmax -0.9338165408193988 xmin -1.1447931823241557 ymax -8.779296395144913 ymin -8.99027303664967
# These are the dimensions of the plot xmax -0.9271170704009075 xmin -1.1380937119056644 ymax -8.800077348519144 ymin -9.011053990023902
# These are the dimensions of the plot xmax 1.1215642447611487 xmin 0.9105876032563918 ymax 9.033906229982641 ymin 8.822929588477884
# These are the dimensions of the plot xmax 1.1247733429639883 xmin 0.9137967014592314 ymax 9.047805795921024 ymin 8.836829154416266
# These are the dimensions of the plot xmax 1.1425299720376536 xmin 0.9315533305328967 ymax 9.05118293821012 ymin 8.840206296705363
# These are the dimensions of the plot xmax 1.083504552930726 xmin 0.872527911425969 ymax 9.068632019705488 ymin 8.85765537820073
# These are the dimensions of the plot xmax 1.063362863394469 xmin 0.8523862218897121 ymax 9.077004356154514 ymin 8.866027714649757

# %%
#Here we try to track a star cluster keeping the center of mass at the center of the plot
plot_path="./plots_pkl/animation_plots/" #creating a path to store the plots only if it does not exist
if not os.path.exists(plot_path):
  os.makedirs(plot_path)


n=snapshot_end-snapshot_start+1
colors=['cyan','blue','green','magenta','yellow','teal','brown','tan','lime','red']

total_clusters=1
#fig1.suptitle("Cylindrical component of the velocity of Cluster Groups from Snapshot 596")
plot_count=0
#plot_count=0
snapshot_list=np.arange(snapshot_start,snapshot_end+1) #create a list of snapshots to plot
time=snapshot_list-snapshot_start #time starts from zero here where t=0 is at the snapshot where we start from
#time=[[0],[20],[40],[60],[80],[100]]

#################################
################################
rmax_global=importdata[time[1]+snapshot_start][1]["rmax"]
for i in range(len(time)):
    cluster_count=1 #change it to look for cluster no cluster_count+1
    
    for j in range(total_clusters):
        r=importdata[time[i]+snapshot_start][cluster_count+1]["rmax"]
        
        if r>rmax_global:
            rmax_global=r


#######################################
######################################

for i in range(len(time)):
    
    fig3=plt.figure(figsize=(7,5))
    ax3 = fig3.add_subplot(1,1,1)
    cluster_count=1 #change it change it to look for cluster no cluster_count+1
    for j in range(total_clusters):
        
        x=importdata[time[i]+snapshot_start][cluster_count+1]["x_tracked"]
        y=importdata[time[i]+snapshot_start][cluster_count+1]["y_tracked"]
        z=importdata[time[i]+snapshot_start][cluster_count+1]["z_tracked"]
        xcm=importdata[time[i]+snapshot_start][cluster_count+1]["xcm"]
        ycm=importdata[time[i]+snapshot_start][cluster_count+1]["ycm"]
        zcm=importdata[time[i]+snapshot_start][cluster_count+1]["zcm"]
        rmax=importdata[time[i]+snapshot_start][cluster_count+1]["rmax"]
        xlim_max=xcm+1.1*rmax_global
        xlim_min=xcm-1.1*rmax_global
        
        zlim_max=zcm+1.1*rmax_global
        zlim_min=zcm-1.1*rmax_global
        
        ylim_max=ycm+1.1*rmax_global
        ylim_min=ycm-1.1*rmax_global
        #print("These are the dimensions of the plot",xlim_max-xlim_min,ylim_max-ylim_min)
        ax3.scatter(x,z,label="cluster_group"+str(cluster_count+1),c=x)
        ax3.scatter(xcm,zcm,c="black",marker='x')
        ax3.set_xlabel("X")
        ax3.set_ylabel("Z")
        ax3.set_title("Cluster "+str(cluster_count+1)+" at T="+str(time[plot_count])+" in Myr")
        ax3.set_xlim(xlim_min,xlim_max)
        ax3.set_ylim(zlim_min,zlim_max)
        ax3.set_xticks([], [])
        ax3.set_yticks([], [])
        ax3.set_aspect('equal')
        ax3.annotate('', xy=(xcm-0.5, zlim_min+0.2), xytext=(xcm+0.5, zlim_min+0.2),xycoords='data', arrowprops=dict(alpha=0.5, fc='b', ec='b', arrowstyle="<->"))
        ax3.annotate('1 kpc',xy=(xcm,zlim_min+0.3),textcoords='data')
        cluster_count+=1
    
    #ax.legend(bbox_to_anchor=(1,0.5), loc='center left')
    plt.tight_layout()
    #plt.axis('square')
    fig3.savefig(plot_path+"cluster_2_snap_fixedCM_zVSx"+str(plot_count)+".png",bbox_inches='tight',dpi=200)
    plot_count+=1
    fig3.clf()
    plt.close()
        
#fig1.subplots_adjust(right=1.5)    
#fig11.legend((s1), ("vphi_cyl"),"lower right")
#fig11.suptitle("This is the title \n")


zVSx_snaps=[]
for k in range(0,101):
    zVSx_snaps.append(imageio.imread(plot_path+"cluster_2_snap_fixedCM_zVSx"+str(k) + '.png'))
    os.remove(plot_path+"cluster_2_snap_fixedCM_zVSx"+str(k) + ".png")

imageio.mimsave(plot_path+"cluster2_fixedCM_zVSx.gif", zVSx_snaps, duration = 1/8)

# %%
#This code tracks the different clusters as they evlove through time.
#The axes is fixed at the CM 
plot_path="./plots_pkl/animation_plots/" #creating a path to store the plots only if it does not exist
if not os.path.exists(plot_path):
  os.makedirs(plot_path)


n=snapshot_end-snapshot_start+1
colors=['cyan','blue','green','magenta','yellow','teal','brown','tan','lime','red']

total_clusters=10
#fig1.suptitle("Cylindrical component of the velocity of Cluster Groups from Snapshot 596")
plot_count=0
snapshot_list=np.arange(snapshot_start,snapshot_end+1) #create a list of snapshots to plot
time=snapshot_list-snapshot_start #time starts from zero here where t=0 is at the snapshot where we start from


#################################
################################
total_subplots=total_clusters
position = range(1,total_subplots + 1)
cols=3
rows=total_subplots//cols
rows=rows+total_subplots%cols

for i in range(len(time)):
    cluster_count=0
    #fig4 = plt.figure(figsize=(15,rows*4))
    fig4 = plt.figure(figsize=(8,rows*3))
    for j in range(total_clusters):
        ax = fig4.add_subplot(rows,cols,position[j])
        rmax_global=importdata[time[i]+snapshot_start][cluster_count+1]["rmax"]
        
        for t in range(len(time)):
            r=importdata[time[t]+snapshot_start][cluster_count+1]["rmax"]
            if r>rmax_global:
                 rmax_global=r

        x=importdata[time[i]+snapshot_start][cluster_count+1]["x_tracked"]
        y=importdata[time[i]+snapshot_start][cluster_count+1]["y_tracked"]
        z=importdata[time[i]+snapshot_start][cluster_count+1]["z_tracked"]
        xcm=importdata[time[i]+snapshot_start][cluster_count+1]["xcm"]
        ycm=importdata[time[i]+snapshot_start][cluster_count+1]["ycm"]
        zcm=importdata[time[i]+snapshot_start][cluster_count+1]["zcm"]
        rmax=importdata[time[i]+snapshot_start][cluster_count+1]["rmax"]
        xlim_max=xcm+1.1*rmax_global
        xlim_min=xcm-1.1*rmax_global
        
        zlim_max=zcm+1.1*rmax_global
        zlim_min=zcm-1.1*rmax_global
        
        ylim_max=ycm+1.1*rmax_global
        ylim_min=ycm-1.1*rmax_global
        #print("These are the dimensions of the plot",xlim_max-xlim_min,ylim_max-ylim_min)
        ax.scatter(x,y,label="cluster_group"+str(cluster_count+1),c=x)
        ax.scatter(xcm,ycm,c="black",marker='x')
        ax.set_xlabel("X")
        ax.set_ylabel("Y")
        ax.set_title("Cluster "+str(cluster_count+1)+" at T="+str(time[plot_count])+" in Myr",fontsize=8)
        ax.set_xlim(xlim_min,xlim_max)
        ax.set_ylim(ylim_min,ylim_max)
        ax.set_xticks([], [])
        ax.set_yticks([], [])
        ax.set_aspect('equal')
        ax.annotate('', xy=(xcm-0.5, ylim_min+0.2), xytext=(xcm+0.5, ylim_min+0.2),xycoords='data', arrowprops=dict(alpha=0.5, fc='b', ec='b', arrowstyle="<->"))
        ax.annotate('1 kpc',xy=(xcm,ylim_min+0.3),textcoords='data')
        cluster_count+=1
    
    #ax.legend(bbox_to_anchor=(1,0.5), loc='center left')
    #plt.tight_layout()
    #plt.axis('square')
    fig4.savefig(plot_path+"all_clusters_fixedCM_yVSx"+str(plot_count)+".png",bbox_inches='tight',dpi=200)
    plot_count+=1
    fig4.clf()
    plt.close()
#fig1.subplots_adjust(right=1.5)    
#fig11.legend((s1), ("vphi_cyl"),"lower right")
#fig11.suptitle("This is the title \n")


zVSx_snaps=[]
for k in range(0,95):
    zVSx_snaps.append(imageio.imread(plot_path+"all_clusters_fixedCM_yVSx"+str(k) + '.png'))
    os.remove(plot_path+"all_clusters_fixedCM_yVSx"+str(k) + ".png")

imageio.mimsave(plot_path+"all_clusters_fixedCM_yVSx.gif", zVSx_snaps, duration = 1/8)
# Out:
# <ipython-input-4-4d2333e61159>:62: MatplotlibDeprecationWarning: Passing the minor parameter of set_xticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   ax.set_xticks([], [])
# <ipython-input-4-4d2333e61159>:63: MatplotlibDeprecationWarning: Passing the minor parameter of set_yticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   ax.set_yticks([], [])

# %%
#This code tracks the different clusters as they evlove through time.
#The axes is fixed at the CM 
plot_path="./plots_pkl/animation_plots/" #creating a path to store the plots only if it does not exist
if not os.path.exists(plot_path):
  os.makedirs(plot_path)


n=snapshot_end-snapshot_start+1
colors=['cyan','blue','green','magenta','yellow','teal','brown','tan','lime','red']

total_clusters=10
#fig1.suptitle("Cylindrical component of the velocity of Cluster Groups from Snapshot 596")
plot_count=0
snapshot_list=np.arange(snapshot_start,snapshot_end+1) #create a list of snapshots to plot
time=snapshot_list-snapshot_start #time starts from zero here where t=0 is at the snapshot where we start from


#################################
################################
total_subplots=total_clusters
position = range(1,total_subplots + 1)
cols=3
rows=total_subplots//cols
rows=rows+total_subplots%cols

##############################
#we would evaluate the largest distance travelled by a star in all of the cluster and use it as our rmax_global
rmax_global=importdata[time[0]+snapshot_start][1]["rmax"]
        
for t in range(len(time)):
    cc=0
    for c in range(total_clusters):
        r=importdata[time[t]+snapshot_start][cc+1]["rmax"]
        if r>rmax_global:
            rmax_global=r
        cc+=1
print("This is the largest distance a star travlled from the CM in all these clusters",rmax_global)
############################
############################



for i in range(len(time)):
    cluster_count=0
    #fig4 = plt.figure(figsize=(15,rows*4))
    fig5 = plt.figure(figsize=(8,rows*3))
    for j in range(total_clusters):
        ax = fig5.add_subplot(rows,cols,position[j])
        x=importdata[time[i]+snapshot_start][cluster_count+1]["x_tracked"]
        y=importdata[time[i]+snapshot_start][cluster_count+1]["y_tracked"]
        z=importdata[time[i]+snapshot_start][cluster_count+1]["z_tracked"]
        xcm=importdata[time[i]+snapshot_start][cluster_count+1]["xcm"]
        ycm=importdata[time[i]+snapshot_start][cluster_count+1]["ycm"]
        zcm=importdata[time[i]+snapshot_start][cluster_count+1]["zcm"]
        rmax=importdata[time[i]+snapshot_start][cluster_count+1]["rmax"]
        xlim_max=xcm+1.1*rmax_global
        xlim_min=xcm-1.1*rmax_global
        
        zlim_max=zcm+1.1*rmax_global
        zlim_min=zcm-1.1*rmax_global
        
        ylim_max=ycm+1.1*rmax_global
        ylim_min=ycm-1.1*rmax_global
        #print("These are the dimensions of the plot",xlim_max-xlim_min,ylim_max-ylim_min)
        ax.scatter(x,y,label="cluster_group"+str(cluster_count+1),c=x)
        ax.scatter(xcm,ycm,c="black",marker='x')
        ax.set_xlabel("X")
        ax.set_ylabel("Y")
        ax.set_title("Cluster "+str(cluster_count+1)+" at T="+str(time[plot_count])+" in Myr",fontsize=8)
        ax.set_xlim(xlim_min,xlim_max)
        ax.set_ylim(ylim_min,ylim_max)
        ax.set_xticks([], [])
        ax.set_yticks([], [])
        ax.set_aspect('equal')
        ax.annotate('', xy=(xcm-0.5, ylim_min+0.2), xytext=(xcm+0.5, ylim_min+0.2),xycoords='data', arrowprops=dict(alpha=0.5, fc='b', ec='b', arrowstyle="<->"))
        ax.annotate('1 kpc',xy=(xcm,ylim_min+0.3),textcoords='data')
        cluster_count+=1
    
    #ax.legend(bbox_to_anchor=(1,0.5), loc='center left')
    #plt.tight_layout()
    #plt.axis('square')
    fig5.savefig(plot_path+"flip_fixed_all_clusters_fixedCM_fixed_r_yVSx"+str(plot_count)+".png",bbox_inches='tight',dpi=200)
    plot_count+=1
    fig5.clf()
    plt.close()
#fig1.subplots_adjust(right=1.5)    
#fig11.legend((s1), ("vphi_cyl"),"lower right")
#fig11.suptitle("This is the title \n")


zVSx_snaps=[]
for k in range(0,n):
    zVSx_snaps.append(imageio.imread(plot_path+"flip_fixed_all_clusters_fixedCM_fixed_r_yVSx"+str(k) + '.png'))
    os.remove(plot_path+"flip_fixed_all_clusters_fixedCM_fixed_r_yVSx"+str(k) + ".png")

imageio.mimsave(plot_path+"flip_fixed_all_clusters_fixedCM_fixed_r_yVSx.gif", zVSx_snaps, duration = 1/8)
# Out:
# This is the largest distance a star travlled from the CM in all these clusters 2.9228877932445627
# <ipython-input-14-e8054badf14a>:72: MatplotlibDeprecationWarning: Passing the minor parameter of set_xticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   ax.set_xticks([], [])
# <ipython-input-14-e8054badf14a>:73: MatplotlibDeprecationWarning: Passing the minor parameter of set_yticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   ax.set_yticks([], [])

# %%
#Plotting all clusters in a single axes 


plot_path="./plots_pkl/animation_plots/" #creating a path to store the plots only if it does not exist
if not os.path.exists(plot_path):
  os.makedirs(plot_path)


n=snapshot_end-snapshot_start+1
colors=['cyan','blue','green','magenta','yellow','teal','brown','tan','lime','red']

total_clusters=10
#fig1.suptitle("Cylindrical component of the velocity of Cluster Groups from Snapshot 596")
plot_count=0
#plot_count=0
snapshot_list=np.arange(snapshot_start,snapshot_end+1) #create a list of snapshots to plot
time=snapshot_list-snapshot_start #time starts from zero here where t=0 is at the snapshot where we start from
#time=[[0],[20],[40],[60],[80],[100]]

xmax=np.amax(importdata[time[1]+snapshot_start][1]["x_tracked"])
xmin=np.amin(importdata[time[1]+snapshot_start][1]["x_tracked"])
ymax=np.amax(importdata[time[1]+snapshot_start][1]["y_tracked"])
ymin=np.amin(importdata[time[1]+snapshot_start][1]["y_tracked"])
for i in range(len(time)-5):
    cluster_count=0
    
    for j in range(total_clusters):
        x=importdata[time[i]+snapshot_start][cluster_count+1]["x_tracked"]
        xmax_new=np.amax(x)
        #print(xmax_new)
        xmin_new=np.amin(x)
        if xmax_new>xmax:
            xmax=xmax_new
        if xmin_new<xmin:
            xmin=xmin_new
        
        y=importdata[time[i]+snapshot_start][cluster_count+1]["y_tracked"]
        ymax_new=np.amax(y)
        ymin_new=np.amin(y)
        if ymax_new>ymax:
            ymax=ymax_new
        if ymin_new<ymin:
            ymin=ymin_new

print("xmax=",xmax,"xmin=",xmin,"ymaxmin=",ymax,",",ymin)







for i in range(len(time)-5):
    
    fig6=plt.figure(figsize=(8,5))
    ax = fig6.add_subplot(1,1,1)
    cluster_count=0
    for j in range(total_clusters):
        
        x=importdata[time[i]+snapshot_start][cluster_count+1]["x_tracked"]
        y=importdata[time[i]+snapshot_start][cluster_count+1]["y_tracked"]
        xcm=importdata[time[i]+snapshot_start][cluster_count+1]["xcm"]
        ycm=importdata[time[i]+snapshot_start][cluster_count+1]["ycm"]
        z=importdata[time[i]+snapshot_start][cluster_count+1]["z_tracked"]
        
        s1=ax.scatter(x,y,label="cluster_group"+str(cluster_count+1),c=colors[cluster_count])
        #ax.scatter(np.abs(xcm),np.abs(ycm),c="black")
        ax.minorticks_on()
        ax.set_xlabel("x position in kpc")
        ax.set_ylabel("y position in kpc")
        ax.set_title("Clusters at T="+str(time[plot_count])+" in Myr")
        ax.set_xlim(xmin,xmax)
        ax.set_ylim(ymin,ymax)
        cluster_count+=1
    
    ax.legend(bbox_to_anchor=(1,0.5), loc='center left')
    plt.tight_layout()
    fig6.savefig(plot_path+"fixed_axes_snap"+str(plot_count)+".png",bbox_inches='tight',dpi=200)
    plot_count+=1
    fig6.clf()
    plt.close()
     
    
#fig1.subplots_adjust(right=1.5)    
#fig11.legend((s1), ("vphi_cyl"),"lower right")
#fig11.suptitle("This is the title \n")

images=[]
for k in range(0,n-5):
    images.append(imageio.imread(plot_path+"fixed_axes_snap"+str(k) + '.png'))
    os.remove(plot_path+"fixed_axes_snap"+str(k) + ".png")
imageio.mimsave(plot_path+"fixed_axes_snapshots.gif", images, duration = 1/8)
# Out:
# xmax= -5.996480406201754 xmin= -11.960946124406133 ymaxmin= 6.087337215672603 , -11.010695594770944
